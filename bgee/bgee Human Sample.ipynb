# %% [markdown]
# # bgee Human Sample

# %% [markdown]
# Author: Moshe Silverstein
# Date: 07-18
# Data Source Home: https://bgee.org/
# Data Source Download: https://bgee.org/?page=download&action=expr_calls#id1

# %%
import sys, datetime, os
import numpy as np
import pandas as pd
import importlib
import utility_functions as uf
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter

# %%
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))

# %% [markdown]
# # Path to Output Files

# %%
path = '/Users/moshesilverstein/Documents/Harmonizome/bgee/Output/'

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('Input/Homo_sapiens_expr_advanced_development.tsv', sep='\t')
# Out:
# /Users/moshesilverstein/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#            Gene ID Gene name Anatomical entity ID  \
# 0  ENSG00000000003    TSPAN6           CL:0000015
# 1  ENSG00000000003    TSPAN6           CL:0000019
# 2  ENSG00000000003    TSPAN6           CL:0000023
# 3  ENSG00000000003    TSPAN6           CL:0000083
# 4  ENSG00000000003    TSPAN6           CL:0000115
#
#         Anatomical entity name Developmental stage ID  \
# 0               male germ cell         HsapDv:0000092
# 1                        sperm         HsapDv:0000088
# 2                       oocyte         HsapDv:0000087
# 3  epithelial cell of pancreas         UBERON:0000104
# 4             endothelial cell         HsapDv:0000092
#
#               Developmental stage name Expression    Call quality  \
# 0      human middle aged stage (human)    present  silver quality
# 1  human early adulthood stage (human)    present  silver quality
# 2            human adult stage (human)     absent  silver quality
# 3                           life cycle    present  silver quality
# 4      human middle aged stage (human)    present  silver quality
#
#   Expression rank Including observed data               ...                \
# 0            5940                     yes               ...
# 1              23                     yes               ...
# 2           20500                     yes               ...
# 3            6050                     yes               ...
# 4           11800                     yes               ...
#
#   In situ hybridization experiment count showing expression of this gene in this condition or in sub-conditions with a low quality  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    In situ hybridization experiment count showing absence of expression of this gene in this condition or valid parent conditions with a high quality  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    In situ hybridization experiment count showing absence of expression of this gene in this condition or valid parent conditions with a low quality  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Including in situ hybridization observed data  RNA-Seq data  \
# 0                                             no       no data
# 1                                             no       no data
# 2                                             no       no data
# 3                                             no       no data
# 4                                             no       no data
#
#   RNA-Seq  experiment count showing expression of this gene in this condition or in sub-conditions with a high quality  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   RNA-Seq  experiment count showing expression of this gene in this condition or in sub-conditions with a low quality  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    RNA-Seq  experiment count showing absence of expression of this gene in this condition or valid parent conditions with a high quality  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    RNA-Seq  experiment count showing absence of expression of this gene in this condition or valid parent conditions with a low quality  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Including RNA-Seq observed data
# 0                              no
# 1                              no
# 2                              no
# 3                              no
# 4                              no
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (32962486, 32)

# %% [markdown]
# # Get relevant data

# %%
df = df[['Gene name', 'Anatomical entity name', 'Developmental stage name', 'Expression', 'Call quality']]

# %%
df.head()
# Out:
#   Gene name       Anatomical entity name             Developmental stage name  \
# 0    TSPAN6               male germ cell      human middle aged stage (human)
# 1    TSPAN6                        sperm  human early adulthood stage (human)
# 2    TSPAN6                       oocyte            human adult stage (human)
# 3    TSPAN6  epithelial cell of pancreas                           life cycle
# 4    TSPAN6             endothelial cell      human middle aged stage (human)
#
#   Expression    Call quality
# 0    present  silver quality
# 1    present  silver quality
# 2     absent  silver quality
# 3    present  silver quality
# 4    present  silver quality

# %%
df = df[df['Expression'] == 'present']

# %%
df['Sample'] = df['Anatomical entity name'].map(str) +'_'+ df['Developmental stage name'].map(str)

# %%
df.head()
# Out:
#   Gene name       Anatomical entity name             Developmental stage name  \
# 0    TSPAN6               male germ cell      human middle aged stage (human)
# 1    TSPAN6                        sperm  human early adulthood stage (human)
# 3    TSPAN6  epithelial cell of pancreas                           life cycle
# 4    TSPAN6             endothelial cell      human middle aged stage (human)
# 7    TSPAN6                    leukocyte      human middle aged stage (human)
#
#   Expression    Call quality                                            Sample
# 0    present  silver quality    male germ cell_human middle aged stage (human)
# 1    present  silver quality         sperm_human early adulthood stage (human)
# 3    present  silver quality            epithelial cell of pancreas_life cycle
# 4    present  silver quality  endothelial cell_human middle aged stage (human)
# 7    present  silver quality         leukocyte_human middle aged stage (human)

# %%
df = df[['Gene name', 'Sample']]

# %%
df.head()
# Out:
#   Gene name                                            Sample
# 0    TSPAN6    male germ cell_human middle aged stage (human)
# 1    TSPAN6         sperm_human early adulthood stage (human)
# 3    TSPAN6            epithelial cell of pancreas_life cycle
# 4    TSPAN6  endothelial cell_human middle aged stage (human)
# 7    TSPAN6         leukocyte_human middle aged stage (human)

# %%
df.shape
# Out:
# (19631082, 2)

# %% [markdown]
# # Map Gene Symbols To Up-to-date Approved Gene Symbols

# %%
df.set_index('Gene name', inplace=True)

# %%
uf.mapgenesymbols(df)
# Out:
# Progeres: 0%  36985 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 0%  41322 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 2%  467477 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 2%  472140 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1034418 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1039293 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1044134 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1053936 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1058624 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1067427 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1072119 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1076939 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1084931 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1089801 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 5%  1102201 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1294818 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1307917 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1318522 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1324535 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1336716 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1341560 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1346286 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1354089 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1359038 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1366408 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 6%  1371530 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1376205 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1384416 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1389265 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1397872 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1402708 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1407137 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1414560 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 7%  1419397 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2484811 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2500208 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2504834 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2510573 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2515516 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2523161 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2527869 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2532673 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2541033 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 12%  2545664 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2558430 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2563081 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2570747 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2575617 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2583384 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2588215 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2592968 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2600542 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2605403 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2610220 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2618156 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2623037 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2627761 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2635734 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2640505 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2645343 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2653704 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2658556 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2663295 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2670875 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2675711 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2680554 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2688293 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2693151 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2697879 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2705589 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2710389 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2716365 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2723390 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2728230 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2732888 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2739145 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 13%  2743858 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2748721 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2753560 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2758133 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2762836 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2767614 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2773098 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2777812 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2786098 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2790964 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2795567 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2802490 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2814524 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2818878 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2823570 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2830351 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2835046 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2844584 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2849334 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2857419 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2862125 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2877703 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2884637 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2898933 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2905627 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2912928 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2917556 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2925663 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2930460 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2938208 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 14%  2942830 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2947744 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2954043 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2958734 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2966803 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2971457 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2976232 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2982170 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2987048 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  2996347 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3004337 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3011292 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3016941 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3026676 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3037333 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3041988 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3049767 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3057490 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3064353 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3069206 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3073775 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3080729 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 15%  3085446 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 23%  4642021 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 23%  4655535 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 23%  4660309 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 23%  4668132 Out of 19631082
# IOPub message rate exceeded.
# ...
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 98%  19404238 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 98%  19409124 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 98%  19414262 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 98%  19419393 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 98%  19427630 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 98%  19432152 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19437715 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19442838 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19447799 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19452714 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19457707 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19462818 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19471568 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19476802 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19481788 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19486795 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19491869 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19496665 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19501789 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19506716 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19514344 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19519554 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19524437 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19529725 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19534578 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19539552 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19544545 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19549590 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19558055 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19562991 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19567912 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19572964 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19577777 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19582843 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19587749 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19592810 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19597691 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19604083 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19608823 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19613864 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19618787 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19623839 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 99%  19628602 Out of 19631082
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progeres: 100%  19631082 Out of 19631082

# %% [markdown]
# # Drop Duplicates

# %%
df.reset_index(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#   Gene name                                            Sample
# 0    TSPAN6    male germ cell_human middle aged stage (human)
# 1    TSPAN6         sperm_human early adulthood stage (human)
# 2    TSPAN6            epithelial cell of pancreas_life cycle
# 3    TSPAN6  endothelial cell_human middle aged stage (human)
# 4    TSPAN6         leukocyte_human middle aged stage (human)

# %%
df.shape
# Out:
# (14983142, 2)

# %% [markdown]
# # Create Binary Matrix

# %%
binary_matrix = uf.createBinaryMatrix(df)
# Out:
# Progeres: 100%  34668 Out of 34668

# %%
binary_matrix.head()
# Out:
#              right adrenal gland_human early adulthood stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  0.0
# XPO5                                                       1.0
#
#              corpus callosum_2-5 year-old child stage (human)  \
# VHLL                                                      0.0
# RNF10                                                     1.0
# RNU6ATAC15P                                               0.0
# RN7SKP187                                                 0.0
# XPO5                                                      1.0
#
#              cerebellum_young adult stage (human)  \
# VHLL                                          0.0
# RNF10                                         1.0
# RNU6ATAC15P                                   0.0
# RN7SKP187                                     0.0
# XPO5                                          1.0
#
#              muscle layer of sigmoid colon_human adult stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  1.0
# XPO5                                                       1.0
#
#              primary visual cortex_human middle aged stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  0.0
# XPO5                                                       1.0
#
#              testis_organogenesis stage  putamen_human adult stage (human)  \
# VHLL                                0.0                                1.0
# RNF10                               1.0                                1.0
# RNU6ATAC15P                         0.0                                0.0
# RN7SKP187                           0.0                                1.0
# XPO5                                1.0                                1.0
#
#              primary visual cortex_80 year-old and over human stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  0.0
# XPO5                                                       1.0
#
#              trachea_life cycle  \
# VHLL                        0.0
# RNF10                       1.0
# RNU6ATAC15P                 0.0
# RN7SKP187                   0.0
# XPO5                        1.0
#
#              left adrenal gland cortex_human adult stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  1.0
# XPO5                                                       1.0
#
#                               ...                    \
# VHLL                          ...
# RNF10                         ...
# RNU6ATAC15P                   ...
# RN7SKP187                     ...
# XPO5                          ...
#
#              vagina_human early adulthood stage (human)  \
# VHLL                                                0.0
# RNF10                                               1.0
# RNU6ATAC15P                                         0.0
# RN7SKP187                                           0.0
# XPO5                                                1.0
#
#              superior frontal gyrus_6-12 year-old child stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      0.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  0.0
# XPO5                                                       0.0
#
#              frontal lobe_late embryonic stage  \
# VHLL                                       0.0
# RNF10                                      0.0
# RNU6ATAC15P                                0.0
# RN7SKP187                                  0.0
# XPO5                                       0.0
#
#              cerebral cortex_late embryonic stage  \
# VHLL                                          0.0
# RNF10                                         0.0
# RNU6ATAC15P                                   0.0
# RN7SKP187                                     0.0
# XPO5                                          0.0
#
#              body of uterus_25-44 year-old human stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  0.0
# XPO5                                                       1.0
#
#              thoracic mammary gland_human late adulthood stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  0.0
# XPO5                                                       1.0
#
#              vermiform appendix_2-5 year-old child stage (human)  \
# VHLL                                                       0.0
# RNF10                                                      1.0
# RNU6ATAC15P                                                0.0
# RN7SKP187                                                  0.0
# XPO5                                                       0.0
#
#              amygdala_65-79 year-old human stage (human)  \
# VHLL                                                 0.0
# RNF10                                                1.0
# RNU6ATAC15P                                          0.0
# RN7SKP187                                            0.0
# XPO5                                                 1.0
#
#              periodontal ligament_post-juvenile adult stage  \
# VHLL                                                    0.0
# RNF10                                                   1.0
# RNU6ATAC15P                                             0.0
# RN7SKP187                                               0.0
# XPO5                                                    0.0
#
#              liver_2-5 year-old child stage (human)
# VHLL                                            0.0
# RNF10                                           1.0
# RNU6ATAC15P                                     0.0
# RN7SKP187                                       0.0
# XPO5                                            0.0
#
# [5 rows x 1077 columns]

# %%
binary_matrix.shape
# Out:
# (34668, 1077)

# %% [markdown]
# # Save Binary Matrix

# %%
filename = path+'bgee_human_sample_binary_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
binary_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene Set Library

# %%
name = 'bgee_human_sample_gene_set'

# %%
uf.createUpGeneSetLib(binary_matrix, path, name)
# Out:
# Progeres: 100%  1077 Out of 1077

# %% [markdown]
# # Create Attribute Library

# %%
name = 'bgee_human_sample_attribute_set'

# %%
uf.createUpAttributeSetLib(binary_matrix, path, name)
# Out:
# Progeres: 100%  34668 Out of 34668

# %% [markdown]
# # Create Gene List

# %%
gene_list = uf.createGeneList(binary_matrix)
# Out:
# Progeres: 100%  34668 Out of 34668

# %%
gene_list.head()
# Out:
#        GeneSym       GeneID
# 0         VHLL       391104
# 1        RNF10         9921
# 2  RNU6ATAC15P  1.06482e+08
# 3    RN7SKP187  1.06481e+08
# 4         XPO5        57510

# %%
gene_list.shape
# Out:
# (34668, 2)

# %% [markdown]
# # Save Gene List

# %%
filename = path+'bgee_human_sample_gene_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_list.to_csv(filename, sep='\t', index=False, compression='gzip')

# %% [markdown]
# # Create Attribute List

# %%
attribute_list = uf.createAttributeList(binary_matrix)

# %%
attribute_list.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [right adrenal gland_human early adulthood stage (human), corpus callosum_2-5 year-old child stage (human), cerebellum_young adult stage (human), muscle layer of sigmoid colon_human adult stage (human), primary visual cortex_human middle aged stage (human)]

# %%
attribute_list.shape
# Out:
# (1077, 0)

# %% [markdown]
# # Save Attribute List

# %%
filename = path+'bgee_human_sample_attribute_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_list.to_csv(filename, sep='\t', index=False, compression='gzip')

# %% [markdown]
# # Create Attribute Similarity matrix

# %%
attribute_similarity_matix = uf.createSimilarityMatrix(binary_matrix.T, 'jaccard')

# %%
attribute_similarity_matix.head()
# Out:
#                                                     right adrenal gland_human early adulthood stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           1.000000
# corpus callosum_2-5 year-old child stage (human)                                             0.677459
# cerebellum_young adult stage (human)                                                         0.400582
# muscle layer of sigmoid colon_human adult stage...                                           0.645799
# primary visual cortex_human middle aged stage (...                                           0.569228
#
#                                                     corpus callosum_2-5 year-old child stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                          0.677459
# corpus callosum_2-5 year-old child stage (human)                                            1.000000
# cerebellum_young adult stage (human)                                                        0.391820
# muscle layer of sigmoid colon_human adult stage...                                          0.633368
# primary visual cortex_human middle aged stage (...                                          0.568111
#
#                                                     cerebellum_young adult stage (human)  \
#
# right adrenal gland_human early adulthood stage...                              0.400582
# corpus callosum_2-5 year-old child stage (human)                                0.391820
# cerebellum_young adult stage (human)                                            1.000000
# muscle layer of sigmoid colon_human adult stage...                              0.276119
# primary visual cortex_human middle aged stage (...                              0.635783
#
#                                                     muscle layer of sigmoid colon_human adult stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.645799
# corpus callosum_2-5 year-old child stage (human)                                             0.633368
# cerebellum_young adult stage (human)                                                         0.276119
# muscle layer of sigmoid colon_human adult stage...                                           1.000000
# primary visual cortex_human middle aged stage (...                                           0.403923
#
#                                                     primary visual cortex_human middle aged stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.569228
# corpus callosum_2-5 year-old child stage (human)                                             0.568111
# cerebellum_young adult stage (human)                                                         0.635783
# muscle layer of sigmoid colon_human adult stage...                                           0.403923
# primary visual cortex_human middle aged stage (...                                           1.000000
#
#                                                     testis_organogenesis stage  \
#
# right adrenal gland_human early adulthood stage...                    0.672455
# corpus callosum_2-5 year-old child stage (human)                      0.607404
# cerebellum_young adult stage (human)                                  0.511483
# muscle layer of sigmoid colon_human adult stage...                    0.496284
# primary visual cortex_human middle aged stage (...                    0.721632
#
#                                                     putamen_human adult stage (human)  \
#
# right adrenal gland_human early adulthood stage...                           0.658247
# corpus callosum_2-5 year-old child stage (human)                             0.654251
# cerebellum_young adult stage (human)                                         0.285430
# muscle layer of sigmoid colon_human adult stage...                           0.844020
# primary visual cortex_human middle aged stage (...                           0.419681
#
#                                                     primary visual cortex_80 year-old and over human stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.606516
# corpus callosum_2-5 year-old child stage (human)                                             0.599362
# cerebellum_young adult stage (human)                                                         0.598990
# muscle layer of sigmoid colon_human adult stage...                                           0.434792
# primary visual cortex_human middle aged stage (...                                           0.882785
#
#                                                     trachea_life cycle  \
#
# right adrenal gland_human early adulthood stage...            0.580007
# corpus callosum_2-5 year-old child stage (human)              0.512419
# cerebellum_young adult stage (human)                          0.565059
# muscle layer of sigmoid colon_human adult stage...            0.406998
# primary visual cortex_human middle aged stage (...            0.687596
#
#                                                     left adrenal gland cortex_human adult stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.744150
# corpus callosum_2-5 year-old child stage (human)                                             0.668269
# cerebellum_young adult stage (human)                                                         0.313378
# muscle layer of sigmoid colon_human adult stage...                                           0.824806
# primary visual cortex_human middle aged stage (...                                           0.456426
#
#                                                                      ...                    \
#                                                                      ...
# right adrenal gland_human early adulthood stage...                   ...
# corpus callosum_2-5 year-old child stage (human)                     ...
# cerebellum_young adult stage (human)                                 ...
# muscle layer of sigmoid colon_human adult stage...                   ...
# primary visual cortex_human middle aged stage (...                   ...
#
#                                                     vagina_human early adulthood stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                    0.717625
# corpus callosum_2-5 year-old child stage (human)                                      0.662008
# cerebellum_young adult stage (human)                                                  0.314282
# muscle layer of sigmoid colon_human adult stage...                                    0.824483
# primary visual cortex_human middle aged stage (...                                    0.458745
#
#                                                     superior frontal gyrus_6-12 year-old child stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.190759
# corpus callosum_2-5 year-old child stage (human)                                             0.189779
# cerebellum_young adult stage (human)                                                         0.417797
# muscle layer of sigmoid colon_human adult stage...                                           0.130056
# primary visual cortex_human middle aged stage (...                                           0.318293
#
#                                                     frontal lobe_late embryonic stage  \
#
# right adrenal gland_human early adulthood stage...                           0.045625
# corpus callosum_2-5 year-old child stage (human)                             0.044992
# cerebellum_young adult stage (human)                                         0.083660
# muscle layer of sigmoid colon_human adult stage...                           0.030804
# primary visual cortex_human middle aged stage (...                           0.070380
#
#                                                     cerebral cortex_late embryonic stage  \
#
# right adrenal gland_human early adulthood stage...                              0.000057
# corpus callosum_2-5 year-old child stage (human)                                0.000055
# cerebellum_young adult stage (human)                                            0.000000
# muscle layer of sigmoid colon_human adult stage...                              0.000037
# primary visual cortex_human middle aged stage (...                              0.000091
#
#                                                     body of uterus_25-44 year-old human stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.800284
# corpus callosum_2-5 year-old child stage (human)                                             0.680998
# cerebellum_young adult stage (human)                                                         0.365567
# muscle layer of sigmoid colon_human adult stage...                                           0.712396
# primary visual cortex_human middle aged stage (...                                           0.524280
#
#                                                     thoracic mammary gland_human late adulthood stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.703486
# corpus callosum_2-5 year-old child stage (human)                                             0.652279
# cerebellum_young adult stage (human)                                                         0.303388
# muscle layer of sigmoid colon_human adult stage...                                           0.845695
# primary visual cortex_human middle aged stage (...                                           0.441524
#
#                                                     vermiform appendix_2-5 year-old child stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                           0.375317
# corpus callosum_2-5 year-old child stage (human)                                             0.339476
# cerebellum_young adult stage (human)                                                         0.491432
# muscle layer of sigmoid colon_human adult stage...                                           0.256394
# primary visual cortex_human middle aged stage (...                                           0.490453
#
#                                                     amygdala_65-79 year-old human stage (human)  \
#
# right adrenal gland_human early adulthood stage...                                     0.787522
# corpus callosum_2-5 year-old child stage (human)                                       0.711755
# cerebellum_young adult stage (human)                                                   0.379957
# muscle layer of sigmoid colon_human adult stage...                                     0.690633
# primary visual cortex_human middle aged stage (...                                     0.559397
#
#                                                     periodontal ligament_post-juvenile adult stage  \
#
# right adrenal gland_human early adulthood stage...                                        0.296967
# corpus callosum_2-5 year-old child stage (human)                                          0.269173
# cerebellum_young adult stage (human)                                                      0.441091
# muscle layer of sigmoid colon_human adult stage...                                        0.200022
# primary visual cortex_human middle aged stage (...                                        0.407175
#
#                                                     liver_2-5 year-old child stage (human)
#
# right adrenal gland_human early adulthood stage...                                0.238924
# corpus callosum_2-5 year-old child stage (human)                                  0.218037
# cerebellum_young adult stage (human)                                              0.383995
# muscle layer of sigmoid colon_human adult stage...                                0.162448
# primary visual cortex_human middle aged stage (...                                0.328921
#
# [5 rows x 1077 columns]

# %% [markdown]
# # Save Attribute Similarity Matrix

# %%
filename = path+'bgee_human_sample_attribute_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene Similarity Matrix

# %%
gene_similarity_matix = uf.createSimilarityMatrix(binary_matrix, 'jaccard')

# %%
gene_similarity_matix.head()
# Out:
#                  VHLL     RNF10  RNU6ATAC15P  RN7SKP187      XPO5     INTS6  \
#
# VHLL         1.000000  0.077399     0.125000   0.221311  0.094103  0.083149
# RNF10        0.077399  1.000000     0.024768   0.230134  0.805726  0.920945
# RNU6ATAC15P  0.125000  0.024768     1.000000   0.083333  0.030113  0.026608
# RN7SKP187    0.221311  0.230134     0.083333   1.000000  0.279799  0.247228
# XPO5         0.094103  0.805726     0.030113   0.279799  1.000000  0.836757
#
#                ZNF879     CDHR1  TCTEX1D1      TAF7    ...      TH2LCRR  \
#                                                        ...
# VHLL         0.109810  0.125850  0.129825  0.077002    ...     0.145957
# RNF10        0.703093  0.597536  0.587203  0.958669    ...     0.522188
# RNU6ATAC15P  0.035139  0.039116  0.042179  0.024641    ...     0.047431
# RN7SKP187    0.326501  0.354515  0.391916  0.228953    ...     0.440711
# XPO5         0.845387  0.643705  0.711779  0.803462    ...     0.634881
#
#               MIR892C   PSMC1P9  MTND3P13    PRPF19   MIR6850    ZNF524  \
#
# VHLL         0.260000  0.115789  0.178808  0.079365  0.294118  0.140713
# RNF10        0.052632  0.031992  0.106295  0.949084  0.172343  0.550052
# RNU6ATAC15P  0.271186  0.078431  0.114035  0.025397  0.110465  0.045028
# RN7SKP187    0.186147  0.104348  0.369748  0.235979  0.529412  0.410448
# XPO5         0.063990  0.038896  0.129235  0.812695  0.209536  0.664581
#
#                PLPPR1    TMEM25    ZNF484
#
# VHLL         0.118199  0.112952  0.185000
# RNF10        0.537668  0.678314  0.411765
# RNU6ATAC15P  0.046065  0.036145  0.060150
# RN7SKP187    0.271795  0.335843  0.558897
# XPO5         0.536131  0.805933  0.500627
#
# [5 rows x 34668 columns]

# %% [markdown]
# # Save Gene Similarity Matrix

# %%
filename = path+'bgee_human_sample_gene_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene-Attribute Edge List

# %%
name = 'bgee_human_sample_gene_attribute_edge_list'

# %%
uf.createGeneAttributeEdgeList(binary_matrix, attribute_list, gene_list, path, name)
# Out:
# Progeres: 100%  1077 Out of 1077
#
#  The number of statisticaly relevent gene-attribute associations is: 14983142
