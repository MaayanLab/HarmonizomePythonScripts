# %% [markdown]
# # Orphanet

# %% [markdown]
# Author: John Erol Evangelista <br/>
# Date: 01-19 <br/>
# Data Source: http://www.orphadata.org

# %%
import sys, datetime, os
import numpy as np
import pandas as pd
import importlib
import xml.etree.ElementTree as ET

# %matplotlib inline
if "/Users/maayan/sigsets/Harmonizome/HarmonizomePythonScripts" not in sys.path:
    sys.path.append("/Users/maayan/sigsets/Harmonizome/HarmonizomePythonScripts")
import utility_functions as uf

# %%
importlib.reload(uf)
# Out:
# <module 'utility_functions' from '/Users/maayan/sigsets/Harmonizome/HarmonizomePythonScripts/utility_functions.py'>

# %% [markdown]
# ## Load Data

# %%
tree = ET.parse('/Users/maayan/sigsets/Harmonizome/Data/Orphanet_Disease_To_Genes.xml')
root = tree.getroot()

# %%
for disease in root.find("DisorderList").findall("Disorder"):
    OrphaNum = disease.find("OrphaNumber").text
    Name = disease.find("Name").text
    Name = disease.find("Name").text
# Out:
# Multiple epiphyseal dysplasia, Al-Gazali type
# Brachydactyly-short stature-retinitis pigmentosa syndrome
# Aspartylglucosaminuria
# Multiple sulfatase deficiency
# Beta-mannosidosis
# Pontocerebellar hypoplasia type 5
# Pontocerebellar hypoplasia type 4
# Von Willebrand disease type 1
# Pontocerebellar hypoplasia type 6
# Farber disease
# Von Willebrand disease type 2A
# Fucosidosis
# Von Willebrand disease type 2M
# Glycogen storage disease due to glycogen debranching enzyme deficiency
# Von Willebrand disease type 2B
# Glycogen storage disease due to muscle glycogen phosphorylase deficiency
# Von Willebrand disease type 2N
# Von Willebrand disease type 3
# Glycogen storage disease due to muscle phosphofructokinase deficiency
# Stickler syndrome type 3
# Glycogen storage disease due to liver glycogen phosphorylase deficiency
# FASTKD2-related infantile mitochondrial encephalomyopathy
# Paroxysmal nocturnal hemoglobinuria
# Intellectual disability, Birk-Barel type
# ...

# %%
# Out:
# 'X'

# %%
chr(ord('A')+25)
# Out:
# 'Z'
