# %% [markdown]
# # Allen Brain Atlas Prenatal Human Brain Tissue (RNA-Seq)

# %% [markdown]
# Author: Moshe Silverstein <br/>
# Date: 3-2018 <br/>
# Data Source: http://www.brainspan.org/static/download.html

# %%
import sys, datetime
import numpy as np
import pandas as pd
import importlib
import untility_functions as uf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from clustergrammer_widget import *
net = Network(clustergrammer_widget)

# %%
importlib.reload(uf)
# Out:
# <module 'untility_functions' from '/Users/moshesilverstein/Documents/Harmonizome/Allen Brain Atlas/BRAINSPAN atlas of the developing brain/Prenatal LMD Microarrat Dataset/untility_functions.py'>

# %% [markdown]
# # Versions Of Modules In Use

# %%
# %load_ext version_information
# %version_information numpy, pandas, clustergrammer_widget
# Out:
# Software versions
# Python 3.5.2 64bit [GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]
# IPython 5.3.0
# OS Darwin 17.2.0 x86_64 i386 64bit
# numpy 1.13.1
# pandas 0.21.0
# clustergrammer_widget 1.9.0
# Thu Mar 08 17:02:05 2018 EST

# %% [markdown]
# # Path to Output Files

# %%
path = '/Users/moshesilverstein/Documents/Harmonizome/Allen Brain Atlas/BRAINSPAN atlas of the developing brain/Prenatal LMD Microarrat Dataset/Output/'

# %% [markdown]
# # Load Data

# %% [markdown]
# # Donor 12566

# %%
matrix_12566 = pd.read_csv('Input/lmd_matrix_12566/expression_matrix.csv', header=None, index_col=0)

# %%
matrix_12566.head()
# Out:
#               1         2         3         4         5         6         7    \
# 0
# 1058685  1.439228  2.097112  1.517832  2.365573  1.064640  1.031267  4.412305
# 1058684  5.469738  5.225554  5.412578  5.513093  4.937427  5.017110  6.465528
# 1058683  1.992190  1.755553  2.978326  1.991787  1.439148  1.448960  3.096352
# 1058682  3.049617  5.047364  4.630829  5.531359  3.745649  4.727461  3.606794
# 1058681  6.390517  7.295888  6.441227  6.885406  6.348808  6.505006  6.384969
#
#               8         9         10     ...          301       302       303  \
# 0                                        ...
# 1058685  5.066255  1.292890  2.950517    ...     0.864253  0.661506  2.875280
# 1058684  5.180694  5.250663  6.810748    ...     5.083837  4.897488  7.306555
# 1058683  1.541452  1.682621  3.051413    ...     2.442397  3.147917  4.198493
# 1058682  4.585564  4.608645  3.106597    ...     4.024892  4.700923  4.688663
# 1058681  6.567756  6.888328  5.528545    ...     6.964731  6.843392  6.299629
#
#               304       305       306       307       308       309       310
# 0
# 1058685  1.044508  4.752277  2.094123  4.003514  1.300852  1.027525  1.366720
# 1058684  5.339243  5.550479  6.138744  5.690613  5.651417  5.291752  5.103054
# 1058683  1.814388  2.000036  7.231437  2.113372  2.059020  1.823958  1.671450
# 1058682  3.613006  4.641472  2.742722  3.026607  3.778842  3.672038  3.395014
# 1058681  6.502205  6.222799  5.692533  6.331764  6.401711  5.889965  5.895140
#
# [5 rows x 310 columns]

# %%
matrix_12566.shape
# Out:
# (58692, 310)

# %% [markdown]
# # Load Sample Metadata

# %%
sample_meta_12566 = pd.read_csv('Input/lmd_matrix_12566/columns_metadata.csv')

# %%
sample_meta_12566.head()
# Out:
#    structure_id  well_id structure_acronym  \
# 0         11305    12887            CA3Csp
# 1         11723    12883             cCPco
# 2         11293    12879            CA2Csp
# 3         11721    12103            cCPmii
# 4         11999    12871             pVZpd
#
#                                    structure_name
# 0                stratum pyramidale of caudal CA3
# 1             outer CP in caudal cingulate cortex
# 2                stratum pyramidale of caudal CA2
# 3                 inner CP in midcingulate cortex
# 4  VZ in posterosuperior (dorsal) parietal cortex

# %%
sample_meta_12566.shape
# Out:
# (310, 4)

# %% [markdown]
# # Load Gene Metadata

# %%
gene_meta_12566 = pd.read_csv('Input/lmd_matrix_12566/rows_metadata.csv', index_col=0)

# %%
gene_meta_12566.head()
# Out:
#                       probeset_name  gene_id gene_symbol  \
# probeset_id
# 1058685                 A_23_P20713      729         C8G
# 1058684      CUST_15185_PI416261804      731          C9
# 1058683                A_32_P203917      731          C9
# 1058682                A_23_P138819      736      MRPL49
# 1058681                A_24_P232500      736      MRPL49
#
#                                              gene_name  entrez_id chromosome
# probeset_id
# 1058685      complement component 8, gamma polypeptide      733.0          9
# 1058684                         complement component 9      735.0          5
# 1058683                         complement component 9      735.0          5
# 1058682            mitochondrial ribosomal protein L49      740.0         11
# 1058681            mitochondrial ribosomal protein L49      740.0         11

# %%
gene_meta_12566.shape
# Out:
# (58692, 6)

# %% [markdown]
# # Map Sample Metadata to Sample ID

# %%
lst = []

for i,col in enumerate(matrix_12566.columns):
    col_num = i+1
    sample = str(sample_meta_12566.loc[(col_num-1), 'structure_name'])
    lst.append(sample)
    
matrix_12566.columns = lst

# %%
matrix_12566.head()
# Out:
#          stratum pyramidale of caudal CA3  \
# 0
# 1058685                          1.439228
# 1058684                          5.469738
# 1058683                          1.992190
# 1058682                          3.049617
# 1058681                          6.390517
#
#          outer CP in caudal cingulate cortex  \
# 0
# 1058685                             2.097112
# 1058684                             5.225554
# 1058683                             1.755553
# 1058682                             5.047364
# 1058681                             7.295888
#
#          stratum pyramidale of caudal CA2  inner CP in midcingulate cortex  \
# 0
# 1058685                          1.517832                         2.365573
# 1058684                          5.412578                         5.513093
# 1058683                          2.978326                         1.991787
# 1058682                          4.630829                         5.531359
# 1058681                          6.441227                         6.885406
#
#          VZ in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                        1.064640
# 1058684                                        4.937427
# 1058683                                        1.439148
# 1058682                                        3.745649
# 1058681                                        6.348808
#
#          pyramidal cells of caudal CA4  lateral posterior nucleus of thalamus  \
# 0
# 1058685                       1.031267                               4.412305
# 1058684                       5.017110                               6.465528
# 1058683                       1.448960                               3.096352
# 1058682                       4.727461                               3.606794
# 1058681                       6.505006                               6.384969
#
#          SP in primary visual cortex  \
# 0
# 1058685                     5.066255
# 1058684                     5.180694
# 1058683                     1.541452
# 1058682                     4.585564
# 1058681                     6.567756
#
#          inner CP in medial temporal-occipital cortex  \
# 0
# 1058685                                      1.292890
# 1058684                                      5.250663
# 1058683                                      1.682621
# 1058682                                      4.608645
# 1058681                                      6.888328
#
#          MZ in posterior parahippocampal cortex  \
# 0
# 1058685                                2.950517
# 1058684                                6.810748
# 1058683                                3.051413
# 1058682                                3.106597
# 1058681                                5.528545
#
#                         ...                  inner CP in frontal polar cortex  \
# 0                       ...
# 1058685                 ...                                          0.864253
# 1058684                 ...                                          5.083837
# 1058683                 ...                                          2.442397
# 1058682                 ...                                          4.024892
# 1058681                 ...                                          6.964731
#
#          MZ in frontal polar cortex  oculomotor nucleus  \
# 0
# 1058685                    0.661506            2.875280
# 1058684                    4.897488            7.306555
# 1058683                    3.147917            4.198493
# 1058682                    4.700923            4.688663
# 1058681                    6.843392            6.299629
#
#          medial habenular nucleus  parafascicular nucleus of thalamus  \
# 0
# 1058685                  1.044508                            4.752277
# 1058684                  5.339243                            5.550479
# 1058683                  1.814388                            2.000036
# 1058682                  3.613006                            4.641472
# 1058681                  6.502205                            6.222799
#
#          SG in rostral entorhinal cortex  SP in perirhinal cortex  \
# 0
# 1058685                         2.094123                 4.003514
# 1058684                         6.138744                 5.690613
# 1058683                         7.231437                 2.113372
# 1058682                         2.742722                 3.026607
# 1058681                         5.692533                 6.331764
#
#          inner CP in rostral perirhinal cortex  \
# 0
# 1058685                               1.300852
# 1058684                               5.651417
# 1058683                               2.059020
# 1058682                               3.778842
# 1058681                               6.401711
#
#          IZ in primary somatosensory cortex  \
# 0
# 1058685                            1.027525
# 1058684                            5.291752
# 1058683                            1.823958
# 1058682                            3.672038
# 1058681                            5.889965
#
#          MZ in primary somatosensory cortex
# 0
# 1058685                            1.366720
# 1058684                            5.103054
# 1058683                            1.671450
# 1058682                            3.395014
# 1058681                            5.895140
#
# [5 rows x 310 columns]

# %% [markdown]
# # Map Gene to Row

# %%
matrix_12566.index = gene_meta_12566['gene_symbol']

# %%
matrix_12566.index.name = ''

# %%
matrix_12566.head()
# Out:
#         stratum pyramidale of caudal CA3  outer CP in caudal cingulate cortex  \
#
# C8G                             1.439228                             2.097112
# C9                              5.469738                             5.225554
# C9                              1.992190                             1.755553
# MRPL49                          3.049617                             5.047364
# MRPL49                          6.390517                             7.295888
#
#         stratum pyramidale of caudal CA2  inner CP in midcingulate cortex  \
#
# C8G                             1.517832                         2.365573
# C9                              5.412578                         5.513093
# C9                              2.978326                         1.991787
# MRPL49                          4.630829                         5.531359
# MRPL49                          6.441227                         6.885406
#
#         VZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                           1.064640
# C9                                            4.937427
# C9                                            1.439148
# MRPL49                                        3.745649
# MRPL49                                        6.348808
#
#         pyramidal cells of caudal CA4  lateral posterior nucleus of thalamus  \
#
# C8G                          1.031267                               4.412305
# C9                           5.017110                               6.465528
# C9                           1.448960                               3.096352
# MRPL49                       4.727461                               3.606794
# MRPL49                       6.505006                               6.384969
#
#         SP in primary visual cortex  \
#
# C8G                        5.066255
# C9                         5.180694
# C9                         1.541452
# MRPL49                     4.585564
# MRPL49                     6.567756
#
#         inner CP in medial temporal-occipital cortex  \
#
# C8G                                         1.292890
# C9                                          5.250663
# C9                                          1.682621
# MRPL49                                      4.608645
# MRPL49                                      6.888328
#
#         MZ in posterior parahippocampal cortex  \
#
# C8G                                   2.950517
# C9                                    6.810748
# C9                                    3.051413
# MRPL49                                3.106597
# MRPL49                                5.528545
#
#                        ...                  inner CP in frontal polar cortex  \
#                        ...
# C8G                    ...                                          0.864253
# C9                     ...                                          5.083837
# C9                     ...                                          2.442397
# MRPL49                 ...                                          4.024892
# MRPL49                 ...                                          6.964731
#
#         MZ in frontal polar cortex  oculomotor nucleus  \
#
# C8G                       0.661506            2.875280
# C9                        4.897488            7.306555
# C9                        3.147917            4.198493
# MRPL49                    4.700923            4.688663
# MRPL49                    6.843392            6.299629
#
#         medial habenular nucleus  parafascicular nucleus of thalamus  \
#
# C8G                     1.044508                            4.752277
# C9                      5.339243                            5.550479
# C9                      1.814388                            2.000036
# MRPL49                  3.613006                            4.641472
# MRPL49                  6.502205                            6.222799
#
#         SG in rostral entorhinal cortex  SP in perirhinal cortex  \
#
# C8G                            2.094123                 4.003514
# C9                             6.138744                 5.690613
# C9                             7.231437                 2.113372
# MRPL49                         2.742722                 3.026607
# MRPL49                         5.692533                 6.331764
#
#         inner CP in rostral perirhinal cortex  \
#
# C8G                                  1.300852
# C9                                   5.651417
# C9                                   2.059020
# MRPL49                               3.778842
# MRPL49                               6.401711
#
#         IZ in primary somatosensory cortex  MZ in primary somatosensory cortex
#
# C8G                               1.027525                            1.366720
# C9                                5.291752                            5.103054
# C9                                1.823958                            1.671450
# MRPL49                            3.672038                            3.395014
# MRPL49                            5.889965                            5.895140
#
# [5 rows x 310 columns]

# %% [markdown]
# # Donor 12840

# %%
matrix_12840 = pd.read_csv('Input/lmd_matrix_12840/expression_matrix.csv', header=None, index_col=0)

# %%
matrix_12840.head()
# Out:
#               1         2         3         4         5         6         7    \
# 0
# 1058685  1.870266  2.500637  5.087565  1.375560  4.130802  4.113178  5.524362
# 1058684  6.297873  5.829589  4.539848  3.944338  4.044747  5.925640  8.025330
# 1058683  2.069434  2.828320  1.844547  1.429880  2.204994  1.598890  1.882322
# 1058682  2.002642  3.366205  4.754818  3.098781  4.431086  4.107063  2.043070
# 1058681  5.460101  6.524749  6.309441  6.213752  6.014018  6.083929  5.731555
#
#               8         9         10     ...          318       319       320  \
# 0                                        ...
# 1058685  1.869377  4.435360  3.926297    ...     1.730386  1.225932  1.323599
# 1058684  4.718171  5.240465  6.237864    ...     4.403363  3.741472  3.804305
# 1058683  2.107117  2.319331  2.290332    ...     1.699429  1.318732  1.361300
# 1058682  3.370859  5.421633  3.433157    ...     5.698593  3.935162  2.617162
# 1058681  6.351332  7.388239  5.625046    ...     7.673056  6.244501  6.025255
#
#               321       322       323       324       325       326       327
# 0
# 1058685  2.192735  2.111756  0.844384  2.487709  0.964439  2.047743  2.082210
# 1058684  4.889730  5.679992  3.350249  5.340184  3.912035  4.673747  4.016817
# 1058683  2.247316  2.021892  2.997790  2.326233  1.020810  1.950179  1.557761
# 1058682  3.745330  5.028064  4.820175  2.480152  4.254607  2.151463  2.368740
# 1058681  6.244710  7.425317  6.963295  6.609604  5.972166  5.973547  5.634292
#
# [5 rows x 327 columns]

# %%
matrix_12840.shape
# Out:
# (58692, 327)

# %% [markdown]
# # Load Sample Metadata

# %%
sample_meta_12840 = pd.read_csv('Input/lmd_matrix_12840/columns_metadata.csv')

# %%
sample_meta_12840.head()
# Out:
#    structure_id    well_id structure_acronym  \
# 0         10368  127408509                BL
# 1         11391  127399761               ELR
# 2         10398  113222060                MD
# 3         13100  127408489            tCP36o
# 4         10494  113222050            LHAtub
#
#                                       structure_name
# 0                basolateral nucleus (basal nucleus)
# 1            laterorostral part of entorhinal cortex
# 2                    mediodorsal nucleus of thalamus
# 3  outer CP in (rostral) midinferior temporal cor...
# 4            lateral hypothalamic area, tuberal part

# %%
sample_meta_12840.shape
# Out:
# (327, 4)

# %% [markdown]
# # Load Gene Metadata

# %%
gene_meta_12840 = pd.read_csv('Input/lmd_matrix_12840/rows_metadata.csv', index_col=0)

# %%
gene_meta_12840.head()
# Out:
#                       probeset_name  gene_id gene_symbol  \
# probeset_id
# 1058685                 A_23_P20713      729         C8G
# 1058684      CUST_15185_PI416261804      731          C9
# 1058683                A_32_P203917      731          C9
# 1058682                A_23_P138819      736      MRPL49
# 1058681                A_24_P232500      736      MRPL49
#
#                                              gene_name  entrez_id chromosome
# probeset_id
# 1058685      complement component 8, gamma polypeptide      733.0          9
# 1058684                         complement component 9      735.0          5
# 1058683                         complement component 9      735.0          5
# 1058682            mitochondrial ribosomal protein L49      740.0         11
# 1058681            mitochondrial ribosomal protein L49      740.0         11

# %%
gene_meta_12840.shape
# Out:
# (58692, 6)

# %% [markdown]
# # Map Sample Metadata to Sample ID

# %%
lst = []

for i,col in enumerate(matrix_12840.columns):
    col_num = i+1
    sample = str(sample_meta_12840.loc[(col_num-1), 'structure_name'])
    lst.append(sample)
    
matrix_12840.columns = lst

# %%
matrix_12840.head()
# Out:
#          basolateral nucleus (basal nucleus)  \
# 0
# 1058685                             1.870266
# 1058684                             6.297873
# 1058683                             2.069434
# 1058682                             2.002642
# 1058681                             5.460101
#
#          laterorostral part of entorhinal cortex  \
# 0
# 1058685                                 2.500637
# 1058684                                 5.829589
# 1058683                                 2.828320
# 1058682                                 3.366205
# 1058681                                 6.524749
#
#          mediodorsal nucleus of thalamus  \
# 0
# 1058685                         5.087565
# 1058684                         4.539848
# 1058683                         1.844547
# 1058682                         4.754818
# 1058681                         6.309441
#
#          outer CP in (rostral) midinferior temporal cortex (area 36)  \
# 0
# 1058685                                           1.375560
# 1058684                                           3.944338
# 1058683                                           1.429880
# 1058682                                           3.098781
# 1058681                                           6.213752
#
#          lateral hypothalamic area, tuberal part  \
# 0
# 1058685                                 4.130802
# 1058684                                 4.044747
# 1058683                                 2.204994
# 1058682                                 4.431086
# 1058681                                 6.014018
#
#          dorsomedial hypothalamic nucleus  \
# 0
# 1058685                          4.113178
# 1058684                          5.925640
# 1058683                          1.598890
# 1058682                          4.107063
# 1058681                          6.083929
#
#          ventral anterior nucleus of thalamus  \
# 0
# 1058685                              5.524362
# 1058684                              8.025330
# 1058683                              1.882322
# 1058682                              2.043070
# 1058681                              5.731555
#
#          ventromedial hypothalamic nucleus  anteroventral nucleus of thalamus  \
# 0
# 1058685                           1.869377                           4.435360
# 1058684                           4.718171                           5.240465
# 1058683                           2.107117                           2.319331
# 1058682                           3.370859                           5.421633
# 1058681                           6.351332                           7.388239
#
#          anteromedial nucleus of thalamus             ...              \
# 0                                                     ...
# 1058685                          3.926297             ...
# 1058684                          6.237864             ...
# 1058683                          2.290332             ...
# 1058682                          3.433157             ...
# 1058681                          5.625046             ...
#
#          rostral division of OFCi (area 11)  \
# 0
# 1058685                            1.730386
# 1058684                            4.403363
# 1058683                            1.699429
# 1058682                            5.698593
# 1058681                            7.673056
#
#          VZ in ventrolateral prefrontal cortex  \
# 0
# 1058685                               1.225932
# 1058684                               3.741472
# 1058683                               1.318732
# 1058682                               3.935162
# 1058681                               6.244501
#
#          outer SZ in ventrolateral prefrontal cortex  \
# 0
# 1058685                                     1.323599
# 1058684                                     3.804305
# 1058683                                     1.361300
# 1058682                                     2.617162
# 1058681                                     6.025255
#
#          IZ in ventrolateral prefrontal cortex  \
# 0
# 1058685                               2.192735
# 1058684                               4.889730
# 1058683                               2.247316
# 1058682                               3.745330
# 1058681                               6.244710
#
#          SP in ventrolateral prefrontal cortex  \
# 0
# 1058685                               2.111756
# 1058684                               5.679992
# 1058683                               2.021892
# 1058682                               5.028064
# 1058681                               7.425317
#
#          outer CP in ventrolateral prefrontal cortex  \
# 0
# 1058685                                     0.844384
# 1058684                                     3.350249
# 1058683                                     2.997790
# 1058682                                     4.820175
# 1058681                                     6.963295
#
#          outer CP in frontal polar cortex  inner SZ in frontal polar cortex  \
# 0
# 1058685                          2.487709                          0.964439
# 1058684                          5.340184                          3.912035
# 1058683                          2.326233                          1.020810
# 1058682                          2.480152                          4.254607
# 1058681                          6.609604                          5.972166
#
#          outer SZ in frontal polar cortex  IZ in frontal polar cortex
# 0
# 1058685                          2.047743                    2.082210
# 1058684                          4.673747                    4.016817
# 1058683                          1.950179                    1.557761
# 1058682                          2.151463                    2.368740
# 1058681                          5.973547                    5.634292
#
# [5 rows x 327 columns]

# %% [markdown]
# # Map Gene to Row

# %%
matrix_12840.index = gene_meta_12840['gene_symbol']

# %%
matrix_12840.index.name = ''

# %%
matrix_12840.head()
# Out:
#         basolateral nucleus (basal nucleus)  \
#
# C8G                                1.870266
# C9                                 6.297873
# C9                                 2.069434
# MRPL49                             2.002642
# MRPL49                             5.460101
#
#         laterorostral part of entorhinal cortex  \
#
# C8G                                    2.500637
# C9                                     5.829589
# C9                                     2.828320
# MRPL49                                 3.366205
# MRPL49                                 6.524749
#
#         mediodorsal nucleus of thalamus  \
#
# C8G                            5.087565
# C9                             4.539848
# C9                             1.844547
# MRPL49                         4.754818
# MRPL49                         6.309441
#
#         outer CP in (rostral) midinferior temporal cortex (area 36)  \
#
# C8G                                              1.375560
# C9                                               3.944338
# C9                                               1.429880
# MRPL49                                           3.098781
# MRPL49                                           6.213752
#
#         lateral hypothalamic area, tuberal part  \
#
# C8G                                    4.130802
# C9                                     4.044747
# C9                                     2.204994
# MRPL49                                 4.431086
# MRPL49                                 6.014018
#
#         dorsomedial hypothalamic nucleus  \
#
# C8G                             4.113178
# C9                              5.925640
# C9                              1.598890
# MRPL49                          4.107063
# MRPL49                          6.083929
#
#         ventral anterior nucleus of thalamus  \
#
# C8G                                 5.524362
# C9                                  8.025330
# C9                                  1.882322
# MRPL49                              2.043070
# MRPL49                              5.731555
#
#         ventromedial hypothalamic nucleus  anteroventral nucleus of thalamus  \
#
# C8G                              1.869377                           4.435360
# C9                               4.718171                           5.240465
# C9                               2.107117                           2.319331
# MRPL49                           3.370859                           5.421633
# MRPL49                           6.351332                           7.388239
#
#         anteromedial nucleus of thalamus             ...              \
#                                                      ...
# C8G                             3.926297             ...
# C9                              6.237864             ...
# C9                              2.290332             ...
# MRPL49                          3.433157             ...
# MRPL49                          5.625046             ...
#
#         rostral division of OFCi (area 11)  \
#
# C8G                               1.730386
# C9                                4.403363
# C9                                1.699429
# MRPL49                            5.698593
# MRPL49                            7.673056
#
#         VZ in ventrolateral prefrontal cortex  \
#
# C8G                                  1.225932
# C9                                   3.741472
# C9                                   1.318732
# MRPL49                               3.935162
# MRPL49                               6.244501
#
#         outer SZ in ventrolateral prefrontal cortex  \
#
# C8G                                        1.323599
# C9                                         3.804305
# C9                                         1.361300
# MRPL49                                     2.617162
# MRPL49                                     6.025255
#
#         IZ in ventrolateral prefrontal cortex  \
#
# C8G                                  2.192735
# C9                                   4.889730
# C9                                   2.247316
# MRPL49                               3.745330
# MRPL49                               6.244710
#
#         SP in ventrolateral prefrontal cortex  \
#
# C8G                                  2.111756
# C9                                   5.679992
# C9                                   2.021892
# MRPL49                               5.028064
# MRPL49                               7.425317
#
#         outer CP in ventrolateral prefrontal cortex  \
#
# C8G                                        0.844384
# C9                                         3.350249
# C9                                         2.997790
# MRPL49                                     4.820175
# MRPL49                                     6.963295
#
#         outer CP in frontal polar cortex  inner SZ in frontal polar cortex  \
#
# C8G                             2.487709                          0.964439
# C9                              5.340184                          3.912035
# C9                              2.326233                          1.020810
# MRPL49                          2.480152                          4.254607
# MRPL49                          6.609604                          5.972166
#
#         outer SZ in frontal polar cortex  IZ in frontal polar cortex
#
# C8G                             2.047743                    2.082210
# C9                              4.673747                    4.016817
# C9                              1.950179                    1.557761
# MRPL49                          2.151463                    2.368740
# MRPL49                          5.973547                    5.634292
#
# [5 rows x 327 columns]

# %% [markdown]
# # Donor 14751

# %%
matrix_14751 = pd.read_csv('Input/lmd_matrix_14751/expression_matrix.csv', header=None, index_col=0)

# %%
matrix_14751.head()
# Out:
#               1         2         3         4         5         6         7    \
# 0
# 1058685  3.936792  5.538540  2.569126  0.818706  2.995845  1.299248  1.364092
# 1058684  4.886833  5.494820  4.554661  4.187818  5.948910  5.248337  4.994043
# 1058683  1.962837  1.943835  1.703461  1.400759  2.271671  1.637838  2.032440
# 1058682  5.353114  4.663232  4.745636  4.911940  3.124640  1.850724  3.633595
# 1058681  7.006690  6.722792  6.449630  6.751410  5.978405  5.734716  5.809233
#
#               8         9         10     ...          331       332       333  \
# 0                                        ...
# 1058685  1.023404  1.476054  2.645755    ...     1.689641  2.338675  2.888681
# 1058684  4.588768  5.100861  5.584276    ...     8.486782  8.368409  5.326986
# 1058683  1.645538  2.133584  2.213658    ...     2.089442  1.416281  2.521962
# 1058682  2.523375  3.423442  5.808649    ...     4.790280  1.601896  4.905557
# 1058681  4.639603  6.815028  7.405893    ...     6.112474  5.335519  6.818870
#
#               334       335       336       337       338       339       340
# 0
# 1058685  1.579801  2.629531  2.573593  1.892434  1.647293  1.500862  1.940358
# 1058684  4.711612  5.012399  4.914148  6.836121  5.631263  5.517357  5.450897
# 1058683  1.989237  1.464136  1.792256  2.249761  2.029263  1.917859  2.307657
# 1058682  4.152238  3.839620  0.707053  3.029755  2.347944  4.443761  4.768853
# 1058681  5.693462  5.743347  4.655115  6.522631  5.607310  6.916370  7.095840
#
# [5 rows x 340 columns]

# %%
matrix_14751.shape
# Out:
# (58692, 340)

# %% [markdown]
# # Load Sample Metadata

# %%
sample_meta_14751 = pd.read_csv('Input/lmd_matrix_14751/columns_metadata.csv')

# %%
sample_meta_14751.head()
# Out:
#    structure_id    well_id structure_acronym  \
# 0         13043  127434262               Lim
# 1         12182  127434242               PTN
# 2         12243  127434238               PTg
# 3         12198  127434234                3N
# 4         12013  127434230              cVZc
#
#                           structure_name
# 0                       limitans nucleus
# 1              pretectal nuclear complex
# 2  pedunculo(pontine) tegmental  nucleus
# 3                     oculomotor nucleus
# 4       VZ in caudal cingulate neocortex

# %%
sample_meta_14751.shape
# Out:
# (340, 4)

# %% [markdown]
# # Load Gene Metadata

# %%
gene_meta_14751 = pd.read_csv('Input/lmd_matrix_12840/rows_metadata.csv', index_col=0)

# %%
gene_meta_14751.head()
# Out:
#                       probeset_name  gene_id gene_symbol  \
# probeset_id
# 1058685                 A_23_P20713      729         C8G
# 1058684      CUST_15185_PI416261804      731          C9
# 1058683                A_32_P203917      731          C9
# 1058682                A_23_P138819      736      MRPL49
# 1058681                A_24_P232500      736      MRPL49
#
#                                              gene_name  entrez_id chromosome
# probeset_id
# 1058685      complement component 8, gamma polypeptide      733.0          9
# 1058684                         complement component 9      735.0          5
# 1058683                         complement component 9      735.0          5
# 1058682            mitochondrial ribosomal protein L49      740.0         11
# 1058681            mitochondrial ribosomal protein L49      740.0         11

# %%
gene_meta_14751.shape
# Out:
# (58692, 6)

# %% [markdown]
# # Map Sample Metadata to Sample ID

# %%
lst = []

for i,col in enumerate(matrix_14751.columns):
    col_num = i+1
    sample = str(sample_meta_14751.loc[(col_num-1), 'structure_name'])
    lst.append(sample)
    
matrix_14751.columns = lst

# %%
matrix_14751.head()
# Out:
#          limitans nucleus  pretectal nuclear complex  \
# 0
# 1058685          3.936792                   5.538540
# 1058684          4.886833                   5.494820
# 1058683          1.962837                   1.943835
# 1058682          5.353114                   4.663232
# 1058681          7.006690                   6.722792
#
#          pedunculo(pontine) tegmental  nucleus  oculomotor nucleus  \
# 0
# 1058685                               2.569126            0.818706
# 1058684                               4.554661            4.187818
# 1058683                               1.703461            1.400759
# 1058682                               4.745636            4.911940
# 1058681                               6.449630            6.751410
#
#          VZ in caudal cingulate neocortex  SZ in caudal cingulate cortex  \
# 0
# 1058685                          2.995845                       1.299248
# 1058684                          5.948910                       5.248337
# 1058683                          2.271671                       1.637838
# 1058682                          3.124640                       1.850724
# 1058681                          5.978405                       5.734716
#
#          IZ in caudal cingulate cortex  SP in caudal cingulate cortex  \
# 0
# 1058685                       1.364092                       1.023404
# 1058684                       4.994043                       4.588768
# 1058683                       2.032440                       1.645538
# 1058682                       3.633595                       2.523375
# 1058681                       5.809233                       4.639603
#
#          inner CP in caudal cingulate cortex  \
# 0
# 1058685                             1.476054
# 1058684                             5.100861
# 1058683                             2.133584
# 1058682                             3.423442
# 1058681                             6.815028
#
#          outer CP in caudal cingulate cortex  \
# 0
# 1058685                             2.645755
# 1058684                             5.584276
# 1058683                             2.213658
# 1058682                             5.808649
# 1058681                             7.405893
#
#                         ...                  \
# 0                       ...
# 1058685                 ...
# 1058684                 ...
# 1058683                 ...
# 1058682                 ...
# 1058681                 ...
#
#          MZ in posterior parahippocampal cortex  \
# 0
# 1058685                                1.689641
# 1058684                                8.486782
# 1058683                                2.089442
# 1058682                                4.790280
# 1058681                                6.112474
#
#          VZ in dorsomedial parietal cortex (area 7m)  \
# 0
# 1058685                                     2.338675
# 1058684                                     8.368409
# 1058683                                     1.416281
# 1058682                                     1.601896
# 1058681                                     5.335519
#
#          SP in posteroinferior (ventral) parietal cortex  \
# 0
# 1058685                                         2.888681
# 1058684                                         5.326986
# 1058683                                         2.521962
# 1058682                                         4.905557
# 1058681                                         6.818870
#
#          basolateral nucleus (basal nucleus)  anterior hypothalamic nucleus  \
# 0
# 1058685                             1.579801                       2.629531
# 1058684                             4.711612                       5.012399
# 1058683                             1.989237                       1.464136
# 1058682                             4.152238                       3.839620
# 1058681                             5.693462                       5.743347
#
#          IZ in granular insular cortex  \
# 0
# 1058685                       2.573593
# 1058684                       4.914148
# 1058683                       1.792256
# 1058682                       0.707053
# 1058681                       4.655115
#
#          outer CP in primary somatosensory cortex  ventral claustrum  \
# 0
# 1058685                                  1.892434           1.647293
# 1058684                                  6.836121           5.631263
# 1058683                                  2.249761           2.029263
# 1058682                                  3.029755           2.347944
# 1058681                                  6.522631           5.607310
#
#          head of caudate  inner CP in orbital frontal cortex
# 0
# 1058685         1.500862                            1.940358
# 1058684         5.517357                            5.450897
# 1058683         1.917859                            2.307657
# 1058682         4.443761                            4.768853
# 1058681         6.916370                            7.095840
#
# [5 rows x 340 columns]

# %% [markdown]
# # Map Gene to Row

# %%
matrix_14751.index = gene_meta_14751['gene_symbol']

# %%
matrix_14751.index.name = ''

# %%
matrix_14751.head()
# Out:
#         limitans nucleus  pretectal nuclear complex  \
#
# C8G             3.936792                   5.538540
# C9              4.886833                   5.494820
# C9              1.962837                   1.943835
# MRPL49          5.353114                   4.663232
# MRPL49          7.006690                   6.722792
#
#         pedunculo(pontine) tegmental  nucleus  oculomotor nucleus  \
#
# C8G                                  2.569126            0.818706
# C9                                   4.554661            4.187818
# C9                                   1.703461            1.400759
# MRPL49                               4.745636            4.911940
# MRPL49                               6.449630            6.751410
#
#         VZ in caudal cingulate neocortex  SZ in caudal cingulate cortex  \
#
# C8G                             2.995845                       1.299248
# C9                              5.948910                       5.248337
# C9                              2.271671                       1.637838
# MRPL49                          3.124640                       1.850724
# MRPL49                          5.978405                       5.734716
#
#         IZ in caudal cingulate cortex  SP in caudal cingulate cortex  \
#
# C8G                          1.364092                       1.023404
# C9                           4.994043                       4.588768
# C9                           2.032440                       1.645538
# MRPL49                       3.633595                       2.523375
# MRPL49                       5.809233                       4.639603
#
#         inner CP in caudal cingulate cortex  \
#
# C8G                                1.476054
# C9                                 5.100861
# C9                                 2.133584
# MRPL49                             3.423442
# MRPL49                             6.815028
#
#         outer CP in caudal cingulate cortex  \
#
# C8G                                2.645755
# C9                                 5.584276
# C9                                 2.213658
# MRPL49                             5.808649
# MRPL49                             7.405893
#
#                        ...                  \
#                        ...
# C8G                    ...
# C9                     ...
# C9                     ...
# MRPL49                 ...
# MRPL49                 ...
#
#         MZ in posterior parahippocampal cortex  \
#
# C8G                                   1.689641
# C9                                    8.486782
# C9                                    2.089442
# MRPL49                                4.790280
# MRPL49                                6.112474
#
#         VZ in dorsomedial parietal cortex (area 7m)  \
#
# C8G                                        2.338675
# C9                                         8.368409
# C9                                         1.416281
# MRPL49                                     1.601896
# MRPL49                                     5.335519
#
#         SP in posteroinferior (ventral) parietal cortex  \
#
# C8G                                            2.888681
# C9                                             5.326986
# C9                                             2.521962
# MRPL49                                         4.905557
# MRPL49                                         6.818870
#
#         basolateral nucleus (basal nucleus)  anterior hypothalamic nucleus  \
#
# C8G                                1.579801                       2.629531
# C9                                 4.711612                       5.012399
# C9                                 1.989237                       1.464136
# MRPL49                             4.152238                       3.839620
# MRPL49                             5.693462                       5.743347
#
#         IZ in granular insular cortex  \
#
# C8G                          2.573593
# C9                           4.914148
# C9                           1.792256
# MRPL49                       0.707053
# MRPL49                       4.655115
#
#         outer CP in primary somatosensory cortex  ventral claustrum  \
#
# C8G                                     1.892434           1.647293
# C9                                      6.836121           5.631263
# C9                                      2.249761           2.029263
# MRPL49                                  3.029755           2.347944
# MRPL49                                  6.522631           5.607310
#
#         head of caudate  inner CP in orbital frontal cortex
#
# C8G            1.500862                            1.940358
# C9             5.517357                            5.450897
# C9             1.917859                            2.307657
# MRPL49         4.443761                            4.768853
# MRPL49         6.916370                            7.095840
#
# [5 rows x 340 columns]

# %% [markdown]
# # Donor 12690

# %%
matrix_12690 = pd.read_csv('Input/lmd_matrix_12690/expression_matrix.csv', header=None, index_col=0)

# %%
matrix_12690.head()
# Out:
#               1         2         3         4         5         6         7    \
# 0
# 1058685  1.124041  0.737312  0.285204  0.866802  0.411822  0.133915  0.593739
# 1058684  6.149551  5.618342  5.004346  5.843209  5.213074  4.828702  5.413073
# 1058683  2.691075  2.285454  2.856570  2.375646  1.836139  1.514362  2.077531
# 1058682  2.491046  2.298266  1.624934  2.683198  3.653753  4.335910  3.880187
# 1058681  5.705383  5.645623  5.795283  5.349731  6.300566  6.921148  6.572005
#
#               8         9         10     ...          217       218       219  \
# 0                                        ...
# 1058685  0.937842  0.000000  0.426516    ...     5.448518  2.636804  1.622553
# 1058684  8.113476  4.508866  5.155864    ...     5.377271  5.251642  5.469682
# 1058683  2.463377  1.334104  1.745217    ...     2.050387  1.922717  2.105393
# 1058682  2.583452  3.902970  8.281534    ...     5.167290  2.474121  3.718266
# 1058681  5.511224  6.369768  6.693612    ...     6.586582  5.941576  6.502620
#
#               220       221       222       223       224       225       226
# 0
# 1058685  2.907317  0.530285  3.501358  3.214470  0.313993  1.236901  0.761081
# 1058684  4.691927  5.159224  6.393398  7.873618  4.994026  5.465123  5.381395
# 1058683  1.317941  1.804876  3.075570  3.337537  1.622141  2.091274  2.043050
# 1058682  4.877882  2.199364  5.326448  4.636038  7.400201  3.200303  3.561647
# 1058681  6.474127  5.434016  7.384552  6.228403  5.819277  6.445159  6.419519
#
# [5 rows x 226 columns]

# %%
matrix_12690.shape
# Out:
# (58692, 226)

# %% [markdown]
# # Load Sample Metadata

# %%
sample_meta_12690 = pd.read_csv('Input/lmd_matrix_12690/columns_metadata.csv')

# %%
sample_meta_12690.head()
# Out:
#    structure_id    well_id structure_acronym  \
# 0         11999  113221580             pVZpd
# 1         11936  113221578            pSZpdi
# 2         11934  113221576            pSZpdo
# 3         11825  113221574             pIZpd
# 4         11767  113221572             pSPpd
#
#                                       structure_name
# 0     VZ in posterosuperior (dorsal) parietal cortex
# 1  inner SZ in posterosuperior (dorsal) parietal ...
# 2  outer SZ in posterosuperior (dorsal) parietal ...
# 3     IZ in posterosuperior (dorsal) parietal cortex
# 4     SP in posterosuperior (dorsal) parietal cortex

# %%
sample_meta_12690.shape
# Out:
# (226, 4)

# %% [markdown]
# # Load Gene Metadata

# %%
gene_meta_12690 = pd.read_csv('Input/lmd_matrix_12690/rows_metadata.csv', index_col=0)

# %%
gene_meta_12690.head()
# Out:
#                       probeset_name  gene_id gene_symbol  \
# probeset_id
# 1058685                 A_23_P20713      729         C8G
# 1058684      CUST_15185_PI416261804      731          C9
# 1058683                A_32_P203917      731          C9
# 1058682                A_23_P138819      736      MRPL49
# 1058681                A_24_P232500      736      MRPL49
#
#                                              gene_name  entrez_id chromosome
# probeset_id
# 1058685      complement component 8, gamma polypeptide      733.0          9
# 1058684                         complement component 9      735.0          5
# 1058683                         complement component 9      735.0          5
# 1058682            mitochondrial ribosomal protein L49      740.0         11
# 1058681            mitochondrial ribosomal protein L49      740.0         11

# %%
gene_meta_12690.shape
# Out:
# (58692, 6)

# %% [markdown]
# # Map Sample Metadata to Sample ID

# %%
lst = []

for i,col in enumerate(matrix_12690.columns):
    col_num = i+1
    sample = str(sample_meta_12690.loc[(col_num-1), 'structure_name'])
    lst.append(sample)
    
matrix_12690.columns = lst

# %%
matrix_12690.head()
# Out:
#          VZ in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                        1.124041
# 1058684                                        6.149551
# 1058683                                        2.691075
# 1058682                                        2.491046
# 1058681                                        5.705383
#
#          inner SZ in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                           0.737312
# 1058684                                           5.618342
# 1058683                                           2.285454
# 1058682                                           2.298266
# 1058681                                           5.645623
#
#          outer SZ in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                           0.285204
# 1058684                                           5.004346
# 1058683                                           2.856570
# 1058682                                           1.624934
# 1058681                                           5.795283
#
#          IZ in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                        0.866802
# 1058684                                        5.843209
# 1058683                                        2.375646
# 1058682                                        2.683198
# 1058681                                        5.349731
#
#          SP in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                        0.411822
# 1058684                                        5.213074
# 1058683                                        1.836139
# 1058682                                        3.653753
# 1058681                                        6.300566
#
#          inner CP in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                           0.133915
# 1058684                                           4.828702
# 1058683                                           1.514362
# 1058682                                           4.335910
# 1058681                                           6.921148
#
#          outer CP in posterosuperior (dorsal) parietal cortex  \
# 0
# 1058685                                           0.593739
# 1058684                                           5.413073
# 1058683                                           2.077531
# 1058682                                           3.880187
# 1058681                                           6.572005
#
#          MZ in posterodorsal (superior) parietal cortex  \
# 0
# 1058685                                        0.937842
# 1058684                                        8.113476
# 1058683                                        2.463377
# 1058682                                        2.583452
# 1058681                                        5.511224
#
#          VZ in midlateral extrastriate cortex (area 19)  \
# 0
# 1058685                                        0.000000
# 1058684                                        4.508866
# 1058683                                        1.334104
# 1058682                                        3.902970
# 1058681                                        6.369768
#
#          inner SZ in midlateral extrastriate cortex  \
# 0
# 1058685                                    0.426516
# 1058684                                    5.155864
# 1058683                                    1.745217
# 1058682                                    8.281534
# 1058681                                    6.693612
#
#                     ...              external segment of globus pallidus  \
# 0                   ...
# 1058685             ...                                         5.448518
# 1058684             ...                                         5.377271
# 1058683             ...                                         2.050387
# 1058682             ...                                         5.167290
# 1058681             ...                                         6.586582
#
#          inner CP in rostral perirhinal cortex  \
# 0
# 1058685                               2.636804
# 1058684                               5.251642
# 1058683                               1.922717
# 1058682                               2.474121
# 1058681                               5.941576
#
#          outer CP in rostral perirhinal cortex  \
# 0
# 1058685                               1.622553
# 1058684                               5.469682
# 1058683                               2.105393
# 1058682                               3.718266
# 1058681                               6.502620
#
#          lateral hypothalamic area, anterior part  \
# 0
# 1058685                                  2.907317
# 1058684                                  4.691927
# 1058683                                  1.317941
# 1058682                                  4.877882
# 1058681                                  6.474127
#
#          SP in temporal polar cortex  inner CP in temporal polar cortex  \
# 0
# 1058685                     0.530285                           3.501358
# 1058684                     5.159224                           6.393398
# 1058683                     1.804876                           3.075570
# 1058682                     2.199364                           5.326448
# 1058681                     5.434016                           7.384552
#
#          IZ in dysgranular insular cortex  inner SZ in orbital frontal cortex  \
# 0
# 1058685                          3.214470                            0.313993
# 1058684                          7.873618                            4.994026
# 1058683                          3.337537                            1.622141
# 1058682                          4.636038                            7.400201
# 1058681                          6.228403                            5.819277
#
#          inner SZ in frontal polar cortex  MZ in frontal polar cortex
# 0
# 1058685                          1.236901                    0.761081
# 1058684                          5.465123                    5.381395
# 1058683                          2.091274                    2.043050
# 1058682                          3.200303                    3.561647
# 1058681                          6.445159                    6.419519
#
# [5 rows x 226 columns]

# %% [markdown]
# # Map Gene to Row

# %%
matrix_12690.index = gene_meta_12690['gene_symbol']

# %%
matrix_12690.index.name = ''

# %%
matrix_12690.head()
# Out:
#         VZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                           1.124041
# C9                                            6.149551
# C9                                            2.691075
# MRPL49                                        2.491046
# MRPL49                                        5.705383
#
#         inner SZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.737312
# C9                                               5.618342
# C9                                               2.285454
# MRPL49                                           2.298266
# MRPL49                                           5.645623
#
#         outer SZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.285204
# C9                                               5.004346
# C9                                               2.856570
# MRPL49                                           1.624934
# MRPL49                                           5.795283
#
#         IZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                           0.866802
# C9                                            5.843209
# C9                                            2.375646
# MRPL49                                        2.683198
# MRPL49                                        5.349731
#
#         SP in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                           0.411822
# C9                                            5.213074
# C9                                            1.836139
# MRPL49                                        3.653753
# MRPL49                                        6.300566
#
#         inner CP in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.133915
# C9                                               4.828702
# C9                                               1.514362
# MRPL49                                           4.335910
# MRPL49                                           6.921148
#
#         outer CP in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.593739
# C9                                               5.413073
# C9                                               2.077531
# MRPL49                                           3.880187
# MRPL49                                           6.572005
#
#         MZ in posterodorsal (superior) parietal cortex  \
#
# C8G                                           0.937842
# C9                                            8.113476
# C9                                            2.463377
# MRPL49                                        2.583452
# MRPL49                                        5.511224
#
#         VZ in midlateral extrastriate cortex (area 19)  \
#
# C8G                                           0.000000
# C9                                            4.508866
# C9                                            1.334104
# MRPL49                                        3.902970
# MRPL49                                        6.369768
#
#         inner SZ in midlateral extrastriate cortex  \
#
# C8G                                       0.426516
# C9                                        5.155864
# C9                                        1.745217
# MRPL49                                    8.281534
# MRPL49                                    6.693612
#
#                    ...              external segment of globus pallidus  \
#                    ...
# C8G                ...                                         5.448518
# C9                 ...                                         5.377271
# C9                 ...                                         2.050387
# MRPL49             ...                                         5.167290
# MRPL49             ...                                         6.586582
#
#         inner CP in rostral perirhinal cortex  \
#
# C8G                                  2.636804
# C9                                   5.251642
# C9                                   1.922717
# MRPL49                               2.474121
# MRPL49                               5.941576
#
#         outer CP in rostral perirhinal cortex  \
#
# C8G                                  1.622553
# C9                                   5.469682
# C9                                   2.105393
# MRPL49                               3.718266
# MRPL49                               6.502620
#
#         lateral hypothalamic area, anterior part  SP in temporal polar cortex  \
#
# C8G                                     2.907317                     0.530285
# C9                                      4.691927                     5.159224
# C9                                      1.317941                     1.804876
# MRPL49                                  4.877882                     2.199364
# MRPL49                                  6.474127                     5.434016
#
#         inner CP in temporal polar cortex  IZ in dysgranular insular cortex  \
#
# C8G                              3.501358                          3.214470
# C9                               6.393398                          7.873618
# C9                               3.075570                          3.337537
# MRPL49                           5.326448                          4.636038
# MRPL49                           7.384552                          6.228403
#
#         inner SZ in orbital frontal cortex  inner SZ in frontal polar cortex  \
#
# C8G                               0.313993                          1.236901
# C9                                4.994026                          5.465123
# C9                                1.622141                          2.091274
# MRPL49                            7.400201                          3.200303
# MRPL49                            5.819277                          6.445159
#
#         MZ in frontal polar cortex
#
# C8G                       0.761081
# C9                        5.381395
# C9                        2.043050
# MRPL49                    3.561647
# MRPL49                    6.419519
#
# [5 rows x 226 columns]

# %% [markdown]
# # Combine Datasets

# %%
matrix = pd.concat([matrix_12690, matrix_14751, matrix_12840, matrix_12566], axis=1)

# %% [markdown]
# # Save Unfiltered Matrix to File

# %%
filename = path+'aba_pre_mic_tissue_matrix_unfilltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Filtered

# %%
normalized_matrix = matrix.copy()

# %%
normalized_matrix.head()
# Out:
#         VZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                           1.124041
# C9                                            6.149551
# C9                                            2.691075
# MRPL49                                        2.491046
# MRPL49                                        5.705383
#
#         inner SZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.737312
# C9                                               5.618342
# C9                                               2.285454
# MRPL49                                           2.298266
# MRPL49                                           5.645623
#
#         outer SZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.285204
# C9                                               5.004346
# C9                                               2.856570
# MRPL49                                           1.624934
# MRPL49                                           5.795283
#
#         IZ in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                           0.866802
# C9                                            5.843209
# C9                                            2.375646
# MRPL49                                        2.683198
# MRPL49                                        5.349731
#
#         SP in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                           0.411822
# C9                                            5.213074
# C9                                            1.836139
# MRPL49                                        3.653753
# MRPL49                                        6.300566
#
#         inner CP in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.133915
# C9                                               4.828702
# C9                                               1.514362
# MRPL49                                           4.335910
# MRPL49                                           6.921148
#
#         outer CP in posterosuperior (dorsal) parietal cortex  \
#
# C8G                                              0.593739
# C9                                               5.413073
# C9                                               2.077531
# MRPL49                                           3.880187
# MRPL49                                           6.572005
#
#         MZ in posterodorsal (superior) parietal cortex  \
#
# C8G                                           0.937842
# C9                                            8.113476
# C9                                            2.463377
# MRPL49                                        2.583452
# MRPL49                                        5.511224
#
#         VZ in midlateral extrastriate cortex (area 19)  \
#
# C8G                                           0.000000
# C9                                            4.508866
# C9                                            1.334104
# MRPL49                                        3.902970
# MRPL49                                        6.369768
#
#         inner SZ in midlateral extrastriate cortex  \
#
# C8G                                       0.426516
# C9                                        5.155864
# C9                                        1.745217
# MRPL49                                    8.281534
# MRPL49                                    6.693612
#
#                        ...                  inner CP in frontal polar cortex  \
#                        ...
# C8G                    ...                                          0.864253
# C9                     ...                                          5.083837
# C9                     ...                                          2.442397
# MRPL49                 ...                                          4.024892
# MRPL49                 ...                                          6.964731
#
#         MZ in frontal polar cortex  oculomotor nucleus  \
#
# C8G                       0.661506            2.875280
# C9                        4.897488            7.306555
# C9                        3.147917            4.198493
# MRPL49                    4.700923            4.688663
# MRPL49                    6.843392            6.299629
#
#         medial habenular nucleus  parafascicular nucleus of thalamus  \
#
# C8G                     1.044508                            4.752277
# C9                      5.339243                            5.550479
# C9                      1.814388                            2.000036
# MRPL49                  3.613006                            4.641472
# MRPL49                  6.502205                            6.222799
#
#         SG in rostral entorhinal cortex  SP in perirhinal cortex  \
#
# C8G                            2.094123                 4.003514
# C9                             6.138744                 5.690613
# C9                             7.231437                 2.113372
# MRPL49                         2.742722                 3.026607
# MRPL49                         5.692533                 6.331764
#
#         inner CP in rostral perirhinal cortex  \
#
# C8G                                  1.300852
# C9                                   5.651417
# C9                                   2.059020
# MRPL49                               3.778842
# MRPL49                               6.401711
#
#         IZ in primary somatosensory cortex  MZ in primary somatosensory cortex
#
# C8G                               1.027525                            1.366720
# C9                                5.291752                            5.103054
# C9                                1.823958                            1.671450
# MRPL49                            3.672038                            3.395014
# MRPL49                            5.889965                            5.895140
#
# [5 rows x 1203 columns]

# %%
normalized_matrix.shape
# Out:
# (58692, 1203)

# %% [markdown]
# # Remove any data with more than 95% missing and imput remaining mssing values to matrix mean

# %%
normalized_matrix = uf.removeAndImpute(normalized_matrix)

# %%
normalized_matrix.shape
# Out:
# (58692, 1203)

# %% [markdown]
# # Log2 Transform

# %%
normalized_matrix = uf.log2(normalized_matrix)

# %%
normalized_matrix.head()
# Out:
#         VZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                           1.086812
# C9                                            2.837853
# C9                                            1.884041
# MRPL49                                        1.803659
# MRPL49                                        2.745320
#
#         inner SZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.796857
# C9                                               2.726470
# C9                                               1.716093
# MRPL49                                           1.721708
# MRPL49                                           2.732404
#
#         outer SZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.361997
# C9                                               2.586007
# C9                                               1.947318
# MRPL49                                           1.392281
# MRPL49                                           2.764534
#
#         IZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                           0.900569
# C9                                            2.774673
# C9                                            1.755164
# MRPL49                                        1.880959
# MRPL49                                        2.666696
#
#         SP in posterosuperior (dorsal) parietal cortex  \
# C8G                                           0.497559
# C9                                            2.635307
# C9                                            1.503928
# MRPL49                                        2.218395
# MRPL49                                        2.868008
#
#         inner CP in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.181312
# C9                                               2.543175
# C9                                               1.330192
# MRPL49                                           2.415734
# MRPL49                                           2.985710
#
#         outer CP in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.672416
# C9                                               2.681016
# C9                                               1.621773
# MRPL49                                           2.286937
# MRPL49                                           2.920675
#
#         MZ in posterodorsal (superior) parietal cortex  \
# C8G                                           0.954451
# C9                                            3.188001
# C9                                            1.792179
# MRPL49                                        1.841350
# MRPL49                                        2.702929
#
#         VZ in midlateral extrastriate cortex (area 19)  \
# C8G                                           1.689507
# C9                                            2.461755
# C9                                            1.222869
# MRPL49                                        2.293656
# MRPL49                                        2.881619
#
#         inner SZ in midlateral extrastriate cortex  \
# C8G                                       0.512496
# C9                                        2.621961
# C9                                        1.456920
# MRPL49                                    3.214363
# MRPL49                                    2.943661
#
#                        ...                  inner CP in frontal polar cortex  \
# C8G                    ...                                          0.898598
# C9                     ...                                          2.604981
# C9                     ...                                          1.783413
# MRPL49                 ...                                          2.329093
# MRPL49                 ...                                          2.993626
#
#         MZ in frontal polar cortex  oculomotor nucleus  \
# C8G                       0.732491            1.954300
# C9                        2.560101            3.054250
# C9                        2.052387            2.378093
# MRPL49                    2.511196            2.508089
# MRPL49                    2.971478            2.867823
#
#         medial habenular nucleus  parafascicular nucleus of thalamus  \
# C8G                     1.031754                            2.524133
# C9                      2.664311                            2.711600
# C9                      1.492821                            1.584980
# MRPL49                  2.205707                            2.496072
# MRPL49                  2.907315                            2.852558
#
#         SG in rostral entorhinal cortex  SP in perirhinal cortex  \
# C8G                            1.629530                 2.322942
# C9                             2.835670                 2.742138
# C9                             3.041144                 1.638478
# MRPL49                         1.904088                 2.009565
# MRPL49                         2.742552                 2.874160
#
#         inner CP in rostral perirhinal cortex  \
# C8G                                  1.202168
# C9                                   2.733662
# C9                                   1.613070
# MRPL49                               2.256661
# MRPL49                               2.887859
#
#         IZ in primary somatosensory cortex  MZ in primary somatosensory cortex
# C8G                               1.019719                            1.242889
# C9                                2.653462                            2.609531
# C9                                1.497719                            1.417623
# MRPL49                            2.224052                            2.135868
# MRPL49                            2.784497                            2.785580
#
# [5 rows x 1203 columns]

# %% [markdown]
# # Normalize Matrix (Quantile Normalize the matrix for the columns)

# %%
normalized_matrix = uf.quantileNormalize(normalized_matrix)
# Out:
# Step 2/2 progress: 100%  1203 Out of 1203

# %%
normalized_matrix.head()
# Out:
#         VZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                           0.983340
# C9                                            2.807242
# C9                                            1.694814
# MRPL49                                        1.554262
# MRPL49                                        2.712905
#
#         inner SZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.946593
# C9                                               2.712811
# C9                                               1.684594
# MRPL49                                           1.693608
# MRPL49                                           2.718379
#
#         outer SZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.726804
# C9                                               2.584007
# C9                                               1.989728
# MRPL49                                           1.543340
# MRPL49                                           2.756183
#
#         IZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                           0.845793
# C9                                            2.742087
# C9                                            1.638292
# MRPL49                                        1.819256
# MRPL49                                        2.631085
#
#         SP in posterosuperior (dorsal) parietal cortex  \
# C8G                                           0.756051
# C9                                            2.641440
# C9                                            1.589474
# MRPL49                                        2.244848
# MRPL49                                        2.868258
#
#         inner CP in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.645515
# C9                                               2.595746
# C9                                               1.584861
# MRPL49                                           2.489141
# MRPL49                                           2.991391
#
#         outer CP in posterosuperior (dorsal) parietal cortex  \
# C8G                                              0.844574
# C9                                               2.694829
# C9                                               1.614099
# MRPL49                                           2.300303
# MRPL49                                           2.925415
#
#         MZ in posterodorsal (superior) parietal cortex  \
# C8G                                           0.915217
# C9                                            3.179343
# C9                                            1.700590
# MRPL49                                        1.790162
# MRPL49                                        2.697372
#
#         VZ in midlateral extrastriate cortex (area 19)  \
# C8G                                           1.778759
# C9                                            2.454802
# C9                                            1.560843
# MRPL49                                        2.290517
# MRPL49                                        2.864809
#
#         inner SZ in midlateral extrastriate cortex  \
# C8G                                       0.803821
# C9                                        2.584951
# C9                                        1.534102
# MRPL49                                    3.198302
# MRPL49                                    2.924076
#
#                        ...                  inner CP in frontal polar cortex  \
# C8G                    ...                                          1.178227
# C9                     ...                                          2.623249
# C9                     ...                                          1.840961
# MRPL49                 ...                                          2.353943
# MRPL49                 ...                                          2.995995
#
#         MZ in frontal polar cortex  oculomotor nucleus  \
# C8G                       0.981332            1.742197
# C9                        2.580449            3.032068
# C9                        2.058773            2.236039
# MRPL49                    2.530300            2.403873
# MRPL49                    2.971528            2.828019
#
#         medial habenular nucleus  parafascicular nucleus of thalamus  \
# C8G                     1.101311                            2.430551
# C9                      2.615444                            2.651565
# C9                      1.485094                            1.464661
# MRPL49                  2.087377                            2.398119
# MRPL49                  2.875026                            2.813864
#
#         SG in rostral entorhinal cortex  SP in perirhinal cortex  \
# C8G                            1.548692                 2.266374
# C9                             2.803895                 2.713929
# C9                             3.021373                 1.486104
# MRPL49                         1.802554                 1.926590
# MRPL49                         2.700687                 2.854576
#
#         inner CP in rostral perirhinal cortex  \
# C8G                                  1.187731
# C9                                   2.719301
# C9                                   1.478216
# MRPL49                               2.210667
# MRPL49                               2.877708
#
#         IZ in primary somatosensory cortex  MZ in primary somatosensory cortex
# C8G                               1.161451                            1.337087
# C9                                2.615953                            2.622383
# C9                                1.518930                            1.514963
# MRPL49                            2.176373                            2.131307
# MRPL49                            2.749313                            2.794341
#
# [5 rows x 1203 columns]

# %% [markdown]
# # Normalize Matrix (z-score the rows)

# %%
uf.zscore(normalized_matrix, 'row')
# Out:
# Progress: 100%  58692 Out of 58692

# %%
normalized_matrix.head()
# Out:
#         VZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                          -1.401209
# C9                                            1.080546
# C9                                            1.492641
# MRPL49                                       -1.879449
# MRPL49                                       -1.102616
#
#         inner SZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                             -1.504728
# C9                                               0.399890
# C9                                               1.369626
# MRPL49                                          -1.490196
# MRPL49                                          -1.061028
#
#         outer SZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                             -2.123882
# C9                                              -0.528524
# C9                                               5.042607
# MRPL49                                          -1.909959
# MRPL49                                          -0.773787
#
#         IZ in posterosuperior (dorsal) parietal cortex  \
# C8G                                          -1.788685
# C9                                            0.610907
# C9                                            0.812271
# MRPL49                                       -1.139209
# MRPL49                                       -1.724290
#
#         SP in posterosuperior (dorsal) parietal cortex  \
# C8G                                          -2.041490
# C9                                           -0.114548
# C9                                            0.224640
# MRPL49                                        0.049652
# MRPL49                                        0.077759
#
#         inner CP in posterosuperior (dorsal) parietal cortex  \
# C8G                                             -2.352875
# C9                                              -0.443911
# C9                                               0.169113
# MRPL49                                           0.732064
# MRPL49                                           1.013333
#
#         outer CP in posterosuperior (dorsal) parietal cortex  \
# C8G                                             -1.792119
# C9                                               0.270274
# C9                                               0.521059
# MRPL49                                           0.204560
# MRPL49                                           0.512045
#
#         MZ in posterodorsal (superior) parietal cortex  \
# C8G                                          -1.593113
# C9                                            3.762634
# C9                                            1.562176
# MRPL49                                       -1.220482
# MRPL49                                       -1.220639
#
#         VZ in midlateral extrastriate cortex (area 19)  \
# C8G                                           0.839517
# C9                                           -1.459831
# C9                                           -0.119995
# MRPL49                                        0.177225
# MRPL49                                        0.051554
#
#         inner SZ in midlateral extrastriate cortex  \
# C8G                                      -1.906922
# C9                                       -0.521720
# C9                                       -0.441894
# MRPL49                                    2.713053
# MRPL49                                    0.501874
#
#                        ...                  inner CP in frontal polar cortex  \
# C8G                    ...                                         -0.852206
# C9                     ...                                         -0.245671
# C9                     ...                                          3.251857
# MRPL49                 ...                                          0.354400
# MRPL49                 ...                                          1.048312
#
#         MZ in frontal polar cortex  oculomotor nucleus  \
# C8G                      -1.406867            0.736520
# C9                       -0.554169            2.701084
# C9                        5.873718            8.007521
# MRPL49                    0.847041            0.493877
# MRPL49                    0.862414           -0.227972
#
#         medial habenular nucleus  parafascicular nucleus of thalamus  \
# C8G                    -1.068881                            2.675638
# C9                     -0.301930                           -0.041572
# C9                     -1.031807                           -1.277774
# MRPL49                 -0.390231                            0.477802
# MRPL49                  0.129189                           -0.335522
#
#         SG in rostral entorhinal cortex  SP in perirhinal cortex  \
# C8G                            0.191408                 2.213147
# C9                             1.056416                 0.407947
# C9                            17.460796                -1.019651
# MRPL49                        -1.185863                -0.839380
# MRPL49                        -1.195453                -0.026194
#
#         inner CP in rostral perirhinal cortex  \
# C8G                                 -0.825432
# C9                                   0.446672
# C9                                  -1.114608
# MRPL49                              -0.045830
# MRPL49                               0.149563
#
#         IZ in primary somatosensory cortex  MZ in primary somatosensory cortex
# C8G                              -0.899463                           -0.404690
# C9                               -0.298261                           -0.251916
# C9                               -0.624520                           -0.672265
# MRPL49                           -0.141628                           -0.267517
# MRPL49                           -0.825984                           -0.483866
#
# [5 rows x 1203 columns]

# %% [markdown]
# # Merge Like Column (by taking the mean)

# %%
normalized_matrix = uf.merge(normalized_matrix, 'column', 'mean')

# %%
normalized_matrix.shape
# Out:
# (58692, 516)

# %% [markdown]
# # Map Gene Symbols To Up-to-date Approved Gene Symbols

# %%
uf.mapgenesymbols(normalized_matrix)
# Out:
# Progeres: 100%  58692 Out of 58692

# %%
normalized_matrix.shape
# Out:
# (45723, 516)

# %% [markdown]
# # Merge Duplicate Genes By Rows

# %%
normalized_matrix = uf.merge(normalized_matrix, 'row', 'mean')

# %%
normalized_matrix.shape
# Out:
# (19281, 516)

# %% [markdown]
# # Histogram of First Sample

# %%
normalized_matrix[normalized_matrix.columns[0]].hist(bins=100)

# %% [markdown]
# # Histogram of First Gene

# %%
normalized_matrix.loc[normalized_matrix.index[0]].hist(bins=50)

# %% [markdown]
# # Save Filtered Matrix

# %%
filename = path+'aba_pre_mic_tissue_matrix_filltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
normalized_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene List

# %%
gene_list = uf.createGeneList(normalized_matrix)
# Out:
# Progeres: 100%  19281 Out of 19281

# %%
gene_list.head()
# Out:
#    GeneSym  GeneID
# 0     A1BG       1
# 1     A1CF   29974
# 2      A2M       2
# 3    A2ML1  144568
# 4  A3GALT2  127550

# %%
gene_list.shape
# Out:
# (19281, 2)

# %% [markdown]
# # Save Gene List

# %%
filename = path+'aba_pre_mic_tissue_gene_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_list.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Attribute List

# %%
attribute_list = uf.createAttributeList(normalized_matrix)

# %%
attribute_list.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [CP in caudal hippocampus, CP in caudal subicular cortex, CP in midlateral temporal cortex, CP in retrosplenial cortex, CP in rostral hippocampus]

# %%
attribute_list.shape
# Out:
# (516, 0)

# %% [markdown]
# # Save Attribute List

# %%
filename = path+'aba_pre_mic_tissue_attribute_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_list.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create matrix of Standardized values (values between -1, and 1)

# %%
standard_matrix = uf.createStandardizedMatrix(normalized_matrix)
# Out:
# Progeres: 100%  19281 Out of 19281

# %%
standard_matrix.head()
# Out:
#          CP in caudal hippocampus  CP in caudal subicular cortex  \
#
# A1BG                     0.122269                      -0.083156
# A1CF                     0.564130                       0.502117
# A2M                     -0.726564                      -0.114164
# A2ML1                   -0.056024                       0.924596
# A3GALT2                  0.130101                      -0.815631
#
#          CP in midlateral temporal cortex  CP in retrosplenial cortex  \
#
# A1BG                             0.777311                    0.765683
# A1CF                            -0.257573                   -0.125793
# A2M                             -0.649047                   -0.451371
# A2ML1                           -0.273077                   -0.141296
# A3GALT2                         -0.997800                    0.738631
#
#          CP in rostral hippocampus  CP in temporal polar cortex  \
#
# A1BG                      0.940100                     0.843201
# A1CF                      0.761808                     0.773434
# A2M                      -0.838968                    -0.699433
# A2ML1                     0.831574                    -0.695557
# A3GALT2                   0.261887                    -0.920282
#
#          Dorsal claustrum  \
#
# A1BG            -0.071526
# A1CF            -0.544397
# A2M             -0.234317
# A2ML1           -0.734316
# A3GALT2         -0.044314
#
#          Edinger-Westphal nucleus (accessory oculomotor nucleus)  \
#
# A1BG                                             -0.827339
# A1CF                                             -0.474626
# A2M                                              -0.156801
# A2ML1                                            -0.583154
# A3GALT2                                          -0.121835
#
#          IZ in caudal cingulate cortex  \
#
# A1BG                         -0.056024
# A1CF                         -0.121916
# A2M                           0.893590
# A2ML1                        -0.087031
# A3GALT2                       0.637855
#
#          IZ in caudal midinferior temporal cortex (area TF)      ...       \
#                                                                  ...
# A1BG                                             -0.435867       ...
# A1CF                                              0.881962       ...
# A2M                                               0.486613       ...
# A2ML1                                             0.940100       ...
# A3GALT2                                           0.839406       ...
#
#          ventral lateral nucleus of thalamus  \
#
# A1BG                               -0.815712
# A1CF                               -0.776952
# A2M                                -0.614161
# A2ML1                              -0.428114
# A3GALT2                            -0.005555
#
#          ventral medial nucleus of thalamus  \
#
# A1BG                              -0.354473
# A1CF                              -0.804085
# A2M                                0.099015
# A2ML1                             -0.730440
# A3GALT2                            0.529328
#
#          ventral posterior inferior nucleus  \
#
# A1BG                              -0.931990
# A1CF                              -0.149049
# A2M                               -0.369978
# A2ML1                             -0.788580
# A3GALT2                           -0.908654
#
#          ventral posterior lateral nucleus  ventral posterior medial nucleus  \
#
# A1BG                             -0.691681                         -0.013387
# A1CF                              0.203666                         -0.044395
# A2M                              -0.121916                         -0.695557
# A2ML1                             0.943977                          0.529245
# A3GALT2                           0.230879                          0.114599
#
#          ventral tegmental area  ventricular (matrix) zone of cerebellum  \
#
# A1BG                  -0.021138                                 0.106765
# A1CF                  -0.435867                                 0.568007
# A2M                    0.075759                                -0.385481
# A2ML1                 -0.025014                                -0.110290
# A3GALT2               -0.493926                                -0.284624
#
#          ventricular (matrix) zone of pons  ventromedial hypothalamic nucleus  \
#
# A1BG                              0.347078                          -0.183931
# A1CF                             -0.540519                          -0.187806
# A2M                               0.537001                          -0.207186
# A2ML1                             0.998242                          -0.032767
# A3GALT2                           0.052585                          -0.641214
#
#          zona incerta
#
# A1BG        -0.466875
# A1CF        -0.846720
# A2M          0.785063
# A2ML1       -0.633543
# A3GALT2     -0.086950
#
# [5 rows x 516 columns]

# %% [markdown]
# # Plot of A Single Celltype, Normalized Value vs. Standardized Value

# %%
plt.plot(normalized_matrix[normalized_matrix.columns[0]], standard_matrix[standard_matrix.columns[0]], 'bo')
plt.xlabel('Normalized Values')
plt.ylabel('Standardized Values')
plt.title(standard_matrix.columns[0])
plt.grid(True)

# %% [markdown]
# # Save Standardized Matrix

# %%
filename = path+'aba_pre_mic_tissue_standard_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
standard_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Tertiary Matrix

# %%
tertiary_matrix = uf.createTertiaryMatrix(standard_matrix)

# %%
tertiary_matrix.head()
# Out:
#          CP in caudal hippocampus  CP in caudal subicular cortex  \
#
# A1BG                            0                              0
# A1CF                            0                              0
# A2M                             0                              0
# A2ML1                           0                              0
# A3GALT2                         0                              0
#
#          CP in midlateral temporal cortex  CP in retrosplenial cortex  \
#
# A1BG                                    0                           0
# A1CF                                    0                           0
# A2M                                     0                           0
# A2ML1                                   0                           0
# A3GALT2                                -1                           0
#
#          CP in rostral hippocampus  CP in temporal polar cortex  \
#
# A1BG                             0                            0
# A1CF                             0                            0
# A2M                              0                            0
# A2ML1                            0                            0
# A3GALT2                          0                            0
#
#          Dorsal claustrum  \
#
# A1BG                    0
# A1CF                    0
# A2M                     0
# A2ML1                   0
# A3GALT2                 0
#
#          Edinger-Westphal nucleus (accessory oculomotor nucleus)  \
#
# A1BG                                                     0
# A1CF                                                     0
# A2M                                                      0
# A2ML1                                                    0
# A3GALT2                                                  0
#
#          IZ in caudal cingulate cortex  \
#
# A1BG                                 0
# A1CF                                 0
# A2M                                  0
# A2ML1                                0
# A3GALT2                              0
#
#          IZ in caudal midinferior temporal cortex (area TF)      ...       \
#                                                                  ...
# A1BG                                                     0       ...
# A1CF                                                     0       ...
# A2M                                                      0       ...
# A2ML1                                                    0       ...
# A3GALT2                                                  0       ...
#
#          ventral lateral nucleus of thalamus  \
#
# A1BG                                       0
# A1CF                                       0
# A2M                                        0
# A2ML1                                      0
# A3GALT2                                    0
#
#          ventral medial nucleus of thalamus  \
#
# A1BG                                      0
# A1CF                                      0
# A2M                                       0
# A2ML1                                     0
# A3GALT2                                   0
#
#          ventral posterior inferior nucleus  \
#
# A1BG                                      0
# A1CF                                      0
# A2M                                       0
# A2ML1                                     0
# A3GALT2                                   0
#
#          ventral posterior lateral nucleus  ventral posterior medial nucleus  \
#
# A1BG                                     0                                 0
# A1CF                                     0                                 0
# A2M                                      0                                 0
# A2ML1                                    0                                 0
# A3GALT2                                  0                                 0
#
#          ventral tegmental area  ventricular (matrix) zone of cerebellum  \
#
# A1BG                          0                                        0
# A1CF                          0                                        0
# A2M                           0                                        0
# A2ML1                         0                                        0
# A3GALT2                       0                                        0
#
#          ventricular (matrix) zone of pons  ventromedial hypothalamic nucleus  \
#
# A1BG                                     0                                  0
# A1CF                                     0                                  0
# A2M                                      0                                  0
# A2ML1                                    1                                  0
# A3GALT2                                  0                                  0
#
#          zona incerta
#
# A1BG                0
# A1CF                0
# A2M                 0
# A2ML1               0
# A3GALT2             0
#
# [5 rows x 516 columns]

# %% [markdown]
# # Save Teriary Matrix

# %%
filename = path+'aba_pre_mic_tissue_tertiary_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
tertiary_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Up Gene Set Library

# %%
name = 'aba_pre_mic_tissue_gene_up_set'

# %%
uf.createUpGeneSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  516 Out of 516

# %% [markdown]
# # Create Down Gene Set Library

# %%
name = 'aba_pre_mic_tissue_gene_down_set'

# %%
uf.createDownGeneSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  516 Out of 516

# %% [markdown]
# # Create Up Attribute Library

# %%
name = 'aba_pre_mic_tissue_attribute_up_set'

# %%
uf.createUpAttributeSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  19281 Out of 19281

# %% [markdown]
# # Create Down Attribute Library

# %%
name = 'aba_pre_mic_tissue_attribute_down_set'

# %%
uf.createDownAttributeSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  19281 Out of 19281

# %% [markdown]
# # Create Attribute Similarity Matrix

# %%
attribute_similarity_matix = uf.createSimilarityMatrix(normalized_matrix.T, 'cosine')

# %%
attribute_similarity_matix.head()
# Out:
#                                   CP in caudal hippocampus  \
#
# CP in caudal hippocampus                          1.000000
# CP in caudal subicular cortex                     0.201347
# CP in midlateral temporal cortex                  0.018802
# CP in retrosplenial cortex                        0.242674
# CP in rostral hippocampus                         0.328712
#
#                                   CP in caudal subicular cortex  \
#
# CP in caudal hippocampus                               0.201347
# CP in caudal subicular cortex                          1.000000
# CP in midlateral temporal cortex                       0.209252
# CP in retrosplenial cortex                             0.114643
# CP in rostral hippocampus                              0.273256
#
#                                   CP in midlateral temporal cortex  \
#
# CP in caudal hippocampus                                  0.018802
# CP in caudal subicular cortex                             0.209252
# CP in midlateral temporal cortex                          1.000000
# CP in retrosplenial cortex                                0.062815
# CP in rostral hippocampus                                 0.167688
#
#                                   CP in retrosplenial cortex  \
#
# CP in caudal hippocampus                            0.242674
# CP in caudal subicular cortex                       0.114643
# CP in midlateral temporal cortex                    0.062815
# CP in retrosplenial cortex                          1.000000
# CP in rostral hippocampus                           0.243938
#
#                                   CP in rostral hippocampus  \
#
# CP in caudal hippocampus                           0.328712
# CP in caudal subicular cortex                      0.273256
# CP in midlateral temporal cortex                   0.167688
# CP in retrosplenial cortex                         0.243938
# CP in rostral hippocampus                          1.000000
#
#                                   CP in temporal polar cortex  \
#
# CP in caudal hippocampus                             0.065923
# CP in caudal subicular cortex                        0.041089
# CP in midlateral temporal cortex                     0.025203
# CP in retrosplenial cortex                           0.097190
# CP in rostral hippocampus                            0.170154
#
#                                   Dorsal claustrum  \
#
# CP in caudal hippocampus                  0.212701
# CP in caudal subicular cortex            -0.013135
# CP in midlateral temporal cortex          0.078252
# CP in retrosplenial cortex                0.267215
# CP in rostral hippocampus                 0.140626
#
#                                   Edinger-Westphal nucleus (accessory oculomotor nucleus)  \
#
# CP in caudal hippocampus                                                   0.015794
# CP in caudal subicular cortex                                              0.099613
# CP in midlateral temporal cortex                                           0.014355
# CP in retrosplenial cortex                                                -0.016931
# CP in rostral hippocampus                                                  0.111341
#
#                                   IZ in caudal cingulate cortex  \
#
# CP in caudal hippocampus                               0.005320
# CP in caudal subicular cortex                          0.169381
# CP in midlateral temporal cortex                       0.093161
# CP in retrosplenial cortex                             0.140206
# CP in rostral hippocampus                              0.104994
#
#                                   IZ in caudal midinferior temporal cortex (area TF)  \
#
# CP in caudal hippocampus                                                   0.034846
# CP in caudal subicular cortex                                              0.152493
# CP in midlateral temporal cortex                                           0.114810
# CP in retrosplenial cortex                                                 0.251120
# CP in rostral hippocampus                                                  0.134103
#
#                                       ...       \
#                                       ...
# CP in caudal hippocampus              ...
# CP in caudal subicular cortex         ...
# CP in midlateral temporal cortex      ...
# CP in retrosplenial cortex            ...
# CP in rostral hippocampus             ...
#
#                                   ventral lateral nucleus of thalamus  \
#
# CP in caudal hippocampus                                     0.094239
# CP in caudal subicular cortex                               -0.001815
# CP in midlateral temporal cortex                            -0.065720
# CP in retrosplenial cortex                                   0.138144
# CP in rostral hippocampus                                    0.067102
#
#                                   ventral medial nucleus of thalamus  \
#
# CP in caudal hippocampus                                    0.068778
# CP in caudal subicular cortex                               0.015960
# CP in midlateral temporal cortex                           -0.038566
# CP in retrosplenial cortex                                  0.057590
# CP in rostral hippocampus                                   0.136814
#
#                                   ventral posterior inferior nucleus  \
#
# CP in caudal hippocampus                                    0.034154
# CP in caudal subicular cortex                               0.039399
# CP in midlateral temporal cortex                            0.039763
# CP in retrosplenial cortex                                  0.092071
# CP in rostral hippocampus                                   0.119841
#
#                                   ventral posterior lateral nucleus  \
#
# CP in caudal hippocampus                                   0.103230
# CP in caudal subicular cortex                              0.011543
# CP in midlateral temporal cortex                          -0.071302
# CP in retrosplenial cortex                                 0.116557
# CP in rostral hippocampus                                  0.127150
#
#                                   ventral posterior medial nucleus  \
#
# CP in caudal hippocampus                                 -0.020604
# CP in caudal subicular cortex                             0.117967
# CP in midlateral temporal cortex                          0.057354
# CP in retrosplenial cortex                                0.083585
# CP in rostral hippocampus                                 0.181375
#
#                                   ventral tegmental area  \
#
# CP in caudal hippocampus                       -0.103817
# CP in caudal subicular cortex                  -0.139816
# CP in midlateral temporal cortex               -0.094360
# CP in retrosplenial cortex                      0.072218
# CP in rostral hippocampus                       0.039425
#
#                                   ventricular (matrix) zone of cerebellum  \
#
# CP in caudal hippocampus                                        -0.033505
# CP in caudal subicular cortex                                    0.022600
# CP in midlateral temporal cortex                                -0.055025
# CP in retrosplenial cortex                                      -0.029791
# CP in rostral hippocampus                                        0.020932
#
#                                   ventricular (matrix) zone of pons  \
#
# CP in caudal hippocampus                                  -0.024660
# CP in caudal subicular cortex                             -0.001916
# CP in midlateral temporal cortex                          -0.091360
# CP in retrosplenial cortex                                -0.040087
# CP in rostral hippocampus                                 -0.008057
#
#                                   ventromedial hypothalamic nucleus  \
#
# CP in caudal hippocampus                                   0.063624
# CP in caudal subicular cortex                              0.063608
# CP in midlateral temporal cortex                          -0.078528
# CP in retrosplenial cortex                                 0.069638
# CP in rostral hippocampus                                  0.152017
#
#                                   zona incerta
#
# CP in caudal hippocampus             -0.017304
# CP in caudal subicular cortex        -0.049109
# CP in midlateral temporal cortex     -0.157588
# CP in retrosplenial cortex            0.030508
# CP in rostral hippocampus             0.045254
#
# [5 rows x 516 columns]

# %% [markdown]
# # Save Attribute Similarity Matrix

# %%
filename = path+'aba_pre_mic_tissue_attribute_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %%
# net.load_df(attribute_similarity_matix.iloc[:,:].copy())
# # net.filter_N_top('row', rank_type='sum', N_top=300)
# net.cluster()
# net.widget()

# %% [markdown]
# # Create Gene Similarity Matrix

# %%
gene_similarity_matix = uf.createSimilarityMatrix(normalized_matrix, 'cosine')

# %%
gene_similarity_matix.head()
# Out:
#              A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT     A4GNT  \
#
# A1BG     1.000000 -0.023731 -0.315999  0.041112  0.036441 -0.037558  0.057357
# A1CF    -0.023731  1.000000 -0.071987  0.143688  0.039723  0.118267  0.143636
# A2M     -0.315999 -0.071987  1.000000  0.007574  0.052168  0.115952 -0.054198
# A2ML1    0.041112  0.143688  0.007574  1.000000  0.057671  0.184468  0.148466
# A3GALT2  0.036441  0.039723  0.052168  0.057671  1.000000  0.048828  0.036446
#
#              AAAS      AACS     AADAC    ...       ZWILCH     ZWINT      ZXDA  \
#                                          ...
# A1BG     0.110841  0.312703 -0.058648    ...     0.092027 -0.189828  0.268177
# A1CF    -0.059144  0.100895  0.115758    ...     0.005180 -0.051512  0.037550
# A2M      0.072724 -0.311314  0.013344    ...    -0.316680  0.207374 -0.314693
# A2ML1    0.108816 -0.041483  0.130610    ...    -0.078578  0.042216  0.100041
# A3GALT2 -0.095500  0.025507  0.171977    ...    -0.052149  0.114917  0.058477
#
#              ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
#
# A1BG     0.010066  0.239450 -0.059244  0.100276  0.058393  0.208300 -0.105342
# A1CF     0.218544 -0.126751  0.159481  0.006604  0.047536  0.113000  0.152201
# A2M     -0.134886 -0.136957 -0.088129 -0.389724 -0.031529 -0.134898 -0.056293
# A2ML1    0.154151 -0.011912  0.023305 -0.238010 -0.069527  0.061857  0.132900
# A3GALT2  0.067882  0.054370  0.088983  0.027350 -0.092940  0.254894  0.082012
#
# [5 rows x 19281 columns]

# %% [markdown]
# # Save Gene Similarity Matrix

# %%
filename = path+'aba_pre_mic_tissue_gene_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene-Attribute Edge List

# %%
name = 'aba_pre_mic_tissue_gene_attribute_edge_list'

# %%
uf.createGeneAttributeEdgeList(standard_matrix, attribute_list, gene_list, path, name)
# Out:
# Progeres: 100%  516 Out of 516
#
#  The number of statisticaly relevent gene-attribute associations is: 501308
