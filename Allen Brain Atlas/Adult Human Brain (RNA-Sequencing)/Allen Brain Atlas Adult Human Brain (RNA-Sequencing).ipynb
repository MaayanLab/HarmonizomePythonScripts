# %% [markdown]
# # Allen Brain Atlas Adult Human Brain (RNA-Sequencing)

# %% [markdown]
# Author: Moshe Silverstein <br/>
# Date: 5-17 <br/>
# Data Source: http://human.brain-map.org/static/download

# %%
import sys, datetime
import numpy as np
import pandas as pd
import importlib
import my_functions as mf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from clustergrammer_widget import *
net = Network(clustergrammer_widget)

# %%
importlib.reload(mf)
# Out:
# <module 'my_functions' from '/Users/moshesilverstein/Documents/Harmonizome/Allen Brain Atlas/BRAIN/my_functions.py'>

# %% [markdown]
# # Versions Of Modules In Use

# %%
# %load_ext version_information
# %version_information numpy, pandas, clustergrammer_widget
# Out:
# Software versions
# Python 3.5.2 64bit [GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]
# IPython 5.3.0
# OS Darwin 17.2.0 x86_64 i386 64bit
# numpy 1.13.1
# pandas 0.21.0
# clustergrammer_widget 1.9.0
# Mon Mar 05 13:19:37 2018 EST

# %% [markdown]
# # Functions

# %%
def mapSampleData(inputDF, sampleMetaDF, Ontology):
    
    lst = []

    for index in sampleMetaDF.index:
        structure = sampleMetaDF.loc[index, 'ontology_structure_id']
        hemisphere = sampleMetaDF.loc[index, 'hemisphere']
        if type(Ontology.loc[structure, 'name']) == str:
            lst.append(str(Ontology.loc[structure, 'name']))
        else:
            for struc in Ontology.loc[structure, ['name', 'hemisphere']].values:
                if struc[1] == hemisphere:
                    lst.append(str(struc[0]))

    inputDF.columns  = lst

# %% [markdown]
# # Donor 9861

# %% [markdown]
# # Load Data

# %%
matrix_9861 = pd.read_csv('~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Input/rnaseq_donor9861/RNAseqCounts.csv', sep=',', header=None, index_col=0)

# %%
matrix_9861.head()
# Out:
#               1        2        3       4        5        6        7    \
# 0
# A1BG        50.72    73.58    43.15   35.03    67.32    54.00    62.43
# A1BG-AS1   101.17   136.09    84.37   55.95    90.35    26.51    98.79
# A1CF         3.13     3.01     5.88    1.00     4.73     2.00     1.02
# A2LD1       26.84    66.72    49.18   24.41    37.27    35.56    39.78
# A2M       1871.00  3411.51  2728.97  948.97  3011.94  2361.58  2359.99
#
#               8        9        10    ...         112      113      114  \
# 0                                     ...
# A1BG        51.94    16.43    67.67   ...       38.00    52.59    53.89
# A1BG-AS1    69.80    24.87    65.49   ...      102.45    81.88    92.86
# A1CF         0.00     0.00     2.00   ...        9.94     8.84     7.94
# A2LD1       22.90    10.47    30.84   ...       30.81    28.07    25.69
# A2M       3300.98  1676.99  2781.99   ...     1812.89  2628.93  1573.98
#
# ...

# %%
matrix_9861.shape
# Out:
# (22318, 121)

# %% [markdown]
# # Load Sample Metadata

# %%
sample_meta_9861 = pd.read_csv('~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Input/rnaseq_donor9861/SampleAnnot.csv', sep=',')

# %%
sample_meta_9861.head()
# Out:
#   RNAseq_sample_name replicate_sample sample_name  well_id microarray_run_id  \
# 0    S010002_L7.LB16               No     S010002      105           275-104
# 1    S010003_L7.LB19               No     S010003      113           275-104
# 2    S010006_L8.LB27               No     S010006      193           275-104
# 3    S010007_L4.LB20               No     S010007      145           275-104
# 4     S010017_L1.LB2               No     S010017      114           275-104
#
#   ontology_color main_structure sub_structure  ontology_structure_id  \
# 0        #FF7B62             PL           SPL                   4101
# 1        #FF7B62             PL           SPL                   4101
# 2        #FF7B62             PL           SPL                   4099
# 3        #FF5D62             PL         AnG-s                   4113
# 4        #E8D959             FL         SFG-l                   4027
#
#   ontology_structure_acronym  ...   brain  million_clusters  clip_percentage  \
# ...

# %%
sample_meta_9861.shape
# Out:
# (121, 21)

# %% [markdown]
# # Load Sample Ontology

# %%
sample_onto_9861 = pd.read_csv('~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Input/rnaseq_donor9861/Ontology.csv', sep=',', index_col=0)

# %%
sample_onto_9861.head()
# Out:
#      acronym             name  parent_structure_id hemisphere  graph_order  \
# id
# 4005      Br            brain                  NaN        NaN            0
# 4006      GM      gray matter               4005.0        NaN            1
# 4007     Tel    telencephalon               4006.0        NaN            2
# 4008      Cx  cerebral cortex               4007.0        NaN            3
# 4009      FL     frontal lobe               4008.0        NaN            4
#
#                structure_id_path color_hex_triplet
# id
# 4005                      /4005/            A0A0A0
# 4006                 /4005/4006/            787878
# 4007            /4005/4006/4007/            D988A3
# 4008       /4005/4006/4007/4008/            EDA65F
# 4009  /4005/4006/4007/4008/4009/            E8CD59

# %%
sample_onto_9861.shape
# Out:
# (1839, 7)

# %% [markdown]
# # Map Sample Metadata to Sample ID

# %%
mapSampleData(matrix_9861, sample_meta_9861, sample_onto_9861)

# %%
matrix_9861.head()
# Out:
#           superior parietal lobule, right, superior bank of gyrus  \
# 0
# A1BG                                                  50.72
# A1BG-AS1                                             101.17
# A1CF                                                   3.13
# A2LD1                                                 26.84
# A2M                                                 1871.00
#
#           superior parietal lobule, right, superior bank of gyrus  \
# 0
# A1BG                                                  73.58
# A1BG-AS1                                             136.09
# A1CF                                                   3.01
# A2LD1                                                 66.72
# A2M                                                 3411.51
#
#           superior parietal lobule, left, inferior bank of gyrus  \
# 0
# A1BG                                                  43.15
# A1BG-AS1                                              84.37
# ...

# %% [markdown]
# # Donor 10021

# %% [markdown]
# # Load Data

# %%
matrix_10021 = pd.read_csv('~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Input/rnaseq_donor10021/RNAseqCounts.csv', sep=',', header=None, index_col=0)

# %%
matrix_10021.head()
# Out:
#               1        2        3        4        5        6        7    \
# 0
# A1BG        84.92   143.85    88.59   110.00    87.07   122.25   103.65
# A1BG-AS1   107.12   108.52    96.26    96.43    98.79    91.09   110.81
# A1CF        13.25     5.09     4.58     4.03     1.00     3.00     2.99
# A2LD1       53.26    72.54    54.20    49.50    46.60    54.83    48.51
# A2M       3813.83  3582.94  3907.99  3892.90  3592.06  4742.55  3811.88
#
#               8        9        10    ...         112      113      114  \
# 0                                     ...
# A1BG       106.91   191.16   162.56   ...      130.22   104.00   180.62
# A1BG-AS1   140.31   198.17   156.49   ...      101.59    47.58    33.40
# A1CF         1.00     7.00     4.25   ...        2.00     1.00     2.98
# A2LD1       68.45    84.89    50.57   ...       88.49    63.68   114.16
# A2M       5890.89  5856.88  4077.96   ...     4095.95  5089.97  9421.94
#
# ...

# %%
matrix_10021.shape
# Out:
# (22318, 121)

# %% [markdown]
# # Load Sample Metadata

# %%
sample_meta_10021 = pd.read_csv('~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Input/rnaseq_donor10021/SampleAnnot.csv', sep=',')

# %%
sample_meta_10021.head()
# Out:
#   RNAseq_sample_name replicate_sample sample_name  well_id microarray_run_id  \
# 0    S020008_L7.LB13               No     S020008     4569           275-201
# 1     S020013_L7.LB3               No     S020013     4514           275-201
# 2     S020019_L2.LB9               No     S020019     4562           275-201
# 3    S020024_L8.LB22               No     S020024     4602           275-205
# 4     S020027_L6.LB6               No     S020027     4531           275-201
#
#   ontology_color main_structure sub_structure  ontology_structure_id  \
# 0        #E8D959             FL         SFG-l                   4024
# 1        #E8D959             FL         SFG-m                   4026
# 2        #E8D959             FL         SFG-l                   4024
# 3        #E8C659             FL         orIFG                   4045
# 4        #E8C659             FL         orIFG                   4046
#
#   ontology_structure_acronym  ...   brain  million_clusters  clip_percentage  \
# ...

# %%
sample_meta_10021.shape
# Out:
# (121, 21)

# %% [markdown]
# # Load Sample Ontology

# %%
sample_onto_10021 = pd.read_csv('~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Input/rnaseq_donor10021/Ontology.csv', sep=',', index_col=0)

# %%
sample_onto_10021.head()
# Out:
#      acronym             name  parent_structure_id hemisphere  graph_order  \
# id
# 4005      Br            brain                  NaN        NaN            0
# 4006      GM      gray matter               4005.0        NaN            1
# 4007     Tel    telencephalon               4006.0        NaN            2
# 4008      Cx  cerebral cortex               4007.0        NaN            3
# 4009      FL     frontal lobe               4008.0        NaN            4
#
#                structure_id_path color_hex_triplet
# id
# 4005                      /4005/            A0A0A0
# 4006                 /4005/4006/            787878
# 4007            /4005/4006/4007/            D988A3
# 4008       /4005/4006/4007/4008/            EDA65F
# 4009  /4005/4006/4007/4008/4009/            E8CD59

# %%
sample_onto_10021.shape
# Out:
# (1839, 7)

# %% [markdown]
# # Map Sample Metadata to Sample ID

# %%
mapSampleData(matrix_10021, sample_meta_10021, sample_onto_10021)

# %%
matrix_10021.head()
# Out:
#           superior frontal gyrus, left, lateral bank of gyrus  \
# 0
# A1BG                                                  84.92
# A1BG-AS1                                             107.12
# A1CF                                                  13.25
# A2LD1                                                 53.26
# A2M                                                 3813.83
#
#           superior frontal gyrus, right, medial bank of gyrus  \
# 0
# A1BG                                                 143.85
# A1BG-AS1                                             108.52
# A1CF                                                   5.09
# A2LD1                                                 72.54
# A2M                                                 3582.94
#
#           superior frontal gyrus, left, lateral bank of gyrus  \
# 0
# A1BG                                                  88.59
# A1BG-AS1                                              96.26
# ...

# %% [markdown]
# # Combine Donor Datasets

# %% [markdown]
# # Unfiltered

# %%
matrix = pd.concat([matrix_9861, matrix_10021], axis=1)

# %%
matrix.head()
# Out:
#           superior parietal lobule, right, superior bank of gyrus  \
# 0
# A1BG                                                  50.72
# A1BG-AS1                                             101.17
# A1CF                                                   3.13
# A2LD1                                                 26.84
# A2M                                                 1871.00
#
#           superior parietal lobule, right, superior bank of gyrus  \
# 0
# A1BG                                                  73.58
# A1BG-AS1                                             136.09
# A1CF                                                   3.01
# A2LD1                                                 66.72
# A2M                                                 3411.51
#
#           superior parietal lobule, left, inferior bank of gyrus  \
# 0
# A1BG                                                  43.15
# A1BG-AS1                                              84.37
# ...

# %%
matrix.shape
# Out:
# (22318, 242)

# %% [markdown]
# # Save Unfiltered to file

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_matrix_unfilltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Filtered

# %%
normalized_matrix = pd.concat([matrix_9861, matrix_10021], axis=1)

# %%
normalized_matrix.head()
# Out:
#           superior parietal lobule, right, superior bank of gyrus  \
# 0
# A1BG                                                  50.72
# A1BG-AS1                                             101.17
# A1CF                                                   3.13
# A2LD1                                                 26.84
# A2M                                                 1871.00
#
#           superior parietal lobule, right, superior bank of gyrus  \
# 0
# A1BG                                                  73.58
# A1BG-AS1                                             136.09
# A1CF                                                   3.01
# A2LD1                                                 66.72
# A2M                                                 3411.51
#
#           superior parietal lobule, left, inferior bank of gyrus  \
# 0
# A1BG                                                  43.15
# A1BG-AS1                                              84.37
# ...

# %%
normalized_matrix.shape
# Out:
# (22318, 242)

# %% [markdown]
# # Remove any data with more than 95% missing and imput remaining mssing values to matrix mean

# %%
normalized_matrix = mf.removeAndImpute(normalized_matrix)

# %%
normalized_matrix.head()
# Out:
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                                  50.72
# A1BG-AS1                                             101.17
# A1CF                                                   3.13
# A2LD1                                                 26.84
# A2M                                                 1871.00
#
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                                  73.58
# A1BG-AS1                                             136.09
# A1CF                                                   3.01
# A2LD1                                                 66.72
# A2M                                                 3411.51
#
#           superior parietal lobule, left, inferior bank of gyrus  \
# A1BG                                                  43.15
# A1BG-AS1                                              84.37
# ...

# %%
normalized_matrix.shape
# Out:
# (19944, 242)

# %% [markdown]
# # Log2 Transform

# %%
normalized_matrix = mf.log2(normalized_matrix)

# %%
normalized_matrix.head()
# Out:
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                               5.692650
# A1BG-AS1                                           6.674828
# A1CF                                               2.046142
# A2LD1                                              4.799087
# A2M                                               10.870365
#
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                               6.220717
# A1BG-AS1                                           7.098980
# A1CF                                               2.003602
# A2LD1                                              6.081510
# A2M                                               11.736618
#
#           superior parietal lobule, left, inferior bank of gyrus  \
# A1BG                                               5.464342
# A1BG-AS1                                           6.415657
# ...

# %% [markdown]
# # Normalize Matrix (Quantile Normalize the matrix for the columns)

# %%
normalized_matrix = mf.quantileNormalize(normalized_matrix)
# Out:
# Step 2/2 progress: 100%  242 Out of 242

# %%
normalized_matrix.head()
# Out:
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                               5.814335
# A1BG-AS1                                           6.787162
# A1CF                                               2.272540
# A2LD1                                              4.918024
# A2M                                               10.818052
#
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                               5.764678
# A1BG-AS1                                           6.600013
# A1CF                                               1.961761
# A2LD1                                              5.618904
# A2M                                               11.164074
#
#           superior parietal lobule, left, inferior bank of gyrus  \
# A1BG                                               5.543387
# A1BG-AS1                                           6.443964
# ...

# %% [markdown]
# # Normalize Matrix (z-score the rows)

# %%
mf.zscore(normalized_matrix, 'row')
# Out:
# Progress: 100%  19944 Out of 19944

# %%
normalized_matrix.head()
# Out:
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                              -1.163256
# A1BG-AS1                                           0.587762
# A1CF                                               0.261860
# A2LD1                                             -1.735814
# A2M                                               -2.560651
#
#           superior parietal lobule, right, superior bank of gyrus  \
# A1BG                                              -1.253627
# A1BG-AS1                                           0.048175
# A1CF                                              -0.204032
# A2LD1                                             -0.073498
# A2M                                               -1.678269
#
#           superior parietal lobule, left, inferior bank of gyrus  \
# A1BG                                              -1.656356
# A1BG-AS1                                          -0.401744
# ...

# %% [markdown]
# # Merge Like Column (by taking the mean)

# %%
normalized_matrix = mf.merge(normalized_matrix, 'column', 'mean')

# %%
normalized_matrix.shape
# Out:
# (19944, 100)

# %% [markdown]
# # Map Gene Symbols To Up-to-date Approved Gene Symbols

# %%
mf.mapgenesymbols(normalized_matrix)
# Out:
# Progeres: 100%  19944 Out of 19944

# %%
normalized_matrix.shape
# Out:
# (18734, 100)

# %% [markdown]
# # Merge Duplicate Genes By Rows

# %%
normalized_matrix = mf.merge(normalized_matrix, 'row', 'mean')

# %%
normalized_matrix.shape
# Out:
# (18629, 100)

# %% [markdown]
# # Histogram of First Sample

# %%
normalized_matrix[normalized_matrix.columns[0]].hist(bins=100)

# %% [markdown]
# # Histogram of First Gene

# %%
normalized_matrix.loc[normalized_matrix.index[0]].hist(bins=100)

# %% [markdown]
# # Save Filtered Matrix

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_matrix_filltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
normalized_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene List

# %%
gene_list = mf.createGeneList(normalized_matrix)
# Out:
# Progeres: 100%  18629 Out of 18629

# %%
gene_list.head()
# Out:
#     GeneSym  GeneID
# 0      A1BG       1
# 1  A1BG-AS1  503538
# 2      A1CF   29974
# 3       A2M       2
# 4     A2ML1  144568

# %%
gene_list.shape
# Out:
# (18629, 2)

# %% [markdown]
# # Save Gene List

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_gene_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_list.to_csv(filename, sep='\t', index=False, compression='gzip')

# %% [markdown]
# # Create Attribute List

# %%
attribute_list = mf.createAttributeList(normalized_matrix)

# %%
attribute_list.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Crus I, right, lateral hemisphere, Crus II, left, lateral hemisphere, IV, right, paravermis, IX, right, paravermis, VI, left, lateral hemisphere]

# %%
attribute_list.shape
# Out:
# (100, 0)

# %% [markdown]
# # Save Attribute List

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_attribute_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_list.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create matrix of Standardized values (values between -1, and 1)

# %%
standard_matrix = mf.createStandardizedMatrix(normalized_matrix)
# Out:
# Progeres: 100%  18629 Out of 18629

# %%
standard_matrix.head()
# Out:
#           Crus I, right, lateral hemisphere  \
#
# A1BG                              -0.922423
# A1BG-AS1                           0.835768
# A1CF                               0.969014
# A2M                               -0.971277
# A2ML1                             -0.991247
#
#           Crus II, left, lateral hemisphere  IV, right, paravermis  \
#
# A1BG                               0.697703               0.337760
# A1BG-AS1                           0.055746              -0.564230
# A1CF                               0.989060               0.868917
# A2M                               -0.931310              -0.711060
# A2ML1                             -0.871144              -0.971277
#
#           IX, right, paravermis  VI, left, lateral hemisphere  \
#
# A1BG                  -0.682127                     -0.782216
# A1BG-AS1              -0.024331                      0.395724
# A1CF                   0.848948                      0.948985
# ...

# %% [markdown]
# # Plot of A Single Celltype, Normalized Value vs. Standardized Value

# %%
plt.plot(normalized_matrix[normalized_matrix.columns[0]], standard_matrix[standard_matrix.columns[0]], 'bo')
plt.xlabel('Normalized Values')
plt.ylabel('Standardized Values')
plt.title(standard_matrix.columns[0])
plt.grid(True)

# %% [markdown]
# # Save Standardized Matrix

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_standard_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
standard_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Tertiary Matrix

# %%
tertiary_matrix = mf.createTertiaryMatrix(standard_matrix)

# %%
tertiary_matrix.head()
# Out:
#           Crus I, right, lateral hemisphere  \
#
# A1BG                                      0
# A1BG-AS1                                  0
# A1CF                                      1
# A2M                                      -1
# A2ML1                                    -1
#
#           Crus II, left, lateral hemisphere  IV, right, paravermis  \
#
# A1BG                                      0                      0
# A1BG-AS1                                  0                      0
# A1CF                                      1                      0
# A2M                                       0                      0
# A2ML1                                     0                     -1
#
#           IX, right, paravermis  VI, left, lateral hemisphere  \
#
# A1BG                          0                             0
# A1BG-AS1                      0                             0
# A1CF                          0                             0
# ...

# %% [markdown]
# # Save Teriary Matrix

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_tertiary_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
tertiary_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Path to output files

# %%
path = '/Users/moshesilverstein/Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/'

# %% [markdown]
# # Create Up Gene Set Library

# %%
name = 'aba_brain_gene_up_set'

# %%
mf.createUpGeneSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  100 Out of 100

# %% [markdown]
# # Create Down Gene Set Library

# %%
name = 'aba_brain_gene_down_set'

# %%
mf.createDownGeneSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  100 Out of 100

# %% [markdown]
# # Create Up Attribute Library

# %%
name = 'aba_brain_attribute_up_set'

# %%
mf.createUpAttributeSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  18629 Out of 18629

# %% [markdown]
# # Create Down Attribute Library

# %%
name = 'aba_brain_attribute_down_set'

# %%
mf.createDownAttributeSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  18629 Out of 18629

# %% [markdown]
# # Create Attribute Similarity matrix

# %%
attribute_similarity_matix = mf.createSimilarityMatrix(normalized_matrix.T, 'cosine')

# %%
attribute_similarity_matix.head()
# Out:
#                                    Crus I, right, lateral hemisphere  \
#
# Crus I, right, lateral hemisphere                           1.000000
# Crus II, left, lateral hemisphere                           0.778314
# IV, right, paravermis                                       0.792658
# IX, right, paravermis                                       0.779113
# VI, left, lateral hemisphere                                0.770540
#
#                                    Crus II, left, lateral hemisphere  \
#
# Crus I, right, lateral hemisphere                           0.778314
# Crus II, left, lateral hemisphere                           1.000000
# IV, right, paravermis                                       0.825358
# IX, right, paravermis                                       0.764161
# VI, left, lateral hemisphere                                0.771405
#
#                                    IV, right, paravermis  \
#
# Crus I, right, lateral hemisphere               0.792658
# ...

# %% [markdown]
# # Save Attribute Similarity Matrix

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_attribute_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %%
net.load_df(attribute_similarity_matix.iloc[:,:].copy())
# net.filter_N_top('row', rank_type='sum', N_top=300)
net.cluster()
net.widget()
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# # Create Gene Similarity Matrix

# %%
gene_similarity_matix = mf.createSimilarityMatrix(normalized_matrix, 'cosine')

# %%
gene_similarity_matix.head()
# Out:
#               A1BG  A1BG-AS1      A1CF       A2M     A2ML1    A4GALT  \
#
# A1BG      1.000000 -0.342883 -0.137559  0.291290  0.161037  0.310286
# A1BG-AS1 -0.342883  1.000000  0.234475 -0.693921 -0.321973 -0.509224
# A1CF     -0.137559  0.234475  1.000000 -0.474102 -0.625239 -0.528976
# A2M       0.291290 -0.693921 -0.474102  1.000000  0.519521  0.823891
# A2ML1     0.161037 -0.321973 -0.625239  0.519521  1.000000  0.601655
#
#              A4GNT      AAAS      AACS    AACSP1    ...       ZWILCH  \
#                                                     ...
# A1BG      0.049806  0.287478 -0.260180 -0.081023    ...    -0.512385
# A1BG-AS1  0.140274 -0.390250  0.657398  0.235363    ...     0.690354
# A1CF      0.002461  0.203840 -0.293207 -0.425337    ...     0.240531
# A2M      -0.028206  0.340544 -0.376534  0.115265    ...    -0.798006
# A2ML1     0.015559 -0.141567  0.154063  0.253178    ...    -0.334900
#
#              ZWINT      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B  \
#
# ...

# %% [markdown]
# # Save Gene Similarity Matrix

# %%
filename = '~/./Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/aba_brain_gene_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene-Attribute Edge List

# %%
path = '/Users/moshesilverstein/Documents/Harmonizome/Allen Brain Atlas/BRAIN/Output/'

# %%
name = 'aba_brain_gene_attribute_edge_list'

# %%
mf.createGeneAttributeEdgeList(standard_matrix, attribute_list, gene_list, path, name)
# Out:
# Progeres: 100%  100 Out of 100
#
#  The number of statisticaly relevent gene-attribute associations is: 92925
