# %% [markdown]
# # Allen Brain Atlas Developing Human Brain Tissue (RNA-Seq)

# %% [markdown]
# Author: Moshe Silverstein <br/>
# Date: 3-18 <br/>
# Data Source: http://www.brainspan.org/static/download.html

# %%
import sys, datetime
import numpy as np
import pandas as pd
import importlib
import untility_functions as uf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from clustergrammer_widget import *
net = Network(clustergrammer_widget)

# %%
importlib.reload(uf)
# Out:
# <module 'untility_functions' from '/Users/moshesilverstein/Documents/Harmonizome/Allen Brain Atlas/BRAINSPAN atlas of the developing brain/Developnetal Transcriptome Dataset/RNA-Seq/untility_functions.py'>

# %% [markdown]
# # Versions Of Modules In Use

# %%
# %load_ext version_information
# %version_information numpy, pandas, clustergrammer_widget
# Out:
# Software versions
# Python 3.5.2 64bit [GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]
# IPython 5.3.0
# OS Darwin 17.2.0 x86_64 i386 64bit
# numpy 1.13.1
# pandas 0.21.0
# clustergrammer_widget 1.9.0
# Wed Mar 07 13:38:24 2018 EST

# %% [markdown]
# # Path to Output Files

# %%
path = '/Users/moshesilverstein/Documents/Harmonizome/Allen Brain Atlas/BRAINSPAN atlas of the developing brain/Developnetal Transcriptome Dataset/RNA-Seq/Output/'

# %% [markdown]
# # Load Data

# %%
matrix = pd.read_csv('Input/genes_matrix_csv/expression_matrix.csv', header=None, index_col=0)

# %%
matrix.head()
# Out:
#          1          2          3          4          5          6    \
# 0
# 1  36.447128  24.251253  19.330479  27.668607  19.998231  14.680673
# 2   0.044081   0.067338   0.000000   0.145466   0.185188   0.311180
# 3  34.373239  20.765661  18.734947  22.366394  19.228431  11.020365
# 4   4.379337   4.227521   2.551825   3.603764   2.948976   2.405183
# 5   3.957119   3.520794   2.037805   3.487035   2.177235   0.999693
#
#          7          8          9          10     ...            515  \
# 0                                                ...
# 1  27.548101  16.580183  44.587799  44.943915    ...       2.320932
# 2   0.000000   0.000000   0.473831   0.181220    ...       0.758571
# 3  25.394607  17.671327  32.903100  38.157569    ...      23.769167
# 4   3.613642   2.573935   3.483817   3.609830    ...       1.593009
# 5   3.481555   1.747568   3.741580   3.560650    ...       0.583488
#
#          516        517        518        519        520        521  \
# 0
# ...

# %%
matrix.shape
# Out:
# (52376, 524)

# %% [markdown]
# # Load Sample Metadata

# %%
sample_meta = pd.read_csv('Input/genes_matrix_csv/columns_metadata.csv', index_col=0)

# %%
sample_meta.head()
# Out:
#             donor_id   donor_name    age gender  structure_id  \
# column_num
# 1              13058  H376.IIA.51  8 pcw      M         10268
# 2              13058  H376.IIA.51  8 pcw      M         10291
# 3              13058  H376.IIA.51  8 pcw      M         10361
# 4              13058  H376.IIA.51  8 pcw      M         10550
# 5              13058  H376.IIA.51  8 pcw      M         10243
#
#            structure_acronym  \
# column_num
# 1                        Ocx
# 2                    M1C-S1C
# 3                        AMY
# 4                        MGE
# 5                        STC
#
#                                                structure_name
# column_num
# 1                                         occipital neocortex
# 2                      primary motor-sensory cortex (samples)
# 3                                          amygdaloid complex
# 4                                  medial ganglionic eminence
# ...

# %% [markdown]
# # Load Gene Metadata

# %%
gene_meta = pd.read_csv('Input/genes_matrix_csv/rows_metadata.csv', index_col=0)

# %%
gene_meta.head()
# Out:
#          gene_id  ensembl_gene_id gene_symbol  entrez_id
# row_num
# 1         7062.0  ENSG00000000003      TSPAN6     7105.0
# 2        40735.0  ENSG00000000005        TNMD    64102.0
# 3         8736.0  ENSG00000000419        DPM1     8813.0
# 4        36423.0  ENSG00000000457       SCYL3    57147.0
# 5        35021.0  ENSG00000000460    C1orf112    55732.0

# %%
gene_meta.shape
# Out:
# (52376, 4)

# %% [markdown]
# # Map Sample Metadata to Sample ID

# %%
lst = []

for i,col in enumerate(matrix.columns):
    col_num = i+1
    sample = str(sample_meta.loc[col_num, 'structure_name'])
    lst.append(sample)
    
matrix.columns = lst

# %%
matrix.head()
# Out:
#    occipital neocortex  primary motor-sensory cortex (samples)  \
# 0
# 1            36.447128                               24.251253
# 2             0.044081                                0.067338
# 3            34.373239                               20.765661
# 4             4.379337                                4.227521
# 5             3.957119                                3.520794
#
#    amygdaloid complex  medial ganglionic eminence  \
# 0
# 1           19.330479                   27.668607
# 2            0.000000                    0.145466
# 3           18.734947                   22.366394
# 4            2.551825                    3.603764
# 5            2.037805                    3.487035
#
#    posterior (caudal) superior temporal cortex (area 22c)  \
# 0
# 1                                          19.998231
# 2                                           0.185188
# 3                                          19.228431
# ...

# %% [markdown]
# # Map Gene to Row

# %%
matrix.index = gene_meta['gene_symbol']

# %%
matrix.index.name = ''

# %%
matrix.head()
# Out:
#           occipital neocortex  primary motor-sensory cortex (samples)  \
#
# TSPAN6              36.447128                               24.251253
# TNMD                 0.044081                                0.067338
# DPM1                34.373239                               20.765661
# SCYL3                4.379337                                4.227521
# C1orf112             3.957119                                3.520794
#
#           amygdaloid complex  medial ganglionic eminence  \
#
# TSPAN6             19.330479                   27.668607
# TNMD                0.000000                    0.145466
# DPM1               18.734947                   22.366394
# SCYL3               2.551825                    3.603764
# C1orf112            2.037805                    3.487035
#
#           posterior (caudal) superior temporal cortex (area 22c)  \
#
# TSPAN6                                            19.998231
# TNMD                                               0.185188
# ...

# %% [markdown]
# # Save Unfiltered Matrix to File

# %%
filename = path+'aba_dev_rnaseq_tish_matrix_unfilltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Filtered

# %%
normalized_matrix = matrix.copy()

# %%
normalized_matrix.head()
# Out:
#           occipital neocortex  primary motor-sensory cortex (samples)  \
#
# TSPAN6              36.447128                               24.251253
# TNMD                 0.044081                                0.067338
# DPM1                34.373239                               20.765661
# SCYL3                4.379337                                4.227521
# C1orf112             3.957119                                3.520794
#
#           amygdaloid complex  medial ganglionic eminence  \
#
# TSPAN6             19.330479                   27.668607
# TNMD                0.000000                    0.145466
# DPM1               18.734947                   22.366394
# SCYL3               2.551825                    3.603764
# C1orf112            2.037805                    3.487035
#
#           posterior (caudal) superior temporal cortex (area 22c)  \
#
# TSPAN6                                            19.998231
# TNMD                                               0.185188
# ...

# %%
normalized_matrix.shape
# Out:
# (52376, 524)

# %% [markdown]
# # Remove any data with more than 95% missing and imput remaining mssing values to matrix mean

# %%
normalized_matrix = uf.removeAndImpute(normalized_matrix)

# %%
normalized_matrix.shape
# Out:
# (38855, 524)

# %% [markdown]
# # Log2 Transform

# %%
normalized_matrix = uf.log2(normalized_matrix)

# %%
normalized_matrix.head()
# Out:
#           occipital neocortex  primary motor-sensory cortex (samples)  \
# TSPAN6               5.226783                                4.658283
# TNMD                 0.062234                                0.094017
# DPM1                 5.144586                                4.443982
# SCYL3                2.427428                                2.386127
# C1orf112             2.309502                                2.176576
#
#           amygdaloid complex  medial ganglionic eminence  \
# TSPAN6              4.345572                    4.841400
# TNMD                0.153085                    0.195935
# DPM1                4.302681                    4.546363
# SCYL3               1.828561                    2.202814
# C1orf112            1.603029                    2.165762
#
#           posterior (caudal) superior temporal cortex (area 22c)  \
# TSPAN6                                             4.392196
# TNMD                                               0.245116
# ...

# %% [markdown]
# # Normalize Matrix (Quantile Normalize the matrix for the columns)

# %%
normalized_matrix = uf.quantileNormalize(normalized_matrix)
# Out:
# Step 2/2 progress: 100%  524 Out of 524

# %%
normalized_matrix.head()
# Out:
#           occipital neocortex  primary motor-sensory cortex (samples)  \
# TSPAN6               4.946887                                4.496292
# TNMD                 0.069855                                0.105250
# DPM1                 4.844502                                4.269782
# SCYL3                2.214087                                2.110741
# C1orf112             2.105242                                1.911024
#
#           amygdaloid complex  medial ganglionic eminence  \
# TSPAN6              4.171544                    4.605324
# TNMD                0.159660                    0.220311
# DPM1                4.125504                    4.344710
# SCYL3               1.685856                    2.034293
# C1orf112            1.473570                    2.002650
#
#           posterior (caudal) superior temporal cortex (area 22c)  \
# TSPAN6                                             4.208949
# TNMD                                               0.261020
# ...

# %% [markdown]
# # Normalize Matrix (z-score the rows)

# %%
uf.zscore(normalized_matrix, 'row')
# Out:
# Progress: 100%  38855 Out of 38855

# %%
normalized_matrix.head()
# Out:
#           occipital neocortex  primary motor-sensory cortex (samples)  \
# TSPAN6               2.481762                                1.964784
# TNMD                -1.050735                               -0.530026
# DPM1                 2.937816                                1.566944
# SCYL3                1.972960                                1.616378
# C1orf112             4.311829                                3.661702
#
#           amygdaloid complex  medial ganglionic eminence  \
# TSPAN6              1.592192                    2.089879
# TNMD                0.270423                    1.162692
# DPM1                1.222799                    1.745669
# SCYL3               0.150357                    1.352602
# C1orf112            2.197364                    3.968414
#
#           posterior (caudal) superior temporal cortex (area 22c)  \
# TSPAN6                                             1.635108
# TNMD                                               1.761577
# ...

# %% [markdown]
# # Merge Like Column (by taking the mean)

# %%
normalized_matrix = uf.merge(normalized_matrix, 'column', 'mean')

# %%
normalized_matrix.shape
# Out:
# (38855, 26)

# %% [markdown]
# # Map Gene Symbols To Up-to-date Approved Gene Symbols

# %%
uf.mapgenesymbols(normalized_matrix)
# Out:
# Progeres: 100%  38855 Out of 38855

# %%
normalized_matrix.shape
# Out:
# (23269, 26)

# %% [markdown]
# # Merge Duplicate Genes By Rows

# %%
normalized_matrix = uf.merge(normalized_matrix, 'row', 'mean')

# %%
normalized_matrix.shape
# Out:
# (22411, 26)

# %% [markdown]
# # Histogram of First Sample

# %%
normalized_matrix[normalized_matrix.columns[0]].hist(bins=100)

# %% [markdown]
# # Histogram of First Gene

# %%
normalized_matrix.loc[normalized_matrix.index[0]].hist(bins=50)

# %% [markdown]
# # Save Filtered Matrix

# %%
filename = path+'aba_dev_rnaseq_tish_matrix_filltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
normalized_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene List

# %%
gene_list = uf.createGeneList(normalized_matrix)
# Out:
# Progeres: 100%  22411 Out of 22411

# %%
gene_list.head()
# Out:
#      GeneSym       GeneID
# 0       A1BG            1
# 1       A1CF        29974
# 2        A2M            2
# 3      A2ML1       144568
# 4  A2ML1-AS1  1.00874e+08

# %%
gene_list.shape
# Out:
# (22411, 2)

# %% [markdown]
# # Save Gene List

# %%
filename = path+'aba_dev_rnaseq_tish_gene_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_list.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Attribute List

# %%
attribute_list = uf.createAttributeList(normalized_matrix)

# %%
attribute_list.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [amygdaloid complex, anterior (rostral) cingulate (medial prefrontal) cortex, caudal ganglionic eminence, cerebellar cortex, cerebellum]

# %%
attribute_list.shape
# Out:
# (26, 0)

# %% [markdown]
# # Save Attribute List

# %%
filename = path+'aba_dev_rnaseq_tish_attribute_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_list.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create matrix of Standardized values (values between -1, and 1)

# %%
standard_matrix = uf.createStandardizedMatrix(normalized_matrix)
# Out:
# Progeres: 100%  22411 Out of 22411

# %%
standard_matrix.head()
# Out:
#            amygdaloid complex  \
#
# A1BG                -0.116189
# A1CF                 0.114580
# A2M                  0.191503
# A2ML1                0.883811
# A2ML1-AS1            0.114580
#
#            anterior (rostral) cingulate (medial prefrontal) cortex  \
#
# A1BG                                               -0.193112
# A1CF                                                0.499196
# A2M                                                -0.116189
# A2ML1                                               0.191503
# A2ML1-AS1                                           0.037657
#
#            caudal ganglionic eminence  cerebellar cortex  cerebellum  \
#
# A1BG                        -0.423881           0.806888   -0.731574
# A1CF                         0.806888          -0.423881   -0.808497
# A2M                         -0.808497           0.653042   -0.577727
# A2ML1                       -0.423881          -0.193112   -0.346958
# ...

# %% [markdown]
# # Plot of A Single Celltype, Normalized Value vs. Standardized Value

# %%
plt.plot(normalized_matrix[normalized_matrix.columns[0]], standard_matrix[standard_matrix.columns[0]], 'bo')
plt.xlabel('Normalized Values')
plt.ylabel('Standardized Values')
plt.title(standard_matrix.columns[0])
plt.grid(True)

# %% [markdown]
# # Save Standardized Matrix

# %%
filename = path+'aba_dev_rnaseq_tish_standard_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
standard_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Tertiary Matrix

# %%
tertiary_matrix = uf.createTertiaryMatrix(standard_matrix)

# %%
tertiary_matrix.head()
# Out:
#            amygdaloid complex  \
#
# A1BG                        0
# A1CF                        0
# A2M                         0
# A2ML1                       0
# A2ML1-AS1                   0
#
#            anterior (rostral) cingulate (medial prefrontal) cortex  \
#
# A1BG                                                       0
# A1CF                                                       0
# A2M                                                        0
# A2ML1                                                      0
# A2ML1-AS1                                                  0
#
#            caudal ganglionic eminence  cerebellar cortex  cerebellum  \
#
# A1BG                                0                  0           0
# A1CF                                0                  0           0
# A2M                                 0                  0           0
# A2ML1                               0                  0           0
# ...

# %% [markdown]
# # Save Teriary Matrix

# %%
filename = path+'aba_dev_rnaseq_tish_tertiary_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
tertiary_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Up Gene Set Library

# %%
name = 'aba_dev_rnaseq_tish_gene_up_set'

# %%
uf.createUpGeneSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  26 Out of 26

# %% [markdown]
# # Create Down Gene Set Library

# %%
name = 'aba_dev_rnaseq_tish_gene_down_set'

# %%
uf.createDownGeneSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  26 Out of 26

# %% [markdown]
# # Create Up Attribute Library

# %%
name = 'aba_dev_rnaseq_tish_attribute_up_set'

# %%
uf.createUpAttributeSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  22411 Out of 22411

# %% [markdown]
# # Create Down Attribute Library

# %%
name = 'aba_dev_rnaseq_tish_attribute_down_set'

# %%
uf.createDownAttributeSetLib(tertiary_matrix, path, name)
# Out:
# Progeres: 100%  22411 Out of 22411

# %% [markdown]
# # Create Attribute Similarity Matrix

# %%
attribute_similarity_matix = uf.createSimilarityMatrix(normalized_matrix.T, 'cosine')

# %%
attribute_similarity_matix.head()
# Out:
#                                                     amygdaloid complex  \
#
# amygdaloid complex                                            1.000000
# anterior (rostral) cingulate (medial prefrontal...            0.277047
# caudal ganglionic eminence                                    0.434164
# cerebellar cortex                                             0.126411
# cerebellum                                                    0.163708
#
#                                                     anterior (rostral) cingulate (medial prefrontal) cortex  \
#
# amygdaloid complex                                                                           0.277047
# anterior (rostral) cingulate (medial prefrontal...                                           1.000000
# caudal ganglionic eminence                                                                   0.341961
# cerebellar cortex                                                                            0.092896
# ...

# %% [markdown]
# # Save Attribute Similarity Matrix

# %%
filename = path+'aba_dev_rnaseq_tish_attribute_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %%
net.load_df(attribute_similarity_matix.iloc[:,:].copy())
# net.filter_N_top('row', rank_type='sum', N_top=300)
net.cluster()
net.widget()

# %% [markdown]
# # Create Gene Similarity Matrix

# %%
gene_similarity_matix = uf.createSimilarityMatrix(normalized_matrix, 'cosine')

# %%
gene_similarity_matix.head()
# Out:
#                A1BG      A1CF       A2M     A2ML1  A2ML1-AS1     A2MP1  \
#
# A1BG       1.000000 -0.077376  0.774587  0.552796  -0.731122  0.378709
# A1CF      -0.077376  1.000000 -0.243646 -0.013923   0.252110 -0.313704
# A2M        0.774587 -0.243646  1.000000  0.475745  -0.824355  0.559533
# A2ML1      0.552796 -0.013923  0.475745  1.000000  -0.321323  0.133461
# A2ML1-AS1 -0.731122  0.252110 -0.824355 -0.321323   1.000000 -0.272888
#
#             A3GALT2    A4GALT     A4GNT      AAAS    ...       ZWILCH  \
#                                                      ...
# A1BG      -0.375720  0.528501  0.151519 -0.736049    ...    -0.825638
# A1CF       0.252849 -0.232666  0.144711  0.156084    ...     0.227134
# A2M       -0.245393  0.482553 -0.042929 -0.865800    ...    -0.972636
# A2ML1     -0.225419  0.834400  0.169595 -0.586570    ...    -0.548816
# A2ML1-AS1  0.320648 -0.421463 -0.170538  0.583987    ...     0.809921
#
# ...

# %% [markdown]
# # Save Gene Similarity Matrix

# %%
filename = path+'aba_dev_rnaseq_tish_gene_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene-Attribute Edge List

# %%
name = 'aba_dev_rnaseq_tish_gene_attribute_edge_list'

# %%
uf.createGeneAttributeEdgeList(standard_matrix, attribute_list, gene_list, path, name)
# Out:
# Progeres: 100%  26 Out of 26
#
#  The number of statisticaly relevent gene-attribute associations is: 44822
