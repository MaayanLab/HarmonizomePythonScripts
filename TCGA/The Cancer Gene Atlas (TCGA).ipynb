# %% [markdown]
# # The Cancer Gene Atlas (TCGA)

# %% [markdown]
# Author: Moshe Silverstein <br/>
# Date: 7-17 <br/>
# Data Source: https://cancergenome.nih.gov/

# %%
import sys, datetime, os
import numpy as np
import pandas as pd
import importlib
import my_functions as mf
# %matplotlib inline

# %% [markdown]
# # Functions

# %%
def getGenes(inputDF):
    
    inputDF.reset_index(inplace=True)
    
    inputDF.rename(columns={'index':'Gene Symbol'}, inplace=True)

    inputDF.set_index('Gene Symbol', inplace=True)

    lst = []

    for index in  inputDF.index:
        lst.append(index.split('|')[5])

    inputDF.index = lst

# %%
def getSampleData(inputDF, metaDF):
    
    lst = []

    for i,col in enumerate(inputDF.columns):

        progressPercent = ((i+1)/len(inputDF.columns))*100

        sys.stdout.write("Progress: %d%%  %d Out of %d   \r" % (progressPercent, (i+1), len(inputDF.columns)))
        sys.stdout.flush()
        
        ID = ('-').join(meta.ix[col, 'a_AliquotBarcode'].split('-')[0:3])
        
        donor = 'Donor:'+ID
        
        if ID in metaDF.index:
            gender = 'Gender:'+metaDF.ix[ID, 'gender']
            if type(metaDF.ix[ID, 'ethnicity']) != float:
                ethnicity = 'Ethnicity:'+metaDF.ix[ID, 'ethnicity']
            else:
                ethnicity = 'Ethnicity:NA'
            if type(metaDF.ix[ID, 'tumor_tissue_site']) != float:    
                tissue = 'Tissue:'+metaDF.ix[ID, 'tumor_tissue_site']
            else:
                ethnicity = 'Tissue:NA'
        else:
            gender = 'Gender:NA'
            ethnicity = 'Ethnicity:NA'
            tissue = 'Tissue:NA'
        tumor = 'Tumor:'+meta.ix[col, 'b_disease']
         
        lst.append(tuple((donor, gender, ethnicity,tissue, tumor)))

        
    inputDF.columns = lst

# %%
def dropZeroExpressGenes(inputDF):

    inputDF.replace(0, np.nan, inplace=True)

    inputDF.dropna(thresh=(0.05*inputDF.shape[1]), axis=0, inplace=True)

    inputDF.replace(np.nan, 0, inplace=True)

# %% [markdown]
# # Load MetaData

# %%
meta = pd.read_csv('Input/TCGA_Metadata.csv', index_col=9)

# %%
meta.head()
# Out:
#                                                   a_AliquotBarcode b_disease  \
# a_CGHubAnalysisID
# 3a8e6a74-137f-468f-8987-fa0acdde2836  TCGA-CS-6188-01A-11R-1896-07       LGG
# c63d44f1-c9ad-4391-b1aa-0feb3713441b  TCGA-EO-A22Y-01A-11R-A180-07      UCEC
# 21912089-1e42-4bcc-9ad9-fe9a9b88fb09  TCGA-94-A5I4-01A-11R-A26W-07      LUSC
# 6b86e544-0372-434a-9f28-6fa4075dd228  TCGA-N5-A4RV-01A-21R-A28V-07       UCS
# 30518eb4-2783-4988-bcd4-36a1a8bb4dfa  TCGA-BK-A56F-01A-32R-A27V-07      UCEC
#
#                                       a_objectSizeBytes b_uploaded b_state  \
# a_CGHubAnalysisID
# 3a8e6a74-137f-468f-8987-fa0acdde2836         6354301047  8/14/2013    Live
# c63d44f1-c9ad-4391-b1aa-0feb3713441b         5497637066  8/29/2013    Live
# 21912089-1e42-4bcc-9ad9-fe9a9b88fb09         4600317850  8/29/2013    Live
# 6b86e544-0372-434a-9f28-6fa4075dd228         4964387768  8/30/2013    Live
# 30518eb4-2783-4988-bcd4-36a1a8bb4dfa         5668623460  8/31/2013    Live
#
#                                      b_library_type  b_center b_assembly  \
# a_CGHubAnalysisID
# 3a8e6a74-137f-468f-8987-fa0acdde2836        RNA-Seq  UNC-LCCC  unaligned
# c63d44f1-c9ad-4391-b1aa-0feb3713441b        RNA-Seq  UNC-LCCC  unaligned
# 21912089-1e42-4bcc-9ad9-fe9a9b88fb09        RNA-Seq  UNC-LCCC  unaligned
# 6b86e544-0372-434a-9f28-6fa4075dd228        RNA-Seq  UNC-LCCC  unaligned
# 30518eb4-2783-4988-bcd4-36a1a8bb4dfa        RNA-Seq  UNC-LCCC  unaligned
#
#                                                                             a_GCSobject
# a_CGHubAnalysisID
# 3a8e6a74-137f-468f-8987-fa0acdde2836  gs://5aa919de-0aa0-43ec-9ec3-288481102b6d/tcga...
# c63d44f1-c9ad-4391-b1aa-0feb3713441b  gs://5aa919de-0aa0-43ec-9ec3-288481102b6d/tcga...
# 21912089-1e42-4bcc-9ad9-fe9a9b88fb09  gs://5aa919de-0aa0-43ec-9ec3-288481102b6d/tcga...
# 6b86e544-0372-434a-9f28-6fa4075dd228  gs://5aa919de-0aa0-43ec-9ec3-288481102b6d/tcga...
# 30518eb4-2783-4988-bcd4-36a1a8bb4dfa  gs://5aa919de-0aa0-43ec-9ec3-288481102b6d/tcga...

# %%
meta.shape
# Out:
# (11373, 9)

# %% [markdown]
# # Load Data (mapping to approved gene symbols and merging duplicate genes)

# %%
matrix = pd.DataFrame()


count = 0
for filename in os.listdir('Input'):
    if '.tsv' in filename:
        count +=1 
i = 0
for filename in os.listdir('Input'):
    if '.tsv' in filename:
        i += 1
        progressPercent = ((i)/count)*100

        sys.stdout.write("Progress: %d%%  %d Out of %d   \r" % (progressPercent, (i), count))
        sys.stdout.flush()
        
        temp = pd.read_csv('Input/'+filename, sep='\t', index_col=0)
        
        # Set Index To Only Show Gene Symbols 
        getGenes(temp)
        
        # Map Gene Symbols To Up-to-date Approved Gene Symbols
        mf.mapgenesymbols(temp)
        
        # Merge Duplicate Genes By Rows
        temp = mf.merge(temp, 'row', 'mean')
        
        matrix = pd.concat([matrix, temp], axis=1)
# Out:
# Progeres: 99%  198691 Out of 199169
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
# Progeres: 99%  199074 Out of 199169
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
# Progeres: 99%  198710 Out of 199169
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.

# %%
matrix.head()
# Out:
#           ca6d9c83-f6bc-474a-a87a-04a8d64f6752  \
# index
# A1BG                                  0.514213
# A1BG-AS1                              0.081734
# A1CF                                  0.002684
# A2M                                   5.012012
# A2M-AS1                               1.514880
#
#           e6f11961-dfda-4c6e-b051-54b27ad9d0de  \
# index
# A1BG                                  1.307944
# A1BG-AS1                              0.098419
# A1CF                                  0.001379
# A2M                                   7.384641
# A2M-AS1                               0.996223
#
#           25de321c-8ad7-4882-8c04-056649e9b4e5  \
# index
# A1BG                                  1.302080
# A1BG-AS1                              0.090536
# A1CF                                  0.001749
# A2M                                   3.538513
# A2M-AS1                               1.652150
#
#           80653994-a361-4e45-b044-502ce874a9d8  \
# index
# A1BG                                  0.380000
# A1BG-AS1                              0.064848
# A1CF                                  0.007381
# A2M                                  15.682749
# A2M-AS1                               1.245620
#
#           8c0b0a9b-6066-4bc3-8f09-1e0454e8b8a3  \
# index
# A1BG                                  0.866746
# A1BG-AS1                              0.105425
# A1CF                                  0.002376
# A2M                                   6.464579
# A2M-AS1                               1.672230
#
#           ec870197-fd7c-405b-bcdf-03c309ed4274  \
# index
# A1BG                                  4.858427
# A1BG-AS1                              0.590316
# A1CF                                  0.012596
# A2M                                  11.328956
# A2M-AS1                               0.238829
#
#           f33c9ee1-d32c-4606-b264-99bcd01e2059  \
# index
# A1BG                                 11.294831
# A1BG-AS1                              0.566710
# A1CF                                  0.000682
# A2M                                   8.117481
# A2M-AS1                               0.230361
#
#           0009f27d-a053-49b0-a030-ba9c1469224f  \
# index
# A1BG                                 29.502162
# A1BG-AS1                              2.382888
# A1CF                                  0.002707
# A2M                                   5.609811
# A2M-AS1                               0.213854
#
#           9b75d36c-9d68-45c1-8a47-bde800bf287e  \
# index
# A1BG                                 39.405359
# A1BG-AS1                              2.075218
# A1CF                                  0.000280
# A2M                                   4.624590
# A2M-AS1                               0.217506
#
#           8e4b078b-e6f7-4424-95fd-51a550203835  \
# index
# A1BG                                  3.334072
# A1BG-AS1                              0.579593
# A1CF                                  0.070824
# A2M                                 313.991266
# A2M-AS1                               3.778770
#
#                           ...                   \
# index                     ...
# A1BG                      ...
# A1BG-AS1                  ...
# A1CF                      ...
# A2M                       ...
# A2M-AS1                   ...
#
#           590edf46-250f-45e5-9080-a95b0d85b47f  \
# index
# A1BG                                  5.456438
# A1BG-AS1                              0.865216
# A1CF                                  0.001318
# A2M                                  75.680612
# A2M-AS1                               2.421480
#
#           5189ff30-67eb-407e-b481-9426eca96908  \
# index
# A1BG                                  2.607938
# A1BG-AS1                              0.353622
# A1CF                                  0.000529
# A2M                                  52.973476
# A2M-AS1                               5.127180
#
#           50cc07f8-cd48-4d6c-9a0f-5c777cf32366  \
# index
# A1BG                                  6.164272
# A1BG-AS1                              0.467968
# A1CF                                  0.000238
# A2M                                  21.599688
# A2M-AS1                               4.456640
#
#           7fd637fc-6d56-4de1-84b4-dd0460c95edd  \
# index
# A1BG                                  9.467584
# A1BG-AS1                              0.596158
# A1CF                                  0.001055
# A2M                                  23.991228
# A2M-AS1                               2.037300
#
#           cfea40ed-d73b-4052-84a5-cf228f9af854  \
# index
# A1BG                                  4.933950
# A1BG-AS1                              0.665443
# A1CF                                  0.000797
# A2M                                  72.393899
# A2M-AS1                               1.756160
#
#           4b1d4b71-b78f-4c33-8dc9-7120894f5b9e  \
# index
# A1BG                                  2.281260
# A1BG-AS1                              0.131770
# A1CF                                  0.000000
# A2M                                  36.401848
# A2M-AS1                               1.367970
#
#           6b894228-ed7f-4907-ad92-a95cb3293a26  \
# index
# A1BG                                  3.737174
# A1BG-AS1                              0.947740
# A1CF                                  0.000952
# A2M                                  93.168460
# A2M-AS1                               2.372430
#
#           fceac077-5a7b-4bdf-a7fa-f937342c85d6  \
# index
# A1BG                                  7.301709
# A1BG-AS1                              0.913018
# A1CF                                  0.000000
# A2M                                  13.819997
# A2M-AS1                               2.405660
#
#           b863da66-25c4-43f7-bd2a-4737095c8fc9  \
# index
# A1BG                                  9.044614
# A1BG-AS1                              1.152430
# A1CF                                  0.002568
# A2M                                 104.625704
# A2M-AS1                               2.722360
#
#           dba72b72-e7ab-4971-8e01-3b130d235924
# index
# A1BG                                  5.810413
# A1BG-AS1                              0.813726
# A1CF                                  0.000529
# A2M                                 134.418843
# A2M-AS1                               1.572680
#
# [5 rows x 11373 columns]

# %%
matrix.shape
# Out:
# (35402, 11373)

# %% [markdown]
# # Load Sample MetaData

# %%
sample_meta = pd.DataFrame()


count = 0
for filename in os.listdir('Input'):
    if 'metadata_' in filename:
        count +=1 
i = 0
for filename in os.listdir('Input'):
    if 'metadata_' in filename:
        i += 1
        progressPercent = ((i)/count)*100

        sys.stdout.write("Progress: %d%%  %d Out of %d   \r" % (progressPercent, (i), count))
        sys.stdout.flush()
        
        temp = pd.read_csv('Input/'+filename, sep='\t', index_col=0)
        
        sample_meta = pd.concat([sample_meta, temp])
# Out:
# Progress: 100%  33 Out of 33

# %%
sample_meta.set_index('ParticipantBarcode', inplace=True)

# %%
sample_meta.head()
# Out:
#                    Study Project                       ParticipantUUID  \
# ParticipantBarcode
# TCGA-OR-A5K3         ACC    TCGA  C72B973B-4719-46AB-AC99-05D14088D3BC
# TCGA-OR-A5KV         ACC    TCGA  202F7A77-9E5A-4F12-8FFE-78AE5527A746
# TCGA-OR-A5L5         ACC    TCGA  2F04E760-8A64-49F2-A1D6-3D390604745C
# TCGA-OR-A5KX         ACC    TCGA  33C02ECE-911B-4F45-B410-9DF07E9B189E
# TCGA-OR-A5JB         ACC    TCGA  D63F2F1E-1970-445F-907B-23CF4D9EFD83
#
#                    TSSCode  age_at_initial_pathologic_diagnosis  \
# ParticipantBarcode
# TCGA-OR-A5K3            OR                                 53.0
# TCGA-OR-A5KV            OR                                 17.0
# TCGA-OR-A5L5            OR                                 77.0
# TCGA-OR-A5KX            OR                                 25.0
# TCGA-OR-A5JB            OR                                 52.0
#
#                    anatomic_neoplasm_subdivision  batch_number  \
# ParticipantBarcode
# TCGA-OR-A5K3                                 NaN         304.0
# TCGA-OR-A5KV                                 NaN         304.0
# TCGA-OR-A5L5                                 NaN         304.0
# TCGA-OR-A5KX                                 NaN         304.0
# TCGA-OR-A5JB                                 NaN         304.0
#
#                                                bcr clinical_M clinical_N  \
# ParticipantBarcode
# TCGA-OR-A5K3        Nationwide Children's Hospital         M0        NaN
# TCGA-OR-A5KV        Nationwide Children's Hospital         M0        NaN
# TCGA-OR-A5L5        Nationwide Children's Hospital         M0        NaN
# TCGA-OR-A5KX        Nationwide Children's Hospital         M0        NaN
# TCGA-OR-A5JB        Nationwide Children's Hospital         M1        NaN
#
#                                 ...               BMI  \
# ParticipantBarcode              ...
# TCGA-OR-A5K3                    ...               NaN
# TCGA-OR-A5KV                    ...               NaN
# TCGA-OR-A5L5                    ...               NaN
# TCGA-OR-A5KX                    ...               NaN
# TCGA-OR-A5JB                    ...               NaN
#
#                    age_began_smoking_in_years h_pylori_infection  \
# ParticipantBarcode
# TCGA-OR-A5K3                              NaN                NaN
# TCGA-OR-A5KV                              NaN                NaN
# TCGA-OR-A5L5                              NaN                NaN
# TCGA-OR-A5KX                              NaN                NaN
# TCGA-OR-A5JB                              NaN                NaN
#
#                                                             other_dx  \
# ParticipantBarcode
# TCGA-OR-A5K3                                                      No
# TCGA-OR-A5KV                                                      No
# TCGA-OR-A5L5        Yes, History of Synchronous/Bilateral Malignancy
# TCGA-OR-A5KX                                                      No
# TCGA-OR-A5JB                                                      No
#
#                    other_malignancy_anatomic_site  \
# ParticipantBarcode
# TCGA-OR-A5K3                                  NaN
# TCGA-OR-A5KV                                  NaN
# TCGA-OR-A5L5                                Ovary
# TCGA-OR-A5KX                                  NaN
# TCGA-OR-A5JB                                  NaN
#
#                     other_malignancy_histological_type  \
# ParticipantBarcode
# TCGA-OR-A5K3                                       NaN
# TCGA-OR-A5KV                                       NaN
# TCGA-OR-A5L5                            Other, specify
# TCGA-OR-A5KX                                       NaN
# TCGA-OR-A5JB                                       NaN
#
#                     other_malignancy_malignancy_type  stopped_smoking_year  \
# ParticipantBarcode
# TCGA-OR-A5K3                                     NaN                   NaN
# TCGA-OR-A5KV                                     NaN                   NaN
# TCGA-OR-A5L5                  Synchronous Malignancy                   NaN
# TCGA-OR-A5KX                                     NaN                   NaN
# TCGA-OR-A5JB                                     NaN                   NaN
#
#                     venous_invasion  year_of_tobacco_smoking_onset
# ParticipantBarcode
# TCGA-OR-A5K3                    NaN                            NaN
# TCGA-OR-A5KV                    NaN                            NaN
# TCGA-OR-A5L5                    NaN                            NaN
# TCGA-OR-A5KX                    NaN                            NaN
# TCGA-OR-A5JB                    NaN                            NaN
#
# [5 rows x 69 columns]

# %%
sample_meta.shape
# Out:
# (10960, 69)

# %% [markdown]
# ## Map Sample Metadata to Sample ID

# %%
getSampleData(matrix, sample_meta)
# Out:
# Progress: 100%  11373 Out of 11373

# %%
matrix.head()
# Out:
#           (Donor:TCGA-OR-A5JG, Gender:MALE, Ethnicity:NA, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                               0.514213
# A1BG-AS1                                           0.081734
# A1CF                                               0.002684
# A2M                                                5.012012
# A2M-AS1                                            1.514880
#
#           (Donor:TCGA-OR-A5LG, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                               1.307944
# A1BG-AS1                                           0.098419
# A1CF                                               0.001379
# A2M                                                7.384641
# A2M-AS1                                            0.996223
#
#           (Donor:TCGA-OR-A5JD, Gender:FEMALE, Ethnicity:NA, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                               1.302080
# A1BG-AS1                                           0.090536
# A1CF                                               0.001749
# A2M                                                3.538513
# A2M-AS1                                            1.652150
#
#           (Donor:TCGA-OR-A5LH, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                               0.380000
# A1BG-AS1                                           0.064848
# A1CF                                               0.007381
# A2M                                               15.682749
# A2M-AS1                                            1.245620
#
#           (Donor:TCGA-OR-A5KY, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                               0.866746
# A1BG-AS1                                           0.105425
# A1CF                                               0.002376
# A2M                                                6.464579
# A2M-AS1                                            1.672230
#
#           (Donor:TCGA-PK-A5HB, Gender:MALE, Ethnicity:NA, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                               4.858427
# A1BG-AS1                                           0.590316
# A1CF                                               0.012596
# A2M                                               11.328956
# A2M-AS1                                            0.238829
#
#           (Donor:TCGA-PK-A5HA, Gender:MALE, Ethnicity:NA, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                              11.294831
# A1BG-AS1                                           0.566710
# A1CF                                               0.000682
# A2M                                                8.117481
# A2M-AS1                                            0.230361
#
#           (Donor:TCGA-OR-A5KX, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                              29.502162
# A1BG-AS1                                           2.382888
# A1CF                                               0.002707
# A2M                                                5.609811
# A2M-AS1                                            0.213854
#
#           (Donor:TCGA-PK-A5H8, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                              39.405359
# A1BG-AS1                                           2.075218
# A1CF                                               0.000280
# A2M                                                4.624590
# A2M-AS1                                            0.217506
#
#           (Donor:TCGA-PK-A5H9, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Adrenal, Tumor:ACC)  \
# index
# A1BG                                               3.334072
# A1BG-AS1                                           0.579593
# A1CF                                               0.070824
# A2M                                              313.991266
# A2M-AS1                                            3.778770
#
#                                                        ...                                                \
# index                                                  ...
# A1BG                                                   ...
# A1BG-AS1                                               ...
# A1CF                                                   ...
# A2M                                                    ...
# A2M-AS1                                                ...
#
#           (Donor:TCGA-V4-A9EX, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               5.456438
# A1BG-AS1                                           0.865216
# A1CF                                               0.001318
# A2M                                               75.680612
# A2M-AS1                                            2.421480
#
#           (Donor:TCGA-V4-A9EO, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               2.607938
# A1BG-AS1                                           0.353622
# A1CF                                               0.000529
# A2M                                               52.973476
# A2M-AS1                                            5.127180
#
#           (Donor:TCGA-VD-A8KO, Gender:MALE, Ethnicity:NA, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               6.164272
# A1BG-AS1                                           0.467968
# A1CF                                               0.000238
# A2M                                               21.599688
# A2M-AS1                                            4.456640
#
#           (Donor:TCGA-YZ-A983, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               9.467584
# A1BG-AS1                                           0.596158
# A1CF                                               0.001055
# A2M                                               23.991228
# A2M-AS1                                            2.037300
#
#           (Donor:TCGA-V4-A9EW, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               4.933950
# A1BG-AS1                                           0.665443
# A1CF                                               0.000797
# A2M                                               72.393899
# A2M-AS1                                            1.756160
#
#           (Donor:TCGA-V4-A9EQ, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               2.281260
# A1BG-AS1                                           0.131770
# A1CF                                               0.000000
# A2M                                               36.401848
# A2M-AS1                                            1.367970
#
#           (Donor:TCGA-V4-A9EV, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               3.737174
# A1BG-AS1                                           0.947740
# A1CF                                               0.000952
# A2M                                               93.168460
# A2M-AS1                                            2.372430
#
#           (Donor:TCGA-V4-A9EY, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               7.301709
# A1BG-AS1                                           0.913018
# A1CF                                               0.000000
# A2M                                               13.819997
# A2M-AS1                                            2.405660
#
#           (Donor:TCGA-V4-A9EU, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)  \
# index
# A1BG                                               9.044614
# A1BG-AS1                                           1.152430
# A1CF                                               0.002568
# A2M                                              104.625704
# A2M-AS1                                            2.722360
#
#           (Donor:TCGA-V4-A9EM, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Choroid, Tumor:UVM)
# index
# A1BG                                               5.810413
# A1BG-AS1                                           0.813726
# A1CF                                               0.000529
# A2M                                              134.418843
# A2M-AS1                                            1.572680
#
# [5 rows x 11373 columns]

# %% [markdown]
# ## Merge Like Column (by taking the mean)

# %%
matrix = mf.merge(matrix, 'column', 'mean')

# %%
matrix.shape
# Out:
# (35402, 10420)

# %% [markdown]
# ## Drop Any Genes That Have Zero Expression Across 95% Of The Samples

# %%
dropZeroExpressGenes(matrix)

# %%
matrix.shape
# Out:
# (31116, 10420)

# %% [markdown]
# # Merge Duplicate genes (by taking the mean)

# %%
matrix = mf.merge(matrix, 'row', 'mean')

# %%
matrix.shape
# Out:
# (31116, 10420)

# %% [markdown]
# ## Save Unfiltered Matrix To File

# %%
filename = '~/./Documents/Harmonizome/TCGA/Output/tcga_matrix_unfilltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Normalize Matrix (Quantile Normalize the matrix for the columns)

# %%
normalized_matrix = mf.quantileNormalize(matrix)
# Out:
# Step 2/2 progress: 100%  10420 Out of 10420

# %%
normalized_matrix.head()
# Out:
#           (Donor:TCGA-02-0047, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                               3.500122
# A1BG-AS1                                           0.448939
# A1CF                                               0.007353
# A2M                                               42.577243
# A2M-AS1                                            3.325177
#
#           (Donor:TCGA-02-0055, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                               8.551152
# A1BG-AS1                                           0.744276
# A1CF                                               0.008785
# A2M                                               35.134520
# A2M-AS1                                            1.961738
#
#           (Donor:TCGA-02-2483, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                               7.605301
# A1BG-AS1                                           0.647442
# A1CF                                               0.011610
# A2M                                               20.053129
# A2M-AS1                                            0.538191
#
#           (Donor:TCGA-02-2485, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                               1.233906
# A1BG-AS1                                           0.198097
# A1CF                                               0.000000
# A2M                                                7.621996
# A2M-AS1                                            0.303942
#
#           (Donor:TCGA-02-2486, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                               2.542070
# A1BG-AS1                                           0.439716
# A1CF                                               0.014865
# A2M                                               33.999556
# A2M-AS1                                            1.327171
#
#           (Donor:TCGA-04-1331, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                               4.755987
# A1BG-AS1                                           0.776454
# A1CF                                               0.003085
# A2M                                                9.872400
# A2M-AS1                                            0.979255
#
#           (Donor:TCGA-04-1332, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                               1.311879
# A1BG-AS1                                           0.079355
# A1CF                                               0.001159
# A2M                                               12.457361
# A2M-AS1                                            2.272350
#
#           (Donor:TCGA-04-1337, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                               2.923073
# A1BG-AS1                                           0.516571
# A1CF                                               0.001148
# A2M                                                5.661991
# A2M-AS1                                            0.626972
#
#           (Donor:TCGA-04-1338, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                               3.120143
# A1BG-AS1                                           0.399217
# A1CF                                               0.010473
# A2M                                                4.915035
# A2M-AS1                                            1.201560
#
#           (Donor:TCGA-04-1341, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                               7.731534
# A1BG-AS1                                           0.447006
# A1CF                                               0.008235
# A2M                                                2.731184
# A2M-AS1                                            1.603376
#
#                                                          ...                                                  \
# index                                                    ...
# A1BG                                                     ...
# A1BG-AS1                                                 ...
# A1CF                                                     ...
# A2M                                                      ...
# A2M-AS1                                                  ...
#
#           (Donor:TCGA-ZP-A9D4, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                             266.051601
# A1BG-AS1                                           0.469845
# A1CF                                               4.586558
# A2M                                                6.772024
# A2M-AS1                                            1.828706
#
#           (Donor:TCGA-ZQ-A9CR, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Stomach, Tumor:STAD)  \
# index
# A1BG                                               1.664587
# A1BG-AS1                                           0.108267
# A1CF                                               0.134291
# A2M                                               22.397889
# A2M-AS1                                            1.424396
#
#           (Donor:TCGA-ZR-A9CJ, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Esophagus, Tumor:ESCA)  \
# index
# A1BG                                               1.545757
# A1BG-AS1                                           0.313376
# A1CF                                               0.113927
# A2M                                               25.474237
# A2M-AS1                                            0.495803
#
#           (Donor:TCGA-ZS-A9CD, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                             367.978589
# A1BG-AS1                                           0.464896
# A1CF                                               3.874013
# A2M                                               50.460718
# A2M-AS1                                            2.168734
#
#           (Donor:TCGA-ZS-A9CE, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                             519.380496
# A1BG-AS1                                           0.769626
# A1CF                                               5.838722
# A2M                                               14.484341
# A2M-AS1                                            1.351711
#
#           (Donor:TCGA-ZS-A9CF, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                              62.137046
# A1BG-AS1                                           0.139140
# A1CF                                               5.366094
# A2M                                               23.892089
# A2M-AS1                                            1.257526
#
#           (Donor:TCGA-ZS-A9CG, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                              95.029660
# A1BG-AS1                                           0.287323
# A1CF                                               6.666369
# A2M                                                8.559427
# A2M-AS1                                            1.583657
#
#           (Donor:TCGA-ZT-A8OM, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Anterior Mediastinum, Tumor:THYM)  \
# index
# A1BG                                              36.998568
# A1BG-AS1                                           1.612295
# A1CF                                               0.000000
# A2M                                               29.810896
# A2M-AS1                                            1.077171
#
#           (Donor:TCGA-ZU-A8S4, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Bile duct, Tumor:CHOL)  \
# index
# A1BG                                             190.403966
# A1BG-AS1                                           0.107904
# A1CF                                               2.034771
# A2M                                               24.612049
# A2M-AS1                                            1.133465
#
#           (Donor:TCGA-ZX-AA5X, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Cervical, Tumor:CESC)
# index
# A1BG                                               1.848744
# A1BG-AS1                                           0.390266
# A1CF                                               0.015038
# A2M                                                8.723992
# A2M-AS1                                            0.407444
#
# [5 rows x 10420 columns]

# %% [markdown]
# # Nomalize Matrix (z-score the rows)

# %%
mf.zscore(normalized_matrix, 'row')
# Out:
# Progress: 100%  31116 Out of 31116

# %%
normalized_matrix.head()
# Out:
#           (Donor:TCGA-02-0047, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                              -0.147700
# A1BG-AS1                                          -0.015040
# A1CF                                              -0.272337
# A2M                                                0.861379
# A2M-AS1                                            1.696066
#
#           (Donor:TCGA-02-0055, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                              -0.059286
# A1BG-AS1                                           0.694900
# A1CF                                              -0.270865
# A2M                                                0.605322
# A2M-AS1                                            0.622286
#
#           (Donor:TCGA-02-2483, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                              -0.075842
# A1BG-AS1                                           0.462127
# A1CF                                              -0.267962
# A2M                                                0.086467
# A2M-AS1                                           -0.498832
#
#           (Donor:TCGA-02-2485, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                              -0.187369
# A1BG-AS1                                          -0.618019
# A1CF                                              -0.279893
# A2M                                               -0.341210
# A2M-AS1                                           -0.683316
#
#           (Donor:TCGA-02-2486, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                              -0.164470
# A1BG-AS1                                          -0.037209
# A1CF                                              -0.264617
# A2M                                                0.566275
# A2M-AS1                                            0.122531
#
#           (Donor:TCGA-04-1331, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                              -0.125717
# A1BG-AS1                                           0.772250
# A1CF                                              -0.276723
# A2M                                               -0.263788
# A2M-AS1                                           -0.151471
#
#           (Donor:TCGA-04-1332, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                              -0.186004
# A1BG-AS1                                          -0.903456
# A1CF                                              -0.278702
# A2M                                               -0.174856
# A2M-AS1                                            0.866909
#
#           (Donor:TCGA-04-1337, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                              -0.157801
# A1BG-AS1                                           0.147536
# A1CF                                              -0.278713
# A2M                                               -0.408641
# A2M-AS1                                           -0.428913
#
#           (Donor:TCGA-04-1338, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                              -0.154351
# A1BG-AS1                                          -0.134561
# A1CF                                              -0.269130
# A2M                                               -0.434339
# A2M-AS1                                            0.023606
#
#           (Donor:TCGA-04-1341, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                              -0.073632
# A1BG-AS1                                          -0.019686
# A1CF                                              -0.271430
# A2M                                               -0.509472
# A2M-AS1                                            0.340057
#
#                                                          ...                                                  \
# index                                                    ...
# A1BG                                                     ...
# A1BG-AS1                                                 ...
# A1CF                                                     ...
# A2M                                                      ...
# A2M-AS1                                                  ...
#
#           (Donor:TCGA-ZP-A9D4, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                               4.448064
# A1BG-AS1                                           0.035215
# A1CF                                               4.433518
# A2M                                               -0.370452
# A2M-AS1                                            0.517516
#
#           (Donor:TCGA-ZQ-A9CR, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Stomach, Tumor:STAD)  \
# index
# A1BG                                              -0.179830
# A1BG-AS1                                          -0.833956
# A1CF                                              -0.141888
# A2M                                                0.167135
# A2M-AS1                                            0.199101
#
#           (Donor:TCGA-ZR-A9CJ, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Esophagus, Tumor:ESCA)  \
# index
# A1BG                                              -0.181910
# A1BG-AS1                                          -0.340908
# A1CF                                              -0.162816
# A2M                                                0.272973
# A2M-AS1                                           -0.532215
#
#           (Donor:TCGA-ZS-A9CD, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                               6.232219
# A1BG-AS1                                           0.023318
# A1CF                                               3.701266
# A2M                                                1.132599
# A2M-AS1                                            0.785306
#
#           (Donor:TCGA-ZS-A9CE, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                               8.882395
# A1BG-AS1                                           0.755837
# A1CF                                               5.720314
# A2M                                               -0.105120
# A2M-AS1                                            0.141857
#
#           (Donor:TCGA-ZS-A9CF, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                               0.878695
# A1BG-AS1                                          -0.759742
# A1CF                                               5.234614
# A2M                                                0.218541
# A2M-AS1                                            0.067682
#
#           (Donor:TCGA-ZS-A9CG, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                               1.454455
# A1BG-AS1                                          -0.403536
# A1CF                                               6.570852
# A2M                                               -0.308959
# A2M-AS1                                            0.324527
#
#           (Donor:TCGA-ZT-A8OM, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Anterior Mediastinum, Tumor:THYM)  \
# index
# A1BG                                               0.438665
# A1BG-AS1                                           2.781467
# A1CF                                              -0.279893
# A2M                                                0.422170
# A2M-AS1                                           -0.074357
#
#           (Donor:TCGA-ZU-A8S4, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Bile duct, Tumor:CHOL)  \
# index
# A1BG                                               3.123910
# A1BG-AS1                                          -0.834828
# A1CF                                               1.811154
# A2M                                                0.243310
# A2M-AS1                                           -0.030023
#
#           (Donor:TCGA-ZX-AA5X, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Cervical, Tumor:CESC)
# index
# A1BG                                              -0.176606
# A1BG-AS1                                          -0.156078
# A1CF                                              -0.264439
# A2M                                               -0.303297
# A2M-AS1                                           -0.601803
#
# [5 rows x 10420 columns]

# %% [markdown]
# ## Save Filtered Matrix

# %%
filename = '~/./Documents/Harmonizome/TCGA/Output/tcga_matrix_filltered_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
normalized_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Tertiary Matrix

# %%
tertiary_matrix = mf.createTertiaryMarix(normalized_matrix)
# Out:
# Progeres: 100%  10420 Out of 10420

# %%
tertiary_matrix.head()
# Out:
#           (Donor:TCGA-02-0047, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     1.0
# A2M-AS1                                                 1.0
#
#           (Donor:TCGA-02-0055, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                1.0
# A1CF                                                    0.0
# A2M                                                     1.0
# A2M-AS1                                                 1.0
#
#           (Donor:TCGA-02-2483, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-02-2485, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                               -1.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                -1.0
#
#           (Donor:TCGA-02-2486, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Brain, Tumor:GBM)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-04-1331, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-04-1332, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                               -1.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 1.0
#
#           (Donor:TCGA-04-1337, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-04-1338, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-04-1341, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Ovary, Tumor:OV)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#                                                          ...                                                  \
# index                                                    ...
# A1BG                                                     ...
# A1BG-AS1                                                 ...
# A1CF                                                     ...
# A2M                                                      ...
# A2M-AS1                                                  ...
#
#           (Donor:TCGA-ZP-A9D4, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                                    1.0
# A1BG-AS1                                                0.0
# A1CF                                                    1.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZQ-A9CR, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Stomach, Tumor:STAD)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                               -1.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZR-A9CJ, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Esophagus, Tumor:ESCA)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZS-A9CD, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                                    1.0
# A1BG-AS1                                                0.0
# A1CF                                                    1.0
# A2M                                                     1.0
# A2M-AS1                                                 1.0
#
#           (Donor:TCGA-ZS-A9CE, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                                    1.0
# A1BG-AS1                                                0.0
# A1CF                                                    1.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZS-A9CF, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                                    1.0
# A1BG-AS1                                               -1.0
# A1CF                                                    1.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZS-A9CG, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Liver, Tumor:LIHC)  \
# index
# A1BG                                                    1.0
# A1BG-AS1                                                0.0
# A1CF                                                    1.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZT-A8OM, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Anterior Mediastinum, Tumor:THYM)  \
# index
# A1BG                                                    0.0
# A1BG-AS1                                                1.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZU-A8S4, Gender:MALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Bile duct, Tumor:CHOL)  \
# index
# A1BG                                                    1.0
# A1BG-AS1                                               -1.0
# A1CF                                                    1.0
# A2M                                                     0.0
# A2M-AS1                                                 0.0
#
#           (Donor:TCGA-ZX-AA5X, Gender:FEMALE, Ethnicity:NOT HISPANIC OR LATINO, Tissue:Cervical, Tumor:CESC)
# index
# A1BG                                                    0.0
# A1BG-AS1                                                0.0
# A1CF                                                    0.0
# A2M                                                     0.0
# A2M-AS1                                                -1.0
#
# [5 rows x 10420 columns]

# %% [markdown]
# ## Save Teriary Matrix

# %%
filename = '~/./Documents/Harmonizome/TCGA/Output/tcga_tertiary_matrix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
tertiary_matrix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# #### Create matrix with simplified column names for libraries

# %%
lst = []
for col in tertiary_matrix.columns:
    lst.append(col[0].split(':')[1]+'_'+col[3].split(':')[1]+'_'+col[4].split(':')[1])

tertiary_matrix_simple_col = tertiary_matrix.copy()
tertiary_matrix_simple_col.columns = lst

# %%
tertiary_matrix_simple_col.head()
# Out:
#           TCGA-02-0047_Brain_GBM  TCGA-02-0055_Brain_GBM  \
# index
# A1BG                         0.0                     0.0
# A1BG-AS1                     0.0                     1.0
# A1CF                         0.0                     0.0
# A2M                          1.0                     1.0
# A2M-AS1                      1.0                     1.0
#
#           TCGA-02-2483_Brain_GBM  TCGA-02-2485_Brain_GBM  \
# index
# A1BG                         0.0                     0.0
# A1BG-AS1                     0.0                    -1.0
# A1CF                         0.0                     0.0
# A2M                          0.0                     0.0
# A2M-AS1                      0.0                    -1.0
#
#           TCGA-02-2486_Brain_GBM  TCGA-04-1331_Ovary_OV  \
# index
# A1BG                         0.0                    0.0
# A1BG-AS1                     0.0                    0.0
# A1CF                         0.0                    0.0
# A2M                          0.0                    0.0
# A2M-AS1                      0.0                    0.0
#
#           TCGA-04-1332_Ovary_OV  TCGA-04-1337_Ovary_OV  TCGA-04-1338_Ovary_OV  \
# index
# A1BG                        0.0                    0.0                    0.0
# A1BG-AS1                   -1.0                    0.0                    0.0
# A1CF                        0.0                    0.0                    0.0
# A2M                         0.0                    0.0                    0.0
# A2M-AS1                     1.0                    0.0                    0.0
#
#           TCGA-04-1341_Ovary_OV             ...              \
# index                                       ...
# A1BG                        0.0             ...
# A1BG-AS1                    0.0             ...
# A1CF                        0.0             ...
# A2M                         0.0             ...
# A2M-AS1                     0.0             ...
#
#           TCGA-ZP-A9D4_Liver_LIHC  TCGA-ZQ-A9CR_Stomach_STAD  \
# index
# A1BG                          1.0                        0.0
# A1BG-AS1                      0.0                       -1.0
# A1CF                          1.0                        0.0
# A2M                           0.0                        0.0
# A2M-AS1                       0.0                        0.0
#
#           TCGA-ZR-A9CJ_Esophagus_ESCA  TCGA-ZS-A9CD_Liver_LIHC  \
# index
# A1BG                              0.0                      1.0
# A1BG-AS1                          0.0                      0.0
# A1CF                              0.0                      1.0
# A2M                               0.0                      1.0
# A2M-AS1                           0.0                      1.0
#
#           TCGA-ZS-A9CE_Liver_LIHC  TCGA-ZS-A9CF_Liver_LIHC  \
# index
# A1BG                          1.0                      1.0
# A1BG-AS1                      0.0                     -1.0
# A1CF                          1.0                      1.0
# A2M                           0.0                      0.0
# A2M-AS1                       0.0                      0.0
#
#           TCGA-ZS-A9CG_Liver_LIHC  TCGA-ZT-A8OM_Anterior Mediastinum_THYM  \
# index
# A1BG                          1.0                                     0.0
# A1BG-AS1                      0.0                                     1.0
# A1CF                          1.0                                     0.0
# A2M                           0.0                                     0.0
# A2M-AS1                       0.0                                     0.0
#
#           TCGA-ZU-A8S4_Bile duct_CHOL  TCGA-ZX-AA5X_Cervical_CESC
# index
# A1BG                              1.0                         0.0
# A1BG-AS1                         -1.0                         0.0
# A1CF                              1.0                         0.0
# A2M                               0.0                         0.0
# A2M-AS1                           0.0                        -1.0
#
# [5 rows x 10420 columns]

# %% [markdown]
# #### Path to output files

# %%
path = '/Users/moshesilverstein/Documents/Harmonizome/TCGA/Output/'

# %% [markdown]
# # Create Up Gene Set Library

# %%
name = 'tcga_gene_up_set'

# %%
mf.createUpGeneSetLib(tertiary_matrix_simple_col, path, name, details=tertiary_matrix.columns.tolist())
# Out:
# Progeres: 100%  10420 Out of 10420

# %% [markdown]
# # Create Down Gene Set Library

# %%
name = 'tcga_gene_down_set'

# %%
mf.createDownGeneSetLib(tertiary_matrix_simple_col, path, name, details=tertiary_matrix.columns.tolist())
# Out:
# Progeres: 100%  10420 Out of 10420

# %% [markdown]
# # Create Up Attribute Library

# %%
name = 'tcga_attribute_up_set'

# %%
mf.createUpAttributeSetLib(tertiary_matrix_simple_col, path, name)
# Out:
# Progeres: 100%  31116 Out of 31116

# %% [markdown]
# # Create Down Attribute Library

# %%
name = 'tcga_attribute_down_set'

# %%
mf.createDownAttributeSetLib(tertiary_matrix_simple_col, path, name)
# Out:
# Progeres: 100%  31116 Out of 31116

# %% [markdown]
# # Create Gene Similaruty Matrix

# %%
gene_similarity_matix = mf.createSimilarityMatrix(normalized_matrix, 'cosine')

# %%
gene_similarity_matix.head()
# Out:
# index         A1BG  A1BG-AS1      A1CF       A2M   A2M-AS1     A2ML1  \
# index
# A1BG      1.000000  0.116493  0.694504  0.275436  0.178500 -0.038911
# A1BG-AS1  0.116493  1.000000 -0.055150  0.126002  0.144157 -0.081790
# A1CF      0.694504 -0.055150  1.000000  0.242718  0.110688 -0.056437
# A2M       0.275436  0.126002  0.242718  1.000000  0.367169 -0.075521
# A2M-AS1   0.178500  0.144157  0.110688  0.367169  1.000000 -0.103743
#
# index     A2ML1-AS1  A2ML1-AS2     A2MP1   A3GALT2    ...        ZWINT  \
# index                                                 ...
# A1BG      -0.029849  -0.004237  0.074557 -0.040985    ...    -0.073043
# A1BG-AS1  -0.054484  -0.033470  0.019838  0.019810    ...    -0.023675
# A1CF      -0.041388  -0.005185  0.056913 -0.068005    ...    -0.047225
# A2M       -0.036350  -0.026936  0.068859 -0.023080    ...    -0.169839
# A2M-AS1   -0.046309   0.018906  0.047931  0.018741    ...    -0.172022
#
# index         ZXDA      ZXDB      ZXDC    ZYG11A  ZYG11AP1    ZYG11B  \
# index
# A1BG     -0.090796  0.144568  0.010248  0.014914 -0.007047  0.014514
# A1BG-AS1 -0.069902 -0.042921 -0.118888  0.003921  0.166333 -0.045374
# A1CF     -0.029196  0.194410  0.035226 -0.004700 -0.027154  0.032193
# A2M       0.074228  0.030915 -0.070017 -0.060819  0.078346  0.100449
# A2M-AS1   0.053002 -0.003202 -0.039905 -0.083750  0.107086  0.039901
#
# index          ZYX     ZZEF1      ZZZ3
# index
# A1BG     -0.073304 -0.088321 -0.030026
# A1BG-AS1  0.017050 -0.001413  0.061001
# A1CF     -0.098956 -0.061513 -0.035481
# A2M       0.140198 -0.023190 -0.007753
# A2M-AS1   0.110037 -0.033705  0.046674
#
# [5 rows x 31116 columns]

# %% [markdown]
# ## Save Gene Similarity Matrix

# %%
filename = '~/./Documents/Harmonizome/TCGA/Output/tcga_gene_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Attribute Similarity matrix

# %% [markdown]
# #### Create matrix with simplified column names for attribute

# %%
lst = []
for col in tertiary_matrix.columns:
    lst.append(col[0].split(':')[1]+'_'+col[3].split(':')[1]+'_'+col[4].split(':')[1])

normalized_matrix_simple_col = normalized_matrix.copy()
normalized_matrix_simple_col.columns = lst

# %%
attribute_similarity_matix = mf.createSimilarityMatrix(normalized_matrix_simple_col.T, 'cosine')

# %%
attribute_similarity_matix.head()
# Out:
#                         TCGA-02-0047_Brain_GBM  TCGA-02-0055_Brain_GBM  \
# TCGA-02-0047_Brain_GBM                1.000000                0.202787
# TCGA-02-0055_Brain_GBM                0.202787                1.000000
# TCGA-02-2483_Brain_GBM                0.330217                0.191400
# TCGA-02-2485_Brain_GBM                0.278746                0.126908
# TCGA-02-2486_Brain_GBM                0.287948                0.379421
#
#                         TCGA-02-2483_Brain_GBM  TCGA-02-2485_Brain_GBM  \
# TCGA-02-0047_Brain_GBM                0.330217                0.278746
# TCGA-02-0055_Brain_GBM                0.191400                0.126908
# TCGA-02-2483_Brain_GBM                1.000000                0.320880
# TCGA-02-2485_Brain_GBM                0.320880                1.000000
# TCGA-02-2486_Brain_GBM                0.208332                0.217863
#
#                         TCGA-02-2486_Brain_GBM  TCGA-04-1331_Ovary_OV  \
# TCGA-02-0047_Brain_GBM                0.287948              -0.023859
# TCGA-02-0055_Brain_GBM                0.379421              -0.092156
# TCGA-02-2483_Brain_GBM                0.208332               0.078093
# TCGA-02-2485_Brain_GBM                0.217863               0.049109
# TCGA-02-2486_Brain_GBM                1.000000              -0.018279
#
#                         TCGA-04-1332_Ovary_OV  TCGA-04-1337_Ovary_OV  \
# TCGA-02-0047_Brain_GBM               0.006932               0.013133
# TCGA-02-0055_Brain_GBM              -0.057064              -0.004409
# TCGA-02-2483_Brain_GBM              -0.014081              -0.004762
# TCGA-02-2485_Brain_GBM              -0.000079              -0.016325
# TCGA-02-2486_Brain_GBM              -0.050648               0.011709
#
#                         TCGA-04-1338_Ovary_OV  TCGA-04-1341_Ovary_OV  \
# TCGA-02-0047_Brain_GBM              -0.049065              -0.054028
# TCGA-02-0055_Brain_GBM               0.004893              -0.035387
# TCGA-02-2483_Brain_GBM              -0.012100               0.042621
# TCGA-02-2485_Brain_GBM              -0.024446              -0.013045
# TCGA-02-2486_Brain_GBM              -0.020894               0.024314
#
#                                    ...              TCGA-ZP-A9D4_Liver_LIHC  \
# TCGA-02-0047_Brain_GBM             ...                            -0.039395
# TCGA-02-0055_Brain_GBM             ...                            -0.064123
# TCGA-02-2483_Brain_GBM             ...                            -0.074094
# TCGA-02-2485_Brain_GBM             ...                            -0.037563
# TCGA-02-2486_Brain_GBM             ...                            -0.020858
#
#                         TCGA-ZQ-A9CR_Stomach_STAD  \
# TCGA-02-0047_Brain_GBM                  -0.060445
# TCGA-02-0055_Brain_GBM                   0.078561
# TCGA-02-2483_Brain_GBM                  -0.066737
# TCGA-02-2485_Brain_GBM                  -0.035253
# TCGA-02-2486_Brain_GBM                  -0.045553
#
#                         TCGA-ZR-A9CJ_Esophagus_ESCA  TCGA-ZS-A9CD_Liver_LIHC  \
# TCGA-02-0047_Brain_GBM                    -0.063892                -0.071719
# TCGA-02-0055_Brain_GBM                     0.039641                 0.001396
# TCGA-02-2483_Brain_GBM                    -0.085566                -0.064230
# TCGA-02-2485_Brain_GBM                    -0.063266                -0.067455
# TCGA-02-2486_Brain_GBM                    -0.046858                -0.012286
#
#                         TCGA-ZS-A9CE_Liver_LIHC  TCGA-ZS-A9CF_Liver_LIHC  \
# TCGA-02-0047_Brain_GBM                -0.065871                -0.035974
# TCGA-02-0055_Brain_GBM                -0.053643                -0.046953
# TCGA-02-2483_Brain_GBM                -0.071307                -0.062375
# TCGA-02-2485_Brain_GBM                -0.043763                -0.029661
# TCGA-02-2486_Brain_GBM                -0.010172                -0.039937
#
#                         TCGA-ZS-A9CG_Liver_LIHC  \
# TCGA-02-0047_Brain_GBM                -0.033098
# TCGA-02-0055_Brain_GBM                -0.010863
# TCGA-02-2483_Brain_GBM                -0.053615
# TCGA-02-2485_Brain_GBM                -0.037368
# TCGA-02-2486_Brain_GBM                 0.006492
#
#                         TCGA-ZT-A8OM_Anterior Mediastinum_THYM  \
# TCGA-02-0047_Brain_GBM                               -0.101960
# TCGA-02-0055_Brain_GBM                               -0.063226
# TCGA-02-2483_Brain_GBM                                0.058715
# TCGA-02-2485_Brain_GBM                               -0.015934
# TCGA-02-2486_Brain_GBM                               -0.010584
#
#                         TCGA-ZU-A8S4_Bile duct_CHOL  \
# TCGA-02-0047_Brain_GBM                     0.004168
# TCGA-02-0055_Brain_GBM                     0.153696
# TCGA-02-2483_Brain_GBM                    -0.036520
# TCGA-02-2485_Brain_GBM                    -0.040071
# TCGA-02-2486_Brain_GBM                     0.038967
#
#                         TCGA-ZX-AA5X_Cervical_CESC
# TCGA-02-0047_Brain_GBM                   -0.071647
# TCGA-02-0055_Brain_GBM                    0.005395
# TCGA-02-2483_Brain_GBM                   -0.091451
# TCGA-02-2485_Brain_GBM                   -0.057882
# TCGA-02-2486_Brain_GBM                   -0.062181
#
# [5 rows x 10420 columns]

# %% [markdown]
# ## Save Attribute Similarity Matrix

# %%
filename = '~/./Documents/Harmonizome/TCGA/Output/tcga_attribute_similarity_matix_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_similarity_matix.to_csv(filename, sep='\t', compression='gzip')

# %% [markdown]
# # Create Gene List

# %%
gene_list = mf.createGeneList(normalized_matrix)
# Out:
# Progeres: 100%  31116 Out of 31116

# %%
gene_list.head()
# Out:
#     GeneSym  GeneID
# 0      A1BG       1
# 1  A1BG-AS1  503538
# 2      A1CF   29974
# 3       A2M       2
# 4   A2M-AS1  144571

# %%
gene_list.shape
# Out:
# (31116, 2)

# %% [markdown]
# ### Save Gene List

# %%
filename = '~/./Documents/Harmonizome/TCGA/Output/tcga_gene_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
gene_list.to_csv(filename, sep='\t', index=False, compression='gzip')

# %% [markdown]
# # Create Attribute List

# %%
attribute_list = mf.createAttributeList(normalized_matrix_simple_col)

# %%
attribute_list.head()
# Out:
#                Attributes
# 0  TCGA-02-0047_Brain_GBM
# 1  TCGA-02-0055_Brain_GBM
# 2  TCGA-02-2483_Brain_GBM
# 3  TCGA-02-2485_Brain_GBM
# 4  TCGA-02-2486_Brain_GBM

# %%
attribute_list.shape
# Out:
# (10420, 1)

# %% [markdown]
# ### Save Attribute List

# %%
filename = '~/./Documents/Harmonizome/TCGA/Output/tcga_attribute_list_%s.tsv.zip'% str(datetime.date.today())[0:7].replace('-', '_')
attribute_list.to_csv(filename, sep='\t', index=False, compression='gzip')

# %% [markdown]
# # Create Gene-Attribute Edge List

# %%
path = '/Users/moshesilverstein/Documents/Harmonizome/TCGA/Output/'

# %%
name = 'tcga_gene_attribute_edge_list'

# %%
mf.createGeneAttributeEdgeList(tertiary_matrix_simple_col, gene_list, path, name)
# Out:
# Progeres: 100%  10420 Out of 10420
#
#  The number of statisticaly relevent gene-attribute associations is: 64843697
